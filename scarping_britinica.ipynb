# %%
import requests
import json
from bs4 import BeautifulSoup
from requests_html import HTMLSession
import pandas as pd
from numpy import random
from time import sleep

try:
    from googlesearch import search
except ImportError:
    print("No module named 'google' found")

# %%
not_stemmed_word = pd.read_csv("not_stemmed_word_based_wiki_score.csv")
not_stemmed_word
# Out:
#              word  similarity
# 0         vehicle    0.765537
# 1           truck    0.735062
# 2          driver    0.711478
# 3         driving    0.644223
# 4        vehicles    0.632800
# ...           ...         ...
# 1047      there's         NaN
# 1048   governor's         NaN
# 1049     mother's         NaN
# 1050  passenger's         NaN
# 1051         he's         NaN
#
# [1052 rows x 2 columns]

# %%
filtred_words1 = []
word_list =  not_stemmed_word["word"].tolist()
for el in word_list:
    if el.endswith("'s"):
        filtred_words1.append(el[:-2])
    else:
        filtred_words1.append(el)

# %%
len(filtred_words1)
# Out:
# 1052

# %%
# filtred_words2 = []
dup_words = []
for check_start in filtred_words1:
    res=[value for value in filtred_words1 if value[:-1].lower() == check_start.lower() and value.endswith("s")]
    if res:
#         print(check_start, res)
        dup_words.extend(res)
dup_words
# Out:
# ['vehicles',
#  'drivers',
#  'automobiles',
#  'autos',
#  'garages',
#  'dealerships',
#  'motors',
#  'wheels',
#  'bombs',
#  'accidents',
#  'engines',
#  'doors',
#  'rides',
#  'wagons',
#  'rentals',
#  'ones',
#  'speeds',
#  'manufacturers',
#  'models',
#  'owners',
#  'windows',
#  'tracks',
#  'races',
#  'dealers',
#  'puts',
#  'parts',
#  'repairs',
#  'lights',
#  'houses',
#  'results',
#  'lines',
#  'parks',
#  'offices',
#  'compartments',
#  'trips',
#  'needs',
#  'cases',
#  'pools',
#  'loads',
#  'radios',
#  'follows',
#  'fares',
#  'horns',
#  'loans',
#  'angles',
#  'friends']

# %%
filtred_words = list(set(filtred_words1) - set(dup_words))
len(filtred_words)
# Out:
# 1003

# %% [markdown]
# ## Do not use google api !!
# there is a limitation(100 req per day) for number of requests!

# %% [markdown]
# ## just for demo use next cell
# ```python
# def get_google_search_results(query="What is car?"):
#     starts = list(x for x in range(1,100,10))
#     res_dict_lsit = []
#     for start in starts :
#         API_KEY = "AIzaSyD8oV9Vs8yjNPLAjWPe6emSZf1E865K7uY"
#     #     SEARCH_ENGINE_ID = "e714535f954174f5d"
#         SEARCH_ENGINE_ID = "13581eb0fad555f88"
#
# #         query = f"What is {word}?"
#
#         url = f"https://www.googleapis.com/customsearch/v1?key={API_KEY}&cx={SEARCH_ENGINE_ID}&q={query}"
#
#         params = {'num': 10, 'start': start}
#
#         res = requests.get(url, params=params).json()
#
#         res_dict_lsit.append(res)
#
#     #     print(json.dumps(res, indent=4, sort_keys=True))
#     #     break
#     return res_dict_lsit
#
# res_dict_lsit = get_google_search_results(query="What is car?")
# def get_link(res_dict_lsit):
#     britannica_links = []
#     for res in res_dict_lsit:
#         try:
#             items = res['items']
#             for item in items:
#                 title = item['title']
#                 print(title)
#                 print(item['link'])
#                 britannica_links.append(item['link'])
#         except KeyError:
#           print(json.dumps(res, indent=4, sort_keys=True))
#     return britannica_links
# ```

# %%
def get_google_search_results(word):
    print(f"search google for {word}")
    starts = list(x for x in range(1,100,10))
    res_dict_lsit = []
    for start in starts :
        API_KEY = "AIzaSyD8oV9Vs8yjNPLAjWPe6emSZf1E865K7uY"
    #     SEARCH_ENGINE_ID = "e714535f954174f5d"
        SEARCH_ENGINE_ID = "13581eb0fad555f88"

        query = f"What is {word}?"

        url = f"https://www.googleapis.com/customsearch/v1?key={API_KEY}&cx={SEARCH_ENGINE_ID}&q={query}"

        params = {'num': 10, 'start': start}

        res = requests.get(url, params=params).json()

        res_dict_lsit.append(res)

    #     print(json.dumps(res, indent=4, sort_keys=True))
    #     break

    britannica_links = []
    for res in res_dict_lsit:
        items = res['items']
        for item in items:
            britannica_links.append(item['link'])
    return britannica_links

# %%
def britannica_search(word):
    print(f"search britannica for {word}")
    # to search
    query = f"what is {word}? site:britannica.com"
    
    p_time = int(random.uniform(3, 7))
    sleep(p_time)
    
    britannica_links = []
    for j in search(query, tld="com", lang='en', num=10, start=0, stop=100, pause=p_time):
        britannica_links.append(j)
    
    return britannica_links

# %%
def scarpe_links(britannica_links):
    # get all link related to a cocept
    all_links = []
    for lin in britannica_links:
        all_links.append(lin)
        # create an HTML Session object
        session = HTMLSession()
        # Use the object above to connect to needed webpage
        resp = session.get(lin)
        for u in resp.html.absolute_links:
            if lin in u and u != lin:
                all_links.append(u)
    #             print(u)
    return all_links

# %%
extracted_links = dict()
extracted_words = []

# %%
print(len(filtred_words))
print(len(list(set(filtred_words) - set(extracted_words))))
# Out:
# 1003
# 968

# %%
len(extracted_words)
# Out:
# 35

# %%
while(search_words):
    search_words = list(set(filtred_words) - set(extracted_words))
    w_count = 0
    
    for word in search_words:
        w_count = w_count + 1
        if w_count == 5:
            break
        brit_links = britannica_search(word)
        extracted_words.append(word)
        extracted_links[word] = brit_links
    print(f"remaining words count: {len(list(set(filtred_words) - set(extracted_words)))}")
    sleep(20 * 60)
# Out:
# search britannica for must
# search britannica for hear
# search britannica for however
# search britannica for peace
# remaining words count: 723
# search britannica for installation
# search britannica for flooded
# search britannica for orders
# search britannica for increased
# remaining words count: 719
# search britannica for across
# search britannica for kissed
# search britannica for hungry
# search britannica for inching
# remaining words count: 715
# search britannica for smiling
# search britannica for cooler
# search britannica for radio
# search britannica for co
# remaining words count: 711
# search britannica for arranged
# search britannica for mass
# search britannica for purring
# search britannica for result
# remaining words count: 707
# search britannica for prices
# search britannica for baby
# search britannica for staff
# search britannica for acr
# remaining words count: 703
# search britannica for garage
# search britannica for train
# search britannica for where
# search britannica for help
# remaining words count: 699
# search britannica for chair
# search britannica for toyota
# search britannica for write
# search britannica for concept
# remaining words count: 695
# search britannica for battle
# search britannica for tail
# search britannica for stuffy
# search britannica for jarring
# remaining words count: 691
# search britannica for what
# search britannica for yellow
# search britannica for bumper
# search britannica for secret
# remaining words count: 687
# search britannica for avenue
# search britannica for slowing
# search britannica for strangers
# search britannica for survived
# remaining words count: 683
# search britannica for loaders
# search britannica for vincent
# search britannica for slides
# search britannica for rudy
# remaining words count: 679
# search britannica for compartment
# search britannica for theft
# search britannica for proportion
# search britannica for target
# remaining words count: 675
# search britannica for payments
# search britannica for depending
# search britannica for mileage
# search britannica for sounded
# remaining words count: 671
# search britannica for midst
# search britannica for scout
# search britannica for chief
# search britannica for two
# remaining words count: 667
# search britannica for business
# search britannica for moderate
# search britannica for oldsmobile
# search britannica for los
# remaining words count: 663
# search britannica for amid
# search britannica for boat
# search britannica for annie
# search britannica for true
# remaining words count: 659
# search britannica for pen
# search britannica for pulling
# search britannica for platform
# search britannica for pool
# remaining words count: 655
# search britannica for boxcar
# search britannica for subcompact
# search britannica for visited
# search britannica for resell
# remaining words count: 651
# search britannica for us
# search britannica for idling
# search britannica for similar
# search britannica for bus
# remaining words count: 647
# search britannica for bicycle
# search britannica for yesterday
# search britannica for shortage
# search britannica for first
# remaining words count: 643
# search britannica for accepted
# search britannica for matchbox
# search britannica for offer
# search britannica for corn
# remaining words count: 639
# search britannica for installed
# search britannica for outa
# search britannica for describe
# search britannica for sound
# remaining words count: 635
# search britannica for foul
# search britannica for cleaners
# search britannica for see
# search britannica for king
# remaining words count: 631
# search britannica for dieu
# search britannica for room
# search britannica for neighbor
# search britannica for company
# remaining words count: 627
# search britannica for last
# search britannica for remember
# search britannica for studying
# search britannica for height
# remaining words count: 623
# search britannica for rock
# search britannica for impact
# search britannica for cruise
# search britannica for hinted
# remaining words count: 619
# search britannica for wind
# search britannica for robbed
# search britannica for service
# search britannica for elevator
# remaining words count: 615
# search britannica for stereo
# search britannica for comme
# search britannica for developed
# search britannica for construction
# remaining words count: 611
# search britannica for system
# search britannica for government
# search britannica for access
# search britannica for leave
# remaining words count: 607
# search britannica for horseback
# search britannica for omnibus
# search britannica for lifetime
# search britannica for raced
# remaining words count: 603
# search britannica for provisions
# search britannica for diagonally
# search britannica for apart
# search britannica for identical
# remaining words count: 599
# search britannica for ninth
# search britannica for sell
# search britannica for economy
# search britannica for thick
# remaining words count: 595
# search britannica for minivan
# search britannica for tire
# search britannica for army
# search britannica for friend
# remaining words count: 591
# search britannica for suicide
# search britannica for changing
# search britannica for inquired
# search britannica for opposite
# remaining words count: 587
# search britannica for machinery
# search britannica for man
# search britannica for meant
# search britannica for winged
# remaining words count: 583
# search britannica for express
# search britannica for testified
# search britannica for floating
# search britannica for drew
# remaining words count: 579
# search britannica for motor
# search britannica for door
# search britannica for identify
# search britannica for tenth
# remaining words count: 575
# search britannica for need
# search britannica for show
# search britannica for filled
# search britannica for tous
# remaining words count: 571
# search britannica for explode
# search britannica for twenty
# search britannica for concierge
# search britannica for propel
# remaining words count: 567
# search britannica for strafed
# search britannica for test
# search britannica for short
# search britannica for bearing
# remaining words count: 563
# search britannica for toy
# search britannica for whirlwind
# search britannica for losing
# search britannica for bank
# remaining words count: 559
# search britannica for floorboard
# search britannica for saved
# search britannica for comfort
# search britannica for cart
# remaining words count: 555
# search britannica for forest
# search britannica for hugged
# search britannica for pull
# search britannica for wondered
# remaining words count: 551
# search britannica for belonged
# search britannica for like
# search britannica for rushes
# search britannica for due
# remaining words count: 547
# search britannica for controlling
# search britannica for consignment
# search britannica for rotation
# search britannica for fairly
# remaining words count: 543
# search britannica for passing
# search britannica for collateral
# search britannica for large
# search britannica for monday
# remaining words count: 539
# search britannica for rail
# search britannica for say
# search britannica for talked
# search britannica for constructed
# remaining words count: 535
# search britannica for coach
# search britannica for buffet
# search britannica for paris
# search britannica for sedan
# remaining words count: 531
# search britannica for highway
# search britannica for morrow
# search britannica for capital
# search britannica for seats
# remaining words count: 527
# search britannica for higher
# search britannica for tragically
# search britannica for essentially
# search britannica for roof
# remaining words count: 523
# search britannica for seemed
# search britannica for ratio
# search britannica for nearest
# search britannica for safety
# remaining words count: 519
# search britannica for rocking
# search britannica for balloon
# search britannica for steep
# search britannica for fixes
# remaining words count: 515
# search britannica for daughter
# search britannica for said
# search britannica for celui
# search britannica for distance
# remaining words count: 511
# search britannica for sort
# search britannica for jackings
# search britannica for launched
# search britannica for seconds
# remaining words count: 507
# search britannica for airplane
# search britannica for allows
# search britannica for vintage
# search britannica for mother
# remaining words count: 503
# search britannica for grocery
# search britannica for coal
# search britannica for refrigerator
# search britannica for stopping
# remaining words count: 499
# search britannica for examination
# search britannica for hand
# search britannica for convert
# search britannica for pace
# remaining words count: 495
# search britannica for silver
# search britannica for told
# search britannica for crow
# search britannica for market
# remaining words count: 491
# search britannica for low
# search britannica for alfa
# search britannica for idle
# search britannica for beater
# remaining words count: 487
# search britannica for carriage
# search britannica for tel
# search britannica for changed
# search britannica for shipping
# remaining words count: 483
# search britannica for small
# search britannica for truck
# search britannica for companies
# search britannica for plus
# remaining words count: 479
# search britannica for parking
# search britannica for grabbed
# search britannica for steam
# search britannica for fiat
# remaining words count: 475
# search britannica for eftoit
# search britannica for highpowered
# search britannica for dead
# search britannica for stock
# remaining words count: 471
# search britannica for drove
# search britannica for engineered
# search britannica for snapped
# search britannica for serviceable
# remaining words count: 467
# search britannica for ireland
# search britannica for colour
# search britannica for mine
# search britannica for pipe
# remaining words count: 463
# search britannica for backseat
# search britannica for rent
# search britannica for briefcase
# search britannica for overloading
# remaining words count: 459
# search britannica for pleasure
# search britannica for pellucid
# search britannica for track
# search britannica for ensure
# remaining words count: 455
# search britannica for stumbled
# search britannica for cushions
# search britannica for lounge
# search britannica for vehicular
# remaining words count: 451
# search britannica for interested
# search britannica for vaulted
# search britannica for body
# search britannica for st
# remaining words count: 447
# search britannica for pressure
# search britannica for road
# search britannica for operations
# search britannica for sales
# remaining words count: 443

# %%
print(len(extracted_words))
print(len(list(set(filtred_words) - set(extracted_words))))
# Out:
# 1003
# 0

# %%
import json

with open('data/britannica_l1_car_link.json', 'w') as fp:
    json.dump(extracted_links, fp)

# %%
with open('data/britannica_l1_car_link.json', 'r') as fp:
    data = json.load(fp)

# %%
import glob

# %%
[f.rsplit('/', 1)[1].split('.',1)[0] for f in glob.glob("data/britanica_texts/*.txt")]
# Out:
# ['untitled']

# %%
def retrive(link, file_name):
    web_text = ""
    try:
        page = requests.get(link)
        soup = BeautifulSoup(page.content, "html.parser")
        # getting all the paragraphs
        for para in soup.find_all("p"):
            web_text = web_text + para.get_text() + "\n"
        # print(para.get_text())
        with open(f'data/britanica_texts/{file_name}.txt', 'w') as f:
            f.write(web_text)
#             print(f'save file in name of {file_name}.txt')
        sleep(1.1)
    except:
        print("An exception occurred")
        sleep(30)

# %%
len(scarped_words)
# Out:
# 1003

# %%
scarped_words = []
for el in data:
    if el not in scarped_words:
        print(f"***** fetch {len(data[el])} articles about {el} *******")
        for l in data[el]:
            file_names = [f.rsplit('/', 1)[1] for f in glob.glob("data/britanica_texts/*.txt")]
            l_split, r_split = l.rsplit('/', 1)
            if r_split == '':
                file_name = l_split.rsplit('/', 1)[1]
            else:
                file_name = l.rsplit('/', 1)[1]
            if file_name + '.txt' not in file_names:
                print(f"retrive {l, file_name}")
                retrive(l, file_name)
    #         else:
    #             print(f"already searched for {file_name}")
        scarped_words.append(el)
        remain_words = list(set(filtred_words) - set(scarped_words))
        print(f'____________________________________ remain: {len(remain_words)} _________________________________')
# Out:
# ***** fetch 100 articles about defendant *******
# ____________________________________ remain: 1002 _____________________________________
# ***** fetch 100 articles about latter *******
# ____________________________________ remain: 1001 _____________________________________
# ***** fetch 100 articles about create *******
# ____________________________________ remain: 1000 _____________________________________
# ***** fetch 100 articles about fender *******
# ____________________________________ remain: 999 _____________________________________
# ***** fetch 100 articles about met *******
# ____________________________________ remain: 998 _____________________________________
# ***** fetch 100 articles about seen *******
# ____________________________________ remain: 997 _____________________________________
# ***** fetch 100 articles about long *******
# ____________________________________ remain: 996 _____________________________________
# ***** fetch 100 articles about asked *******
# ____________________________________ remain: 995 _____________________________________
# ***** fetch 100 articles about kicked *******
# ____________________________________ remain: 994 _____________________________________
# ***** fetch 100 articles about spoke *******
# ____________________________________ remain: 993 _____________________________________
# ***** fetch 100 articles about pictures *******
# ____________________________________ remain: 992 _____________________________________
# ***** fetch 100 articles about received *******
# ____________________________________ remain: 991 _____________________________________
# ***** fetch 100 articles about stolen *******
# ____________________________________ remain: 990 _____________________________________
# ***** fetch 100 articles about unlocked *******
# ____________________________________ remain: 989 _____________________________________
# ***** fetch 100 articles about makers *******
# ____________________________________ remain: 988 _____________________________________
# ***** fetch 100 articles about automobile *******
# ____________________________________ remain: 987 _____________________________________
# ***** fetch 100 articles about line *******
# ____________________________________ remain: 986 _____________________________________
# ***** fetch 100 articles about issue *******
# ____________________________________ remain: 985 _____________________________________
# ***** fetch 100 articles about played *******
# ____________________________________ remain: 984 _____________________________________
# ***** fetch 100 articles about policemen *******
# ____________________________________ remain: 983 _____________________________________
# ***** fetch 100 articles about control *******
# ____________________________________ remain: 982 _____________________________________
# ***** fetch 100 articles about instead *******
# ____________________________________ remain: 981 _____________________________________
# ***** fetch 76 articles about briskly *******
# ____________________________________ remain: 980 _____________________________________
# ***** fetch 100 articles about marie *******
# ____________________________________ remain: 979 _____________________________________
# ***** fetch 100 articles about falling *******
# ____________________________________ remain: 978 _____________________________________
# ***** fetch 69 articles about cashier *******
# ____________________________________ remain: 977 _____________________________________
# ***** fetch 100 articles about sharply *******
# ____________________________________ remain: 976 _____________________________________
# ***** fetch 100 articles about thief *******
# ____________________________________ remain: 975 _____________________________________
# ***** fetch 100 articles about hidden *******
# ____________________________________ remain: 974 _____________________________________
# ***** fetch 100 articles about shiny *******
# ____________________________________ remain: 973 _____________________________________
# ***** fetch 100 articles about builders *******
# ____________________________________ remain: 972 _____________________________________
# ***** fetch 100 articles about walk *******
# ____________________________________ remain: 971 _____________________________________
# ***** fetch 100 articles about continue *******
# ____________________________________ remain: 970 _____________________________________
# ***** fetch 100 articles about trolley *******
# ____________________________________ remain: 969 _____________________________________
# ***** fetch 100 articles about wonder *******
# ____________________________________ remain: 968 _____________________________________
# ***** fetch 100 articles about home *******
# ____________________________________ remain: 967 _____________________________________
# ***** fetch 100 articles about park *******
# ____________________________________ remain: 966 _____________________________________
# ***** fetch 100 articles about grain *******
# ____________________________________ remain: 965 _____________________________________
# ***** fetch 100 articles about doc *******
# ____________________________________ remain: 964 _____________________________________
# ***** fetch 100 articles about tax *******
# ____________________________________ remain: 963 _____________________________________
# ***** fetch 100 articles about sill *******
# ____________________________________ remain: 962 _____________________________________
# ***** fetch 100 articles about narrow *******
# ____________________________________ remain: 961 _____________________________________
# ***** fetch 100 articles about rusty *******
# ____________________________________ remain: 960 _____________________________________
# ***** fetch 100 articles about crossing *******
# ____________________________________ remain: 959 _____________________________________
# ***** fetch 100 articles about answering *******
# ____________________________________ remain: 958 _____________________________________
# ***** fetch 100 articles about stay *******
# ____________________________________ remain: 957 _____________________________________
# ***** fetch 100 articles about teenagers *******
# ____________________________________ remain: 956 _____________________________________
# ***** fetch 100 articles about slam *******
# ____________________________________ remain: 955 _____________________________________
# ***** fetch 100 articles about lot *******
# ____________________________________ remain: 954 _____________________________________
# ***** fetch 100 articles about mentioned *******
# ____________________________________ remain: 953 _____________________________________
# ***** fetch 100 articles about today *******
# ____________________________________ remain: 952 _____________________________________
# ***** fetch 78 articles about ln *******
# ____________________________________ remain: 951 _____________________________________
# ***** fetch 100 articles about iron *******
# ____________________________________ remain: 950 _____________________________________
# ***** fetch 100 articles about rounds *******
# ____________________________________ remain: 949 _____________________________________
# ***** fetch 100 articles about motorcycle *******
# ____________________________________ remain: 948 _____________________________________
# ***** fetch 100 articles about bruce *******
# ____________________________________ remain: 947 _____________________________________
# ***** fetch 100 articles about adjusted *******
# ____________________________________ remain: 946 _____________________________________
# ***** fetch 100 articles about mail *******
# ____________________________________ remain: 945 _____________________________________
# ***** fetch 100 articles about filling *******
# ____________________________________ remain: 944 _____________________________________
# ***** fetch 100 articles about float *******
# ____________________________________ remain: 943 _____________________________________
# ***** fetch 80 articles about getaway *******
# ____________________________________ remain: 942 _____________________________________
# ***** fetch 47 articles about limousine *******
# ____________________________________ remain: 941 _____________________________________
# ***** fetch 100 articles about there *******
# ____________________________________ remain: 940 _____________________________________
# ***** fetch 100 articles about talking *******
# ____________________________________ remain: 939 _____________________________________
# ***** fetch 100 articles about ye *******
# ____________________________________ remain: 938 _____________________________________
# ***** fetch 100 articles about expensive *******
# ____________________________________ remain: 937 _____________________________________
# ***** fetch 9 articles about diac *******
# ____________________________________ remain: 936 _____________________________________
# ***** fetch 100 articles about valet *******
# ____________________________________ remain: 935 _____________________________________
# ***** fetch 100 articles about spins *******
# ____________________________________ remain: 934 _____________________________________
# ***** fetch 100 articles about supplying *******
# ____________________________________ remain: 933 _____________________________________
# ***** fetch 100 articles about hybrid *******
# ____________________________________ remain: 932 _____________________________________
# ***** fetch 100 articles about someone *******
# ____________________________________ remain: 931 _____________________________________
# ***** fetch 100 articles about tune *******
# ____________________________________ remain: 930 _____________________________________
# ***** fetch 100 articles about used *******
# ____________________________________ remain: 929 _____________________________________
# ***** fetch 100 articles about ride *******
# ____________________________________ remain: 928 _____________________________________
# ***** fetch 100 articles about disappearing *******
# ____________________________________ remain: 927 _____________________________________
# ***** fetch 100 articles about fixing *******
# ____________________________________ remain: 926 _____________________________________
# ***** fetch 100 articles about commission *******
# ____________________________________ remain: 925 _____________________________________
# ***** fetch 100 articles about freight *******
# ____________________________________ remain: 924 _____________________________________
# ***** fetch 100 articles about recall *******
# ____________________________________ remain: 923 _____________________________________
# ***** fetch 100 articles about breakdown *******
# ____________________________________ remain: 922 _____________________________________
# ***** fetch 100 articles about muscle *******
# ____________________________________ remain: 921 _____________________________________
# ***** fetch 100 articles about phone *******
# ____________________________________ remain: 920 _____________________________________
# ***** fetch 100 articles about typical *******
# ____________________________________ remain: 919 _____________________________________
# ***** fetch 100 articles about wanting *******
# ____________________________________ remain: 918 _____________________________________
# ***** fetch 100 articles about victory *******
# ____________________________________ remain: 917 _____________________________________
# ***** fetch 100 articles about flew *******
# ____________________________________ remain: 916 _____________________________________
# ***** fetch 100 articles about imagination *******
# ____________________________________ remain: 915 _____________________________________
# ***** fetch 100 articles about searched *******
# ____________________________________ remain: 914 _____________________________________
# ***** fetch 100 articles about policeman *******
# ____________________________________ remain: 913 _____________________________________
# ***** fetch 100 articles about flipped *******
# ____________________________________ remain: 912 _____________________________________
# ***** fetch 100 articles about especially *******
# ____________________________________ remain: 911 _____________________________________
# ***** fetch 100 articles about halfway *******
# ____________________________________ remain: 910 _____________________________________
# ***** fetch 100 articles about bomb *******
# ____________________________________ remain: 909 _____________________________________
# ***** fetch 100 articles about onto *******
# ____________________________________ remain: 908 _____________________________________
# ***** fetch 100 articles about beauty *******
# ____________________________________ remain: 907 _____________________________________
# ***** fetch 100 articles about vice *******
# ____________________________________ remain: 906 _____________________________________
# ***** fetch 100 articles about distant *******
# ____________________________________ remain: 905 _____________________________________
# ***** fetch 100 articles about staring *******
# ____________________________________ remain: 904 _____________________________________
# ***** fetch 100 articles about custom *******
# ____________________________________ remain: 903 _____________________________________
# ***** fetch 100 articles about gazing *******
# ____________________________________ remain: 902 _____________________________________
# ***** fetch 100 articles about wagon *******
# ____________________________________ remain: 901 _____________________________________
# ***** fetch 100 articles about mercedes *******
# ____________________________________ remain: 900 _____________________________________
# ***** fetch 100 articles about dining *******
# ____________________________________ remain: 899 _____________________________________
# ***** fetch 70 articles about eft *******
# ____________________________________ remain: 898 _____________________________________
# ***** fetch 83 articles about diomedes *******
# ____________________________________ remain: 897 _____________________________________
# ***** fetch 100 articles about fix *******
# ____________________________________ remain: 896 _____________________________________
# ***** fetch 100 articles about hung *******
# ____________________________________ remain: 895 _____________________________________
# ***** fetch 100 articles about burning *******
# ____________________________________ remain: 894 _____________________________________
# ***** fetch 100 articles about mounting *******
# ____________________________________ remain: 893 _____________________________________
# ***** fetch 100 articles about palace *******
# ____________________________________ remain: 892 _____________________________________
# ***** fetch 97 articles about crunched *******
# ____________________________________ remain: 891 _____________________________________
# ***** fetch 100 articles about contents *******
# ____________________________________ remain: 890 _____________________________________
# ***** fetch 100 articles about former *******
# ____________________________________ remain: 889 _____________________________________
# ***** fetch 100 articles about read *******
# ____________________________________ remain: 888 _____________________________________
# ***** fetch 100 articles about squad *******
# ____________________________________ remain: 887 _____________________________________
# ***** fetch 100 articles about older *******
# ____________________________________ remain: 886 _____________________________________
# ***** fetch 100 articles about supposed *******
# ____________________________________ remain: 885 _____________________________________
# ***** fetch 100 articles about driver *******
# ____________________________________ remain: 884 _____________________________________
# ***** fetch 100 articles about observation *******
# ____________________________________ remain: 883 _____________________________________
# ***** fetch 100 articles about hood *******
# ____________________________________ remain: 882 _____________________________________
# ***** fetch 100 articles about bandwagon *******
# ____________________________________ remain: 881 _____________________________________
# ***** fetch 100 articles about merits *******
# ____________________________________ remain: 880 _____________________________________
# ***** fetch 100 articles about funeral *******
# ____________________________________ remain: 879 _____________________________________
# ***** fetch 100 articles about standing *******
# ____________________________________ remain: 878 _____________________________________
# ***** fetch 100 articles about rolls *******
# ____________________________________ remain: 877 _____________________________________
# ***** fetch 100 articles about colliding *******
# ____________________________________ remain: 876 _____________________________________
# ***** fetch 34 articles about roadster *******
# ____________________________________ remain: 875 _____________________________________
# ***** fetch 100 articles about hop *******
# ____________________________________ remain: 874 _____________________________________
# ***** fetch 78 articles about thronged *******
# ____________________________________ remain: 873 _____________________________________
# ***** fetch 6 articles about cln *******
# ____________________________________ remain: 872 _____________________________________
# ***** fetch 72 articles about vandalized *******
# ____________________________________ remain: 871 _____________________________________
# ***** fetch 100 articles about street *******
# ____________________________________ remain: 870 _____________________________________
# ***** fetch 100 articles about day *******
# ____________________________________ remain: 869 _____________________________________
# ***** fetch 85 articles about minicar *******
# ____________________________________ remain: 868 _____________________________________
# ***** fetch 100 articles about shipped *******
# ____________________________________ remain: 867 _____________________________________
# ***** fetch 100 articles about occupant *******
# ____________________________________ remain: 866 _____________________________________
# ***** fetch 100 articles about coast *******
# ____________________________________ remain: 865 _____________________________________
# ***** fetch 100 articles about characteristics *******
# ____________________________________ remain: 864 _____________________________________
# ***** fetch 100 articles about escaped *******
# ____________________________________ remain: 863 _____________________________________
# ***** fetch 100 articles about england *******
# ____________________________________ remain: 862 _____________________________________
# ***** fetch 100 articles about caesar *******
# ____________________________________ remain: 861 _____________________________________
# ***** fetch 100 articles about sports *******
# ____________________________________ remain: 860 _____________________________________
# ***** fetch 100 articles about deputy *******
# ____________________________________ remain: 859 _____________________________________
# ***** fetch 69 articles about marmon *******
# ____________________________________ remain: 858 _____________________________________
# ***** fetch 100 articles about noise *******
# ____________________________________ remain: 857 _____________________________________
# ***** fetch 100 articles about auto *******
# ____________________________________ remain: 856 _____________________________________
# ***** fetch 100 articles about bounced *******
# ____________________________________ remain: 855 _____________________________________
# ***** fetch 100 articles about wore *******
# ____________________________________ remain: 854 _____________________________________
# ***** fetch 100 articles about fingerprints *******
# ____________________________________ remain: 853 _____________________________________
# ***** fetch 100 articles about that *******
# ____________________________________ remain: 852 _____________________________________
# ***** fetch 100 articles about dealer *******
# ____________________________________ remain: 851 _____________________________________
# ***** fetch 100 articles about hire *******
# ____________________________________ remain: 850 _____________________________________
# ***** fetch 100 articles about dump *******
# ____________________________________ remain: 849 _____________________________________
# ***** fetch 100 articles about bridge *******
# ____________________________________ remain: 848 _____________________________________
# ***** fetch 100 articles about seeped *******
# ____________________________________ remain: 847 _____________________________________
# ***** fetch 100 articles about overtaken *******
# ____________________________________ remain: 846 _____________________________________
# ***** fetch 98 articles about suis *******
# ____________________________________ remain: 845 _____________________________________
# ***** fetch 100 articles about easier *******
# ____________________________________ remain: 844 _____________________________________
# ***** fetch 3 articles about carpark *******
# ____________________________________ remain: 843 _____________________________________
# ***** fetch 100 articles about pinto *******
# ____________________________________ remain: 842 _____________________________________
# ***** fetch 100 articles about dennis *******
# ____________________________________ remain: 841 _____________________________________
# ***** fetch 100 articles about van *******
# ____________________________________ remain: 840 _____________________________________
# ***** fetch 100 articles about porters *******
# ____________________________________ remain: 839 _____________________________________
# ***** fetch 100 articles about fleet *******
# ____________________________________ remain: 838 _____________________________________
# ***** fetch 100 articles about trade *******
# ____________________________________ remain: 837 _____________________________________
# ***** fetch 100 articles about mort *******
# ____________________________________ remain: 836 _____________________________________
# ***** fetch 100 articles about crate *******
# ____________________________________ remain: 835 _____________________________________
# ***** fetch 100 articles about processional *******
# ____________________________________ remain: 834 _____________________________________
# ***** fetch 100 articles about around *******
# ____________________________________ remain: 833 _____________________________________
# ***** fetch 100 articles about hesitated *******
# ____________________________________ remain: 832 _____________________________________
# ***** fetch 77 articles about motorcade *******
# ____________________________________ remain: 831 _____________________________________
# ***** fetch 100 articles about chinese *******
# ____________________________________ remain: 830 _____________________________________
# ***** fetch 100 articles about drive *******
# ____________________________________ remain: 829 _____________________________________
# ***** fetch 61 articles about trooper *******
# ____________________________________ remain: 828 _____________________________________
# ***** fetch 100 articles about also *******
# ____________________________________ remain: 827 _____________________________________
# ***** fetch 100 articles about style *******
# ____________________________________ remain: 826 _____________________________________
# ***** fetch 100 articles about paying *******
# ____________________________________ remain: 825 _____________________________________
# ***** fetch 100 articles about size *******
# ____________________________________ remain: 824 _____________________________________
# ***** fetch 100 articles about cab *******
# ____________________________________ remain: 823 _____________________________________
# ***** fetch 61 articles about shoved *******
# ____________________________________ remain: 822 _____________________________________
# ***** fetch 29 articles about faut *******
# ____________________________________ remain: 821 _____________________________________
# ***** fetch 100 articles about earth *******
# ____________________________________ remain: 820 _____________________________________
# ***** fetch 100 articles about glove *******
# ____________________________________ remain: 819 _____________________________________
# ***** fetch 100 articles about guideth *******
# ____________________________________ remain: 818 _____________________________________
# ***** fetch 100 articles about engineering *******
# ____________________________________ remain: 817 _____________________________________
# ***** fetch 100 articles about gray *******
# ____________________________________ remain: 816 _____________________________________
# ***** fetch 100 articles about become *******
# ____________________________________ remain: 815 _____________________________________
# ***** fetch 100 articles about fare *******
# ____________________________________ remain: 814 _____________________________________
# ***** fetch 100 articles about battery *******
# ____________________________________ remain: 813 _____________________________________
# ***** fetch 100 articles about proper *******
# ____________________________________ remain: 812 _____________________________________
# ***** fetch 100 articles about alice *******
# ____________________________________ remain: 811 _____________________________________
# ***** fetch 100 articles about rival *******
# ____________________________________ remain: 810 _____________________________________
# ***** fetch 100 articles about governor *******
# ____________________________________ remain: 809 _____________________________________
# ***** fetch 100 articles about could *******
# ____________________________________ remain: 808 _____________________________________
# ***** fetch 100 articles about vehicle *******
# ____________________________________ remain: 807 _____________________________________
# ***** fetch 100 articles about lighting *******
# ____________________________________ remain: 806 _____________________________________
# ***** fetch 52 articles about motoring *******
# ____________________________________ remain: 805 _____________________________________
# ***** fetch 100 articles about wrapped *******
# ____________________________________ remain: 804 _____________________________________
# ***** fetch 100 articles about ann *******
# ____________________________________ remain: 803 _____________________________________
# ***** fetch 100 articles about town *******
# ____________________________________ remain: 802 _____________________________________
# ***** fetch 100 articles about hopper *******
# ____________________________________ remain: 801 _____________________________________
# ***** fetch 100 articles about cigarette *******
# ____________________________________ remain: 800 _____________________________________
# ***** fetch 100 articles about mouth *******
# ____________________________________ remain: 799 _____________________________________
# ***** fetch 100 articles about shoot *******
# ____________________________________ remain: 798 _____________________________________
# ***** fetch 100 articles about whipped *******
# ____________________________________ remain: 797 _____________________________________
# ***** fetch 100 articles about joel *******
# ____________________________________ remain: 796 _____________________________________
# ***** fetch 100 articles about outskirts *******
# ____________________________________ remain: 795 _____________________________________
# ***** fetch 100 articles about toward *******
# ____________________________________ remain: 794 _____________________________________
# ***** fetch 100 articles about railroad *******
# ____________________________________ remain: 793 _____________________________________
# ***** fetch 100 articles about drinking *******
# ____________________________________ remain: 792 _____________________________________
# ***** fetch 100 articles about window *******
# ____________________________________ remain: 791 _____________________________________
# ***** fetch 100 articles about approved *******
# ____________________________________ remain: 790 _____________________________________
# ***** fetch 100 articles about campus *******
# ____________________________________ remain: 789 _____________________________________
# ***** fetch 100 articles about speakers *******
# ____________________________________ remain: 788 _____________________________________
# ***** fetch 100 articles about including *******
# ____________________________________ remain: 787 _____________________________________
# ***** fetch 100 articles about women *******
# ____________________________________ remain: 786 _____________________________________
# ***** fetch 100 articles about together *******
# ____________________________________ remain: 785 _____________________________________
# ***** fetch 100 articles about school *******
# ____________________________________ remain: 784 _____________________________________
# ***** fetch 100 articles about examined *******
# ____________________________________ remain: 783 _____________________________________
# ***** fetch 100 articles about dash *******
# ____________________________________ remain: 782 _____________________________________
# ***** fetch 100 articles about silence *******
# ____________________________________ remain: 781 _____________________________________
# ***** fetch 100 articles about shuttle *******
# ____________________________________ remain: 780 _____________________________________
# ***** fetch 100 articles about cloud *******
# ____________________________________ remain: 779 _____________________________________
# ***** fetch 100 articles about ought *******
# ____________________________________ remain: 778 _____________________________________
# ***** fetch 100 articles about fig *******
# ____________________________________ remain: 777 _____________________________________
# ***** fetch 100 articles about back *******
# ____________________________________ remain: 776 _____________________________________
# ***** fetch 100 articles about loaned *******
# ____________________________________ remain: 775 _____________________________________
# ***** fetch 76 articles about yells *******
# ____________________________________ remain: 774 _____________________________________
# ***** fetch 100 articles about father *******
# ____________________________________ remain: 773 _____________________________________
# ***** fetch 100 articles about half *******
# ____________________________________ remain: 772 _____________________________________
# ***** fetch 100 articles about refrigerated *******
# ____________________________________ remain: 771 _____________________________________
# ***** fetch 100 articles about lived *******
# ____________________________________ remain: 770 _____________________________________
# ***** fetch 35 articles about prowl *******
# ____________________________________ remain: 769 _____________________________________
# ***** fetch 100 articles about upon *******
# ____________________________________ remain: 768 _____________________________________
# ***** fetch 100 articles about bodies *******
# ____________________________________ remain: 767 _____________________________________
# ***** fetch 100 articles about find *******
# ____________________________________ remain: 766 _____________________________________
# ***** fetch 100 articles about worry *******
# ____________________________________ remain: 765 _____________________________________
# ***** fetch 100 articles about world *******
# ____________________________________ remain: 764 _____________________________________
# ***** fetch 100 articles about maroon *******
# ____________________________________ remain: 763 _____________________________________
# ***** fetch 100 articles about chariot *******
# ____________________________________ remain: 762 _____________________________________
# ***** fetch 100 articles about fastest *******
# ____________________________________ remain: 761 _____________________________________
# ***** fetch 100 articles about railway *******
# ____________________________________ remain: 760 _____________________________________
# ***** fetch 100 articles about motorcar *******
# ____________________________________ remain: 759 _____________________________________
# ***** fetch 42 articles about lorry *******
# ____________________________________ remain: 758 _____________________________________
# ***** fetch 100 articles about coursers *******
# ____________________________________ remain: 757 _____________________________________
# ***** fetch 100 articles about overcrowded *******
# ____________________________________ remain: 756 _____________________________________
# ***** fetch 11 articles about hatchback *******
# ____________________________________ remain: 755 _____________________________________
# ***** fetch 100 articles about fund *******
# ____________________________________ remain: 754 _____________________________________
# ***** fetch 67 articles about propped *******
# ____________________________________ remain: 753 _____________________________________
# ***** fetch 100 articles about crashes *******
# ____________________________________ remain: 752 _____________________________________
# ***** fetch 100 articles about material *******
# ____________________________________ remain: 751 _____________________________________
# ***** fetch 100 articles about bound *******
# ____________________________________ remain: 750 _____________________________________
# ***** fetch 100 articles about upset *******
# ____________________________________ remain: 749 _____________________________________
# ***** fetch 100 articles about aside *******
# ____________________________________ remain: 748 _____________________________________
# ***** fetch 100 articles about equity *******
# ____________________________________ remain: 747 _____________________________________
# ***** fetch 100 articles about constant *******
# ____________________________________ remain: 746 _____________________________________
# ***** fetch 100 articles about indra *******
# ____________________________________ remain: 745 _____________________________________
# ***** fetch 100 articles about rounded *******
# ____________________________________ remain: 744 _____________________________________
# ***** fetch 100 articles about furnishing *******
# ____________________________________ remain: 743 _____________________________________
# ***** fetch 100 articles about usually *******
# ____________________________________ remain: 742 _____________________________________
# ***** fetch 100 articles about needless *******
# ____________________________________ remain: 741 _____________________________________
# ***** fetch 100 articles about flames *******
# ____________________________________ remain: 740 _____________________________________
# ***** fetch 100 articles about taken *******
# ____________________________________ remain: 739 _____________________________________
# ***** fetch 100 articles about pair *******
# ____________________________________ remain: 738 _____________________________________
# ***** fetch 50 articles about carmaker *******
# ____________________________________ remain: 737 _____________________________________
# ***** fetch 100 articles about location *******
# ____________________________________ remain: 736 _____________________________________
# ***** fetch 100 articles about guys *******
# ____________________________________ remain: 735 _____________________________________
# ***** fetch 100 articles about attendant *******
# ____________________________________ remain: 734 _____________________________________
# ***** fetch 100 articles about coupe *******
# ____________________________________ remain: 733 _____________________________________
# ***** fetch 100 articles about attained *******
# ____________________________________ remain: 732 _____________________________________
# ***** fetch 100 articles about ferry *******
# ____________________________________ remain: 731 _____________________________________
# ***** fetch 100 articles about recognize *******
# ____________________________________ remain: 730 _____________________________________
# ***** fetch 100 articles about optional *******
# ____________________________________ remain: 729 _____________________________________
# ***** fetch 100 articles about exhaust *******
# ____________________________________ remain: 728 _____________________________________
# ***** fetch 100 articles about log *******
# ____________________________________ remain: 727 _____________________________________
# ***** fetch 100 articles about must *******
# ____________________________________ remain: 726 _____________________________________
# ***** fetch 100 articles about hear *******
# ____________________________________ remain: 725 _____________________________________
# ***** fetch 100 articles about however *******
# ____________________________________ remain: 724 _____________________________________
# ***** fetch 100 articles about peace *******
# ____________________________________ remain: 723 _____________________________________
# ***** fetch 100 articles about installation *******
# ____________________________________ remain: 722 _____________________________________
# ***** fetch 100 articles about flooded *******
# ____________________________________ remain: 721 _____________________________________
# ***** fetch 100 articles about orders *******
# ____________________________________ remain: 720 _____________________________________
# ***** fetch 100 articles about increased *******
# ____________________________________ remain: 719 _____________________________________
# ***** fetch 100 articles about across *******
# ____________________________________ remain: 718 _____________________________________
# ***** fetch 100 articles about kissed *******
# ____________________________________ remain: 717 _____________________________________
# ***** fetch 100 articles about hungry *******
# ____________________________________ remain: 716 _____________________________________
# ***** fetch 26 articles about inching *******
# ____________________________________ remain: 715 _____________________________________
# ***** fetch 100 articles about smiling *******
# ____________________________________ remain: 714 _____________________________________
# ***** fetch 100 articles about cooler *******
# ____________________________________ remain: 713 _____________________________________
# ***** fetch 100 articles about radio *******
# ____________________________________ remain: 712 _____________________________________
# ***** fetch 100 articles about co *******
# ____________________________________ remain: 711 _____________________________________
# ***** fetch 100 articles about arranged *******
# ____________________________________ remain: 710 _____________________________________
# ***** fetch 100 articles about mass *******
# ____________________________________ remain: 709 _____________________________________
# ***** fetch 52 articles about purring *******
# ____________________________________ remain: 708 _____________________________________
# ***** fetch 100 articles about result *******
# ____________________________________ remain: 707 _____________________________________
# ***** fetch 100 articles about prices *******
# ____________________________________ remain: 706 _____________________________________
# ***** fetch 100 articles about baby *******
# ____________________________________ remain: 705 _____________________________________
# ***** fetch 100 articles about staff *******
# ____________________________________ remain: 704 _____________________________________
# ***** fetch 14 articles about acr *******
# ____________________________________ remain: 703 _____________________________________
# ***** fetch 100 articles about garage *******
# ____________________________________ remain: 702 _____________________________________
# ***** fetch 100 articles about train *******
# ____________________________________ remain: 701 _____________________________________
# ***** fetch 100 articles about where *******
# ____________________________________ remain: 700 _____________________________________
# ***** fetch 100 articles about help *******
# ____________________________________ remain: 699 _____________________________________
# ***** fetch 100 articles about chair *******
# ____________________________________ remain: 698 _____________________________________
# ***** fetch 100 articles about toyota *******
# ____________________________________ remain: 697 _____________________________________
# ***** fetch 100 articles about write *******
# ____________________________________ remain: 696 _____________________________________
# ***** fetch 100 articles about concept *******
# ____________________________________ remain: 695 _____________________________________
# ***** fetch 100 articles about battle *******
# ____________________________________ remain: 694 _____________________________________
# ***** fetch 100 articles about tail *******
# ____________________________________ remain: 693 _____________________________________
# ***** fetch 55 articles about stuffy *******
# ____________________________________ remain: 692 _____________________________________
# ***** fetch 100 articles about jarring *******
# ____________________________________ remain: 691 _____________________________________
# ***** fetch 100 articles about what *******
# ____________________________________ remain: 690 _____________________________________
# ***** fetch 100 articles about yellow *******
# ____________________________________ remain: 689 _____________________________________
# ***** fetch 100 articles about bumper *******
# ____________________________________ remain: 688 _____________________________________
# ***** fetch 100 articles about secret *******
# ____________________________________ remain: 687 _____________________________________
# ***** fetch 100 articles about avenue *******
# ____________________________________ remain: 686 _____________________________________
# ***** fetch 100 articles about slowing *******
# ____________________________________ remain: 685 _____________________________________
# ***** fetch 100 articles about strangers *******
# ____________________________________ remain: 684 _____________________________________
# ***** fetch 100 articles about survived *******
# ____________________________________ remain: 683 _____________________________________
# ***** fetch 100 articles about loaders *******
# ____________________________________ remain: 682 _____________________________________
# ***** fetch 100 articles about vincent *******
# ____________________________________ remain: 681 _____________________________________
# ***** fetch 100 articles about slides *******
# ____________________________________ remain: 680 _____________________________________
# ***** fetch 100 articles about rudy *******
# ____________________________________ remain: 679 _____________________________________
# ***** fetch 100 articles about compartment *******
# ____________________________________ remain: 678 _____________________________________
# ***** fetch 100 articles about theft *******
# ____________________________________ remain: 677 _____________________________________
# ***** fetch 100 articles about proportion *******
# ____________________________________ remain: 676 _____________________________________
# ***** fetch 100 articles about target *******
# ____________________________________ remain: 675 _____________________________________
# ***** fetch 100 articles about payments *******
# ____________________________________ remain: 674 _____________________________________
# ***** fetch 100 articles about depending *******
# ____________________________________ remain: 673 _____________________________________
# ***** fetch 49 articles about mileage *******
# ____________________________________ remain: 672 _____________________________________
# ***** fetch 100 articles about sounded *******
# ____________________________________ remain: 671 _____________________________________
# ***** fetch 100 articles about midst *******
# ____________________________________ remain: 670 _____________________________________
# ***** fetch 100 articles about scout *******
# ____________________________________ remain: 669 _____________________________________
# ***** fetch 100 articles about chief *******
# ____________________________________ remain: 668 _____________________________________
# ***** fetch 100 articles about two *******
# ____________________________________ remain: 667 _____________________________________
# ***** fetch 100 articles about business *******
# ____________________________________ remain: 666 _____________________________________
# ***** fetch 100 articles about moderate *******
# ____________________________________ remain: 665 _____________________________________
# ***** fetch 31 articles about oldsmobile *******
# ____________________________________ remain: 664 _____________________________________
# ***** fetch 100 articles about los *******
# ____________________________________ remain: 663 _____________________________________
# ***** fetch 100 articles about amid *******
# ____________________________________ remain: 662 _____________________________________
# ***** fetch 100 articles about boat *******
# ____________________________________ remain: 661 _____________________________________
# ***** fetch 100 articles about annie *******
# ____________________________________ remain: 660 _____________________________________
# ***** fetch 100 articles about true *******
# ____________________________________ remain: 659 _____________________________________
# ***** fetch 100 articles about pen *******
# ____________________________________ remain: 658 _____________________________________
# ***** fetch 100 articles about pulling *******
# ____________________________________ remain: 657 _____________________________________
# ***** fetch 100 articles about platform *******
# ____________________________________ remain: 656 _____________________________________
# ***** fetch 100 articles about pool *******
# ____________________________________ remain: 655 _____________________________________
# ***** fetch 47 articles about boxcar *******
# ____________________________________ remain: 654 _____________________________________
# ***** fetch 11 articles about subcompact *******
# ____________________________________ remain: 653 _____________________________________
# ***** fetch 100 articles about visited *******
# ____________________________________ remain: 652 _____________________________________
# ***** fetch 45 articles about resell *******
# ____________________________________ remain: 651 _____________________________________
# ***** fetch 100 articles about us *******
# ____________________________________ remain: 650 _____________________________________
# ***** fetch 44 articles about idling *******
# ____________________________________ remain: 649 _____________________________________
# ***** fetch 100 articles about similar *******
# ____________________________________ remain: 648 _____________________________________
# ***** fetch 100 articles about bus *******
# ____________________________________ remain: 647 _____________________________________
# ***** fetch 100 articles about bicycle *******
# ____________________________________ remain: 646 _____________________________________
# ***** fetch 100 articles about yesterday *******
# ____________________________________ remain: 645 _____________________________________
# ***** fetch 100 articles about shortage *******
# ____________________________________ remain: 644 _____________________________________
# ***** fetch 100 articles about first *******
# ____________________________________ remain: 643 _____________________________________
# ***** fetch 100 articles about accepted *******
# ...
# ***** fetch 100 articles about crash *******
# ____________________________________ remain: 120 _____________________________________
# ***** fetch 100 articles about shadow *******
# ____________________________________ remain: 119 _____________________________________
# ***** fetch 13 articles about semble *******
# ____________________________________ remain: 118 _____________________________________
# ***** fetch 100 articles about giving *******
# ____________________________________ remain: 117 _____________________________________
# ***** fetch 9 articles about handcar *******
# ____________________________________ remain: 116 _____________________________________
# ***** fetch 100 articles about called *******
# ____________________________________ remain: 115 _____________________________________
# ***** fetch 100 articles about restaurant *******
# ____________________________________ remain: 114 _____________________________________
# ***** fetch 100 articles about sight *******
# ____________________________________ remain: 113 _____________________________________
# ***** fetch 100 articles about choice *******
# ____________________________________ remain: 112 _____________________________________
# ***** fetch 100 articles about almost *******
# ____________________________________ remain: 111 _____________________________________
# ***** fetch 100 articles about night *******
# ____________________________________ remain: 110 _____________________________________
# ***** fetch 100 articles about salesman *******
# ____________________________________ remain: 109 _____________________________________
# ***** fetch 100 articles about response *******
# ____________________________________ remain: 108 _____________________________________
# ***** fetch 100 articles about role *******
# ____________________________________ remain: 107 _____________________________________
# ***** fetch 100 articles about brand *******
# ____________________________________ remain: 106 _____________________________________
# ***** fetch 60 articles about buick *******
# ____________________________________ remain: 105 _____________________________________
# ***** fetch 100 articles about fired *******
# ____________________________________ remain: 104 _____________________________________
# ***** fetch 100 articles about cattle *******
# ____________________________________ remain: 103 _____________________________________
# ***** fetch 100 articles about nativity *******
# ____________________________________ remain: 102 _____________________________________
# ***** fetch 100 articles about cabin *******
# ____________________________________ remain: 101 _____________________________________
# ***** fetch 24 articles about bodywork *******
# ____________________________________ remain: 100 _____________________________________
# ***** fetch 100 articles about big *******
# ____________________________________ remain: 99 _____________________________________
# ***** fetch 100 articles about free *******
# ____________________________________ remain: 98 _____________________________________
# ***** fetch 100 articles about popular *******
# ____________________________________ remain: 97 _____________________________________
# ***** fetch 100 articles about moment *******
# ____________________________________ remain: 96 _____________________________________
# ***** fetch 100 articles about near *******
# ____________________________________ remain: 95 _____________________________________
# ***** fetch 100 articles about furnish *******
# ____________________________________ remain: 94 _____________________________________
# ***** fetch 100 articles about feed *******
# ____________________________________ remain: 93 _____________________________________
# ***** fetch 100 articles about nearby *******
# ____________________________________ remain: 92 _____________________________________
# ***** fetch 100 articles about designed *******
# ____________________________________ remain: 91 _____________________________________
# ***** fetch 100 articles about buyers *******
# ____________________________________ remain: 90 _____________________________________
# ***** fetch 100 articles about feet *******
# ____________________________________ remain: 89 _____________________________________
# ***** fetch 100 articles about later *******
# ____________________________________ remain: 88 _____________________________________
# ***** fetch 100 articles about wire *******
# ____________________________________ remain: 87 _____________________________________
# ***** fetch 100 articles about angle *******
# ____________________________________ remain: 86 _____________________________________
# ***** fetch 100 articles about ford *******
# ____________________________________ remain: 85 _____________________________________
# ***** fetch 100 articles about neighborhood *******
# ____________________________________ remain: 84 _____________________________________
# ***** fetch 29 articles about headlight *******
# ____________________________________ remain: 83 _____________________________________
# ***** fetch 100 articles about pound *******
# ____________________________________ remain: 82 _____________________________________
# ***** fetch 100 articles about given *******
# ____________________________________ remain: 81 _____________________________________
# ***** fetch 100 articles about hard *******
# ____________________________________ remain: 80 _____________________________________
# ***** fetch 100 articles about wholly *******
# ____________________________________ remain: 79 _____________________________________
# ***** fetch 100 articles about passenger *******
# ____________________________________ remain: 78 _____________________________________
# ***** fetch 100 articles about holes *******
# ____________________________________ remain: 77 _____________________________________
# ***** fetch 100 articles about restore *******
# ____________________________________ remain: 76 _____________________________________
# ***** fetch 100 articles about oberon *******
# ____________________________________ remain: 75 _____________________________________
# ***** fetch 100 articles about glowing *******
# ____________________________________ remain: 74 _____________________________________
# ***** fetch 100 articles about case *******
# ____________________________________ remain: 73 _____________________________________
# ***** fetch 100 articles about cylinder *******
# ____________________________________ remain: 72 _____________________________________
# ***** fetch 100 articles about performance *******
# ____________________________________ remain: 71 _____________________________________
# ***** fetch 100 articles about three *******
# ____________________________________ remain: 70 _____________________________________
# ***** fetch 100 articles about accident *******
# ____________________________________ remain: 69 _____________________________________
# ***** fetch 100 articles about ore *******
# ____________________________________ remain: 68 _____________________________________
# ***** fetch 100 articles about glass *******
# ____________________________________ remain: 67 _____________________________________
# ***** fetch 100 articles about mere *******
# ____________________________________ remain: 66 _____________________________________
# ***** fetch 100 articles about leases *******
# ____________________________________ remain: 65 _____________________________________
# ***** fetch 100 articles about machine *******
# ____________________________________ remain: 64 _____________________________________
# ***** fetch 100 articles about occasionally *******
# ____________________________________ remain: 63 _____________________________________
# ***** fetch 46 articles about soldat *******
# ____________________________________ remain: 62 _____________________________________
# ***** fetch 100 articles about many *******
# ____________________________________ remain: 61 _____________________________________
# ***** fetch 100 articles about command *******
# ____________________________________ remain: 60 _____________________________________
# ***** fetch 100 articles about native *******
# ____________________________________ remain: 59 _____________________________________
# ***** fetch 83 articles about huddled *******
# ____________________________________ remain: 58 _____________________________________
# ***** fetch 100 articles about wrought *******
# ____________________________________ remain: 57 _____________________________________
# ***** fetch 100 articles about call *******
# ____________________________________ remain: 56 _____________________________________
# ***** fetch 100 articles about deliver *******
# ____________________________________ remain: 55 _____________________________________
# ***** fetch 100 articles about people *******
# ____________________________________ remain: 54 _____________________________________
# ***** fetch 100 articles about carla *******
# ____________________________________ remain: 53 _____________________________________
# ***** fetch 100 articles about never *******
# ____________________________________ remain: 52 _____________________________________
# ***** fetch 100 articles about afford *******
# ____________________________________ remain: 51 _____________________________________
# ***** fetch 100 articles about getting *******
# ____________________________________ remain: 50 _____________________________________
# ***** fetch 100 articles about victor *******
# ____________________________________ remain: 49 _____________________________________
# ***** fetch 100 articles about extent *******
# ____________________________________ remain: 48 _____________________________________
# ***** fetch 100 articles about covers *******
# ____________________________________ remain: 47 _____________________________________
# ***** fetch 100 articles about tram *******
# ____________________________________ remain: 46 _____________________________________
# ***** fetch 100 articles about surround *******
# ____________________________________ remain: 45 _____________________________________
# ***** fetch 100 articles about player *******
# ____________________________________ remain: 44 _____________________________________
# ***** fetch 100 articles about equipment *******
# ____________________________________ remain: 43 _____________________________________
# ***** fetch 100 articles about anyone *******
# ____________________________________ remain: 42 _____________________________________
# ***** fetch 100 articles about mrs *******
# ____________________________________ remain: 41 _____________________________________
# ***** fetch 100 articles about power *******
# ____________________________________ remain: 40 _____________________________________
# ***** fetch 100 articles about baggage *******
# ____________________________________ remain: 39 _____________________________________
# ***** fetch 100 articles about viewed *******
# ____________________________________ remain: 38 _____________________________________
# ***** fetch 100 articles about police *******
# ____________________________________ remain: 37 _____________________________________
# ***** fetch 100 articles about rose *******
# ____________________________________ remain: 36 _____________________________________
# ***** fetch 100 articles about trip *******
# ____________________________________ remain: 35 _____________________________________
# ***** fetch 100 articles about wrecked *******
# ____________________________________ remain: 34 _____________________________________
# ***** fetch 100 articles about wheel *******
# ____________________________________ remain: 33 _____________________________________
# ***** fetch 100 articles about rim *******
# ____________________________________ remain: 32 _____________________________________
# ***** fetch 100 articles about stare *******
# ____________________________________ remain: 31 _____________________________________
# ***** fetch 100 articles about raise *******
# ____________________________________ remain: 30 _____________________________________
# ***** fetch 100 articles about ass *******
# ____________________________________ remain: 29 _____________________________________
# ***** fetch 100 articles about resulting *******
# ____________________________________ remain: 28 _____________________________________
# ***** fetch 51 articles about coasted *******
# ____________________________________ remain: 27 _____________________________________
# ***** fetch 100 articles about horn *******
# ____________________________________ remain: 26 _____________________________________
# ***** fetch 100 articles about shops *******
# ____________________________________ remain: 25 _____________________________________
# ***** fetch 100 articles about stream *******
# ____________________________________ remain: 24 _____________________________________
# ***** fetch 100 articles about jersey *******
# ____________________________________ remain: 23 _____________________________________
# ***** fetch 100 articles about floored *******
# ____________________________________ remain: 22 _____________________________________
# ***** fetch 100 articles about insurance *******
# ____________________________________ remain: 21 _____________________________________
# ***** fetch 100 articles about pony *******
# ____________________________________ remain: 20 _____________________________________
# ***** fetch 100 articles about made *******
# ____________________________________ remain: 19 _____________________________________
# ***** fetch 100 articles about downtown *******
# ____________________________________ remain: 18 _____________________________________
# ***** fetch 100 articles about outside *******
# ____________________________________ remain: 17 _____________________________________
# ***** fetch 100 articles about mid *******
# ____________________________________ remain: 16 _____________________________________
# ***** fetch 100 articles about replaced *******
# ____________________________________ remain: 15 _____________________________________
# ***** fetch 100 articles about infant *******
# ____________________________________ remain: 14 _____________________________________
# ***** fetch 100 articles about warm *******
# ____________________________________ remain: 13 _____________________________________
# ***** fetch 100 articles about warrant *******
# ____________________________________ remain: 12 _____________________________________
# ***** fetch 100 articles about lower *******
# ____________________________________ remain: 11 _____________________________________
# ***** fetch 29 articles about lege *******
# ____________________________________ remain: 10 _____________________________________
# ***** fetch 100 articles about recovering *******
# ____________________________________ remain: 9 _____________________________________
# ***** fetch 100 articles about problem *******
# ____________________________________ remain: 8 _____________________________________
# ***** fetch 100 articles about cruiser *******
# ____________________________________ remain: 7 _____________________________________
# ***** fetch 100 articles about gleaming *******
# ____________________________________ remain: 6 _____________________________________
# ***** fetch 100 articles about exact *******
# ____________________________________ remain: 5 _____________________________________
# ***** fetch 100 articles about slipped *******
# ____________________________________ remain: 4 _____________________________________
# ***** fetch 7 articles about latmus *******
# ____________________________________ remain: 3 _____________________________________
# ***** fetch 100 articles about automaker *******
# ____________________________________ remain: 2 _____________________________________
# ***** fetch 100 articles about temperature *******
# ____________________________________ remain: 1 _____________________________________
# ***** fetch 100 articles about carrying *******
# ____________________________________ remain: 0 _____________________________________

# %%
! ls
# Out:
# clustring.ipynb			       scarping_britinica.ipynb
# data				       scarping_wiki.ipynb
# information_scarping.ipynb	       scarping_wikipedia.ipynb
# most_similar.ipynb		       Untitled1.ipynb
# n_car.txt			       Untitled.ipynb
# ngram_search.txt		       web_scarpe_text_files
# not_stemmed_word_based_wiki_score.csv  wiki_data_processing.ipynb
# partial_data_based_wiki_score.csv      wiki_text.ipynb
# partial_data.csv		       word_file
# refine_text.ipynb

# %%
#URL = "https://www.britannica.com/technology/automobile"
web_text = ""
for el in set_links:
    page = requests.get(el)
    soup = BeautifulSoup(page.content, "html.parser")
    # getting all the paragraphs
    for para in soup.find_all("p"):
        web_text = web_text + para.get_text() + "\n"
#         print(para.get_text())

# %%
with open('web_scarpe_text_files/britannica.txt', 'w') as f:
    f.write(web_text)
