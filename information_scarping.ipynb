# %% [markdown]
# # dict

# %%
! pip install urbandict
# Out:
# Collecting urbandict
#   Downloading urbandict-0.6.1.tar.gz (22 kB)
# Using legacy 'setup.py install' for urbandict, since package 'wheel' is not installed.
# Installing collected packages: urbandict
#     Running setup.py install for urbandict ... done
# Successfully installed urbandict-0.6.1
# WARNING: You are using pip version 20.3.3; however, version 21.3 is available.
# You should consider upgrading via the '/home/barzamini/.pyenv/versions/3.7.6/bin/python3.7 -m pip install --upgrade pip' command.

# %%
import urbandict

# %%
urbandict.define('truck')
# Out:
# [{'word': 'truck',
#   'def': 'Someone who draws',
#   'example': 'The pigs',
#   'category': ''},
#  {'word': 'truck', 'def': 'To run', 'example': 'Ol', 'category': ''},
#  {'word': 'truck',
#   'def': 'another four-wheeled vehicle with a flat bed in the back used for storage',
#   'example': 'Trucks',
#   'category': ''},
#  {'word': 'truck',
#   'def': 'A vehicle of a redneck, which he drives to a date with his girlfriend instead of carring',
#   'example': 'My truck is Dodge',
#   'category': ''},
#  {'word': 'truck',
#   'def': 'compensation',
#   'example': "he's compensating",
#   'category': ''},
#  {'word': 'truck',
#   'def': 'a word to describe someone/things extreme',
#   'example': 'that dude is a truck',
#   'category': ''},
#  {'word': 'truck',
#   'def': 'Connection, association',
#   'example': 'My grandfather',
#   'category': ''}]

# %%
! pip install wordsapy
# Out:
# Collecting wordsapy
#   Downloading wordsapy-1.1.1-py3-none-any.whl (7.3 kB)
# Collecting requests
#   Downloading requests-2.26.0-py2.py3-none-any.whl (62 kB)
#      |████████████████████████████████| 62 kB 181 kB/s  eta 0:00:01
# Collecting certifi>=2017.4.17
#   Downloading certifi-2021.10.8-py2.py3-none-any.whl (149 kB)
#      |████████████████████████████████| 149 kB 35.4 MB/s eta 0:00:01
# Collecting charset-normalizer~=2.0.0
#   Downloading charset_normalizer-2.0.7-py3-none-any.whl (38 kB)
# Collecting idna<4,>=2.5
#   Downloading idna-3.3-py3-none-any.whl (61 kB)
#      |████████████████████████████████| 61 kB 2.2 MB/s  eta 0:00:01
# Collecting urllib3<1.27,>=1.21.1
#   Downloading urllib3-1.26.7-py2.py3-none-any.whl (138 kB)
#      |████████████████████████████████| 138 kB 59.5 MB/s eta 0:00:01
# Installing collected packages: urllib3, idna, charset-normalizer, certifi, requests, wordsapy
# Successfully installed certifi-2021.10.8 charset-normalizer-2.0.7 idna-3.3 requests-2.26.0 urllib3-1.26.7 wordsapy-1.1.1
# WARNING: You are using pip version 20.3.3; however, version 21.3 is available.
# You should consider upgrading via the '/home/barzamini/.pyenv/versions/3.7.6/bin/python3.7 -m pip install --upgrade pip' command.

# %%
! pip install GoogleNews
# Out:
# Collecting GoogleNews
#   Downloading GoogleNews-1.5.9-py3-none-any.whl (7.8 kB)
# Requirement already satisfied: python-dateutil in /home/barzamini/.pyenv/versions/3.7.6/lib/python3.7/site-packages (from GoogleNews) (2.8.1)
# Collecting beautifulsoup4
#   Downloading beautifulsoup4-4.10.0-py3-none-any.whl (97 kB)
#      |████████████████████████████████| 97 kB 1.1 MB/s  eta 0:00:01
# Collecting soupsieve>1.2
#   Downloading soupsieve-2.2.1-py3-none-any.whl (33 kB)
# Collecting dateparser
#   Downloading dateparser-1.1.0-py2.py3-none-any.whl (288 kB)
#      |████████████████████████████████| 288 kB 70.0 MB/s eta 0:00:01
# Requirement already satisfied: pytz in /home/barzamini/.pyenv/versions/3.7.6/lib/python3.7/site-packages (from dateparser->GoogleNews) (2021.1)
# Requirement already satisfied: regex!=2019.02.19,!=2021.8.27 in /home/barzamini/.pyenv/versions/3.7.6/lib/python3.7/site-packages (from dateparser->GoogleNews) (2021.9.24)
# Requirement already satisfied: six>=1.5 in /home/barzamini/.pyenv/versions/3.7.6/lib/python3.7/site-packages (from python-dateutil->GoogleNews) (1.15.0)
# Collecting tzlocal
#   Downloading tzlocal-4.0.1-py3-none-any.whl (19 kB)
# Collecting backports.zoneinfo
#   Downloading backports.zoneinfo-0.2.1-cp37-cp37m-manylinux1_x86_64.whl (70 kB)
#      |████████████████████████████████| 70 kB 2.2 MB/s  eta 0:00:01
# Collecting pytz-deprecation-shim
#   Downloading pytz_deprecation_shim-0.1.0.post0-py2.py3-none-any.whl (15 kB)
# Collecting tzdata
#   Downloading tzdata-2021.4-py2.py3-none-any.whl (339 kB)
#      |████████████████████████████████| 339 kB 66.9 MB/s eta 0:00:01
# Installing collected packages: tzdata, backports.zoneinfo, pytz-deprecation-shim, tzlocal, soupsieve, dateparser, beautifulsoup4, GoogleNews
# Successfully installed GoogleNews-1.5.9 backports.zoneinfo-0.2.1 beautifulsoup4-4.10.0 dateparser-1.1.0 pytz-deprecation-shim-0.1.0.post0 soupsieve-2.2.1 tzdata-2021.4 tzlocal-4.0.1
# WARNING: You are using pip version 20.3.3; however, version 21.3 is available.
# You should consider upgrading via the '/home/barzamini/.pyenv/versions/3.7.6/bin/python3.7 -m pip install --upgrade pip' command.

# %%
from GoogleNews import GoogleNews
googlenews = GoogleNews(lang='en', region='US')

# %%
googlenews.set_lang('en')
googlenews.set_period('7d')
googlenews.get_news('CAR')
googlenews.search('CAR')

# %%
result = googlenews.page_at(1)
result
# Out:
# [{'title': 'Bloomingdale man shot in parked car in Paterson',
#   'media': 'Paterson Times',
#   'date': '5 mins ago',
#   'datetime': None,
#   'desc': "An occupant from a passing car began shooting towards the victim's vehicle, authorities said. Police said the victim arrived at Saint Joseph's University...",
#   'link': 'https://patersontimes.com/2021/10/22/bloomingdale-man-shot-in-parked-car-in-paterson/',
#   'img': '...'},
#  {'title': '3 hurt after 2-car crash on Highway 51',
#   'media': 'Channel 3000',
#   'date': '11 mins ago',
#   'datetime': None,
#   'desc': 'Dispatch confirmed the two-car crash happened at 8:25 a.m. on the highway south of McFarland. Officials said two of the injuries are non-life threatening, while...',
#   'link': 'https://www.channel3000.com/several-injuries-in-2-car-crash-on-highway-51-dispatch-says/',
#   'img': '...'},
#  {'title': 'Teen crashes stolen vehicle into WPD patrol car',
#   'media': 'KWCH',
#   'date': '17 mins ago',
#   'datetime': None,
#   'desc': "Near Blake and Palisade, the vehicle stopped and turned around, facing the officer's car, which was parked with the officer inside.",
#   'link': 'https://www.kwch.com/2021/10/22/teen-crashes-stolen-vehicle-into-wpd-patrol-car/',
#   'img': '...'},
#  {'title': 'Alleged Car Burglar Opens Fire at Doral Homeowner; Group ...',
#   'media': 'NBC Miami',
#   'date': '19 mins ago',
#   'datetime': None,
#   'desc': 'A group of alleged car burglars are on the run after one suspect opened fire at a Doral homeowner Friday, surveillance video shows.',
#   'link': 'https://www.nbcmiami.com/news/local/alleged-car-burglar-opens-fire-at-doral-homeowner-group-of-suspects-remain-at-large/2588057/',
#   'img': '...'},
#  {'title': 'Man seriously injured in car-train crash in Anderson',
#   'media': 'The Herald Bulletin',
#   'date': '22 mins ago',
#   'datetime': None,
#   'desc': "ANDERSON — A 60-year-old man was seriously injured Thursday in a car-train crash on the city's east side, police said. According to a report from Anderson...",
#   'link': 'https://www.heraldbulletin.com/news/local_news/man-seriously-injured-in-car-train-crash-in-anderson/article_aeaedc6a-333f-11ec-b142-e7844cbf6027.html',
#   'img': '...'},
#  {'title': 'Flying debris leaves worker in critical condition after Pinellas ...',
#   'media': 'WFLA',
#   'date': '24 mins ago',
#   'datetime': None,
#   'desc': '(WFLA) — An excavator operator was hospitalized Thursday along the 6300 block of the Pinellas Bayway when debris from a nearby car accident struck a worker...',
#   'link': 'https://www.wfla.com/news/pinellas-county/flying-debris-leaves-worker-in-critical-condition-after-pinellas-county-car-crash/',
#   'img': '...'},
#  {'title': 'Planning Commission OKs luxury car service center at Tysons ...',
#   'media': 'Tysons Reporter',
#   'date': '25 mins ago',
#   'datetime': None,
#   'desc': 'Planning Commission OKs luxury car service center at Tysons Galleria ... Luxury electric vehicle manufacturer Lucid Motors passed a crucial step yesterday (...',
#   'link': 'https://www.tysonsreporter.com/2021/10/22/planning-commission-oks-luxury-car-service-electric-vehicle-business-at-tysons-galleria/',
#   'img': '...'},
#  {'title': 'Man accused of leading officers on chase, backing into patrol ...',
#   'media': 'WWAY',
#   'date': '31 mins ago',
#   'datetime': None,
#   'desc': 'Man accused of leading officers on chase, backing into patrol car ... WILMINGTON, NC (WWAY) — A man faces several drug and assault charges after a brief chase in...',
#   'link': 'https://www.wwaytv3.com/2021/10/22/man-accused-of-leading-officers-on-chase-backing-into-patrol-car/',
#   'img': '...'},
#  {'title': 'Dothan man pleads guilty in hot car death of his son',
#   'media': 'WTVY',
#   'date': '33 mins ago',
#   'datetime': None,
#   'desc': 'On a hot June afternoon in 2019, two-year-old Castiel King slipped out of his home and climbed into a Mazda sports car as Robert and his wife, Melinda King,...',
#   'link': 'https://www.wtvy.com/2021/10/22/dothan-man-pleads-guilty-hot-car-death-his-son/',
#   'img': '...'},
#  {'title': '"I hope he has the car to push Lewis Hamilton to the limit ...',
#   'media': '',
#   'date': '43 mins ago',
#   'datetime': None,
#   'desc': '“I hope he has the car to push Lewis Hamilton to the limit”: Sebastian Vettel hopes Max Verstappen does not face the same problems as he did in his title fight...',
#   'link': 'https://thesportsrush.com/f1-news-i-hope-he-has-the-car-to-push-lewis-hamilton-to-the-limit-sebastian-vettel-hopes-max-verstappen-does-not-face-the-same-problems-as-he-did-in-his-title-fight-with-the-mercedes-driver/',
#   'img': '...'}]

# %%
! pip install mwthesaurus
# Out:
# Collecting mwthesaurus
#   Downloading mwthesaurus-0.1.2-py3-none-any.whl (4.0 kB)
# Collecting httpx<0.14.0,>=0.13.0
#   Downloading httpx-0.13.3-py3-none-any.whl (55 kB)
#      |████████████████████████████████| 55 kB 680 kB/s  eta 0:00:01
# Requirement already satisfied: certifi in /home/barzamini/.pyenv/versions/3.7.6/lib/python3.7/site-packages (from httpx<0.14.0,>=0.13.0->mwthesaurus) (2021.10.8)
# Collecting chardet==3.*
#   Using cached chardet-3.0.4-py2.py3-none-any.whl (133 kB)
# Collecting httpcore==0.9.*
#   Downloading httpcore-0.9.1-py3-none-any.whl (42 kB)
#      |████████████████████████████████| 42 kB 193 kB/s  eta 0:00:01
# Collecting h2==3.*
#   Downloading h2-3.2.0-py2.py3-none-any.whl (65 kB)
#      |████████████████████████████████| 65 kB 730 kB/s  eta 0:00:01
# Collecting idna==2.*
#   Using cached idna-2.10-py2.py3-none-any.whl (58 kB)
# Collecting sniffio
#   Downloading sniffio-1.2.0-py3-none-any.whl (10 kB)
# Collecting h11<0.10,>=0.8
#   Downloading h11-0.9.0-py2.py3-none-any.whl (53 kB)
#      |████████████████████████████████| 53 kB 782 kB/s  eta 0:00:01
# Collecting hpack<4,>=3.0
#   Downloading hpack-3.0.0-py2.py3-none-any.whl (38 kB)
# Collecting hyperframe<6,>=5.2.0
#   Downloading hyperframe-5.2.0-py2.py3-none-any.whl (12 kB)
# Collecting rfc3986<2,>=1.3
#   Downloading rfc3986-1.5.0-py2.py3-none-any.whl (31 kB)
# Collecting hstspreload
#   Downloading hstspreload-2021.10.1-py3-none-any.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 61.5 MB/s eta 0:00:01
# Installing collected packages: hyperframe, hpack, sniffio, h2, h11, rfc3986, idna, httpcore, hstspreload, chardet, httpx, mwthesaurus
#   Attempting uninstall: idna
#     Found existing installation: idna 3.3
#     Uninstalling idna-3.3:
#       Successfully uninstalled idna-3.3
# Successfully installed chardet-3.0.4 h11-0.9.0 h2-3.2.0 hpack-3.0.0 hstspreload-2021.10.1 httpcore-0.9.1 httpx-0.13.3 hyperframe-5.2.0 idna-2.10 mwthesaurus-0.1.2 rfc3986-1.5.0 sniffio-1.2.0
# WARNING: You are using pip version 20.3.3; however, version 21.3 is available.
# You should consider upgrading via the '/home/barzamini/.pyenv/versions/3.7.6/bin/python3.7 -m pip install --upgrade pip' command.

# %%
from mwthesaurus import MWClient
client = MWClient(key="ede6968f-710a-48f5-b91d-79acf2960001")
# client.get("python")

# %%
client.get("python")
# Out:
# [Word(word='python', wordtype='noun', shortdef=['as in anaconda, boa'], synonyms=['adder', 'anaconda', 'asp', 'black racer', 'blacksnake', 'blue racer', 'boa', 'bull snake', 'bushmaster', 'chicken snake', 'cobra', 'constrictor', 'copperhead', 'coral snake', 'cottonmouth moccasin', 'diamondback rattlesnake', 'fer-de-lance', 'garter snake', 'gopher snake', 'green snake', 'hognose snake', 'horned viper', 'indigo snake', 'king cobra', 'king snake', 'krait', 'mamba', 'milk snake', 'moccasin', 'pine snake', 'pit viper', 'puff adder', 'racer', 'rat snake', 'rattlesnake', 'sea serpent', 'sea snake', 'sidewinder', 'taipan', 'water moccasin', 'water snake', 'worm snake', 'serpent', 'snake', 'viper'], antonyms=[], stems=['python'])]

# %%
key = "5b7622e5-5fe6-4429-b1c0-53a2edce4d1a"
word = "car"
d_key = "c7cad8a9-82f4-494e-8e76-dfaebc7ce8c6" 
ith_url_req = f"https://dictionaryapi.com/api/v3/references/ithesaurus/json/{word}?key={key}"
itdict_url = f"https://dictionaryapi.com/api/v3/references/sd3/json/{word}?key={d_key}"

# %%
import requests
from requests.exceptions import HTTPError

try:
    response = requests.get(itdict_url)
    response.raise_for_status()
    # access JSOn content
    jsonResponse = response.json()
    print("Entire JSON response")
    print(jsonResponse)

except HTTPError as http_err:
    print(f'HTTP error occurred: {http_err}')
except Exception as err:
    print(f'Other error occurred: {err}')
# Out:
# Entire JSON response
# [{'meta': {'id': 'car', 'uuid': '17a426a7-f27a-4052-bc72-da2bb8f863c0', 'src': 'int_dict', 'section': 'alpha', 'stems': ['car', 'cars'], 'offensive': False}, 'hwi': {'hw': 'car', 'prs': [{'mw': 'ˈkär', 'sound': {'audio': 'car00001'}}]}, 'fl': 'noun', 'def': [{'sseq': [[['sense', {'sn': '1', 'dt': [['text', '{bc}a vehicle (as an automobile or part of a passenger train) moving on wheels']]}]], [['sense', {'sn': '2', 'dt': [['text', '{bc}the passenger compartment of an elevator']]}]], [['sense', {'sn': '3', 'dt': [['text', '{bc}the part of a balloon or an airship that carries the passengers and equipment']]}]]]}], 'shortdef': ['a vehicle (as an automobile or part of a passenger train) moving on wheels', 'the passenger compartment of an elevator', 'the part of a balloon or an airship that carries the passengers and equipment']}, {'meta': {'id': 'car pool', 'uuid': 'e33d1592-8fac-4f0d-ab97-5cf4192443fa', 'src': 'int_dict', 'section': 'alpha', 'stems': ['car pool', 'car pools', 'carpool', 'carpooler'], 'offensive': False}, 'hwi': {'hw': 'car pool'}, 'fl': 'noun', 'def': [{'sseq': [[['sense', {'dt': [['text', '{bc}an arrangement by a group of automobile owners in which each in turn drives his or her own car and carries the others as passengers usually to and from work']]}]]]}], 'uros': [{'ure': 'car*pool', 'prs': [{'mw': 'ˈkär-ˌpül'}], 'fl': 'verb'}, {'ure': 'car*pool*er', 'fl': 'noun'}], 'shortdef': ['an arrangement by a group of automobile owners in which each in turn drives his or her own car and carries the others as passengers usually to and from work']}, {'meta': {'id': 'car seat', 'uuid': '0c40c885-f373-43fd-8fff-f26b3b681626', 'src': 'int_dict', 'section': 'alpha', 'stems': ['car seat', 'car seats'], 'offensive': False}, 'hwi': {'hw': 'car seat'}, 'fl': 'noun', 'def': [{'sseq': [[['sense', {'dt': [['text', '{bc}a portable seat for an infant or a small child that attaches to an automobile seat and holds the child safely']]}]]]}], 'shortdef': ['a portable seat for an infant or a small child that attaches to an automobile seat and holds the child safely']}, {'meta': {'id': 'bumper car', 'uuid': 'a2eb3597-44db-4b87-a9b5-8d910ffe4c74', 'src': 'int_dict', 'section': 'alpha', 'stems': ['bumper car', 'bumper cars'], 'offensive': False}, 'hwi': {'hw': 'bumper car'}, 'fl': 'noun', 'def': [{'sseq': [[['sense', {'dt': [['text', '{bc}a small electric car made to be driven around in an enclosure and to be bumped into others (as in an amusement park)']]}]]]}], 'shortdef': ['a small electric car made to be driven around in an enclosure and to be bumped into others (as in an amusement park)']}, {'meta': {'id': 'cable car', 'uuid': '09eb2c17-a53a-4a72-bb1b-b2e3cd151f52', 'src': 'int_dict', 'section': 'alpha', 'stems': ['cable car', 'cable cars'], 'offensive': False}, 'hwi': {'hw': 'cable car'}, 'fl': 'noun', 'def': [{'sseq': [[['sense', {'dt': [['text', '{bc}a car moved on tracks by an endless cable or along an overhead cable']]}]]]}], 'shortdef': ['a car moved on tracks by an endless cable or along an overhead cable']}, {'meta': {'id': 'dining car', 'uuid': '2a192b86-0f2a-401b-8ebf-cee02df8ae57', 'src': 'int_dict', 'section': 'alpha', 'stems': ['dining car', 'dining cars'], 'offensive': False}, 'hwi': {'hw': 'din*ing car', 'prs': [{'mw': 'ˈdī-niŋ-'}]}, 'fl': 'noun', 'def': [{'sseq': [[['sense', {'dt': [['text', '{bc}a railroad car in which meals are served']]}]]]}], 'shortdef': ['a railroad car in which meals are served']}, {'meta': {'id': 'prowl car', 'uuid': '616aecce-3761-4b3d-9950-c36c5f1bfd61', 'src': 'int_dict', 'section': 'alpha', 'stems': ['prowl car', 'prowl cars'], 'offensive': False}, 'hwi': {'hw': 'prowl car'}, 'fl': 'noun', 'def': [{'sseq': [[['sense', {'dt': [['text', '{bc}{sx|squad car||}']]}]]]}], 'shortdef': ['squad car']}, {'meta': {'id': 'sleeping car', 'uuid': 'a5cd7059-791a-4cab-ae2e-b7e9cc11f9cf', 'src': 'int_dict', 'section': 'alpha', 'stems': ['sleeping car', 'sleeping cars'], 'offensive': False}, 'hwi': {'hw': 'sleepi ...

# %%
import requests
from requests.exceptions import HTTPError

try:
    response = requests.get(ith_url_req)
    response.raise_for_status()
    # access JSOn content
    jsonResponse = response.json()
    print("Entire JSON response")
    print(jsonResponse)

except HTTPError as http_err:
    print(f'HTTP error occurred: {http_err}')
except Exception as err:
    print(f'Other error occurred: {err}')
# Out:
# Entire JSON response
# [{'meta': {'id': 'car', 'uuid': '1f90bfb2-47ff-4d4a-be1b-90b1de7ef7e0', 'src': 'int_thes', 'section': 'alpha', 'target': {'tuuid': 'af66ae63-d0ad-40e4-8624-a24478037975', 'tsrc': 'collegiate'}, 'stems': ['car', 'cars'], 'syns': [['auto', 'automobile', 'machine', 'motor', 'motorcar', 'motor vehicle', 'wheels']], 'ants': [], 'offensive': False}, 'hwi': {'hw': 'car'}, 'fl': 'noun', 'def': [{'sseq': [[['sense', {'dt': [['text', 'a self-propelled passenger vehicle on wheels '], ['vis', [{'t': "every teenager's dream of getting a driver's license and a first {it}car{/it}"}]]], 'syn_list': [[{'wd': 'auto'}, {'wd': 'automobile'}, {'wd': 'machine'}, {'wd': 'motor'}, {'wd': 'motorcar'}, {'wd': 'motor vehicle'}, {'wd': 'wheels', 'wsls': ['slang']}]], 'rel_list': [[{'wd': 'bus'}, {'wd': 'coach'}, {'wd': 'minibus'}], [{'wd': 'beach buggy'}, {'wd': 'brougham'}, {'wd': 'compact'}, {'wd': 'convertible'}, {'wd': 'coupe'}, {'wd': 'dune buggy'}, {'wd': 'fastback'}, {'wd': 'gas-guzzler'}, {'wd': 'hardtop'}, {'wd': 'hatchback'}, {'wd': 'hot rod'}, {'wd': 'jeep'}, {'wd': 'limousine'}, {'wd': 'roadster'}, {'wd': 'sedan'}, {'wd': 'sports car'}, {'wd': 'station wagon'}, {'wd': 'stock car'}, {'wd': 'subcompact'}, {'wd': 'van'}], [{'wd': 'flivver'}, {'wd': 'jalopy'}]]}]]]}], 'shortdef': ['a self-propelled passenger vehicle on wheels']}, {'meta': {'id': 'motorcar', 'uuid': '77ac9345-eaee-4377-a350-9dcf160eabfe', 'src': 'int_thes', 'section': 'alpha', 'target': {'tuuid': 'b1370319-7ce8-484e-8548-95d486ca00f0', 'tsrc': 'collegiate'}, 'stems': ['motorcar', 'motor car', 'motor cars', 'motorcars'], 'syns': [['auto', 'automobile', 'car', 'machine', 'motor', 'motor vehicle', 'wheels']], 'ants': [], 'offensive': False}, 'hwi': {'hw': 'motorcar'}, 'fl': 'noun', 'def': [{'sseq': [[['sense', {'dt': [['text', 'a self-propelled passenger vehicle on wheels '], ['vis', [{'t': 'a convention for those who love antique {it}motorcars{/it}'}]]], 'syn_list': [[{'wd': 'auto'}, {'wd': 'automobile'}, {'wd': 'car'}, {'wd': 'machine'}, {'wd': 'motor'}, {'wd': 'motor vehicle'}, {'wd': 'wheels', 'wsls': ['slang']}]], 'rel_list': [[{'wd': 'bus'}, {'wd': 'coach'}, {'wd': 'minibus'}], [{'wd': 'beach buggy'}, {'wd': 'brougham'}, {'wd': 'compact'}, {'wd': 'convertible'}, {'wd': 'coupe'}, {'wd': 'dune buggy'}, {'wd': 'fastback'}, {'wd': 'gas-guzzler'}, {'wd': 'hardtop'}, {'wd': 'hatchback'}, {'wd': 'hot rod'}, {'wd': 'jeep'}, {'wd': 'limousine'}, {'wd': 'roadster'}, {'wd': 'sedan'}, {'wd': 'sports car'}, {'wd': 'station wagon'}, {'wd': 'stock car'}, {'wd': 'subcompact'}, {'wd': 'van'}], [{'wd': 'flivver'}, {'wd': 'jalopy'}]]}]]]}], 'shortdef': ['a self-propelled passenger vehicle on wheels']}, {'meta': {'id': 'saloon', 'uuid': 'b2481c7f-d1e4-4c95-ba3b-27f7247c7815', 'src': 'int_thes', 'section': 'alpha', 'target': {'tuuid': '86213a0d-ab81-4dd3-8d97-272a531cafb4', 'tsrc': 'collegiate'}, 'stems': ['saloon', 'saloon car', 'saloons'], 'syns': [['bar', 'barroom', 'café', 'groggery', 'grogshop', 'pub', 'public house', 'tavern']], 'ants': [], 'offensive': False}, 'hwi': {'hw': 'saloon'}, 'fl': 'noun', 'def': [{'sseq': [[['sense', {'dt': [['text', 'a place of business where alcoholic beverages are sold to be consumed on the premises '], ['vis', [{'t': 'cowboys drinking in the {it}saloon{/it} after their work was done for the day'}]]], 'syn_list': [[{'wd': 'bar'}, {'wd': 'barroom'}, {'wd': 'café', 'wvrs': [{'wvl': 'also', 'wva': 'cafe'}]}, {'wd': 'groggery'}, {'wd': 'grogshop'}, {'wd': 'pub'}, {'wd': 'public house', 'wsls': ['chiefly British']}, {'wd': 'tavern'}]], 'rel_list': [[{'wd': 'cabaret'}, {'wd': 'dive'}, {'wd': 'joint'}, {'wd': 'nightclub'}, {'wd': 'roadhouse'}, {'wd': 'speakeasy'}], [{'wd': 'package store'}]]}]]]}], 'shortdef': ['a place of business where alcoholic beverages are sold to be consumed on the premises']}]

# %%
! pip install google-api-python-client
# Out:
# Collecting google-api-python-client
#   Downloading google_api_python_client-2.27.0-py2.py3-none-any.whl (7.7 MB)
#      |████████████████████████████████| 7.7 MB 12.0 MB/s eta 0:00:01
# Collecting google-api-core<3.0.0dev,>=1.21.0
#   Downloading google_api_core-2.1.1-py2.py3-none-any.whl (95 kB)
#      |████████████████████████████████| 95 kB 939 kB/s  eta 0:00:01
# Requirement already satisfied: setuptools>=40.3.0 in /home/barzamini/.pyenv/versions/3.7.6/lib/python3.7/site-packages (from google-api-core<3.0.0dev,>=1.21.0->google-api-python-client) (41.2.0)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in /home/barzamini/.pyenv/versions/3.7.6/lib/python3.7/site-packages (from google-api-core<3.0.0dev,>=1.21.0->google-api-python-client) (2.26.0)
# Collecting google-auth<3.0.0dev,>=1.16.0
#   Downloading google_auth-2.3.1-py2.py3-none-any.whl (154 kB)
#      |████████████████████████████████| 154 kB 63.7 MB/s eta 0:00:01
# Requirement already satisfied: six>=1.9.0 in /home/barzamini/.pyenv/versions/3.7.6/lib/python3.7/site-packages (from google-auth<3.0.0dev,>=1.16.0->google-api-python-client) (1.15.0)
# Collecting cachetools<5.0,>=2.0.0
#   Downloading cachetools-4.2.4-py3-none-any.whl (10 kB)
# Collecting google-auth-httplib2>=0.1.0
#   Downloading google_auth_httplib2-0.1.0-py2.py3-none-any.whl (9.3 kB)
# Collecting googleapis-common-protos<2.0dev,>=1.6.0
#   Downloading googleapis_common_protos-1.53.0-py2.py3-none-any.whl (198 kB)
#      |████████████████████████████████| 198 kB 61.4 MB/s eta 0:00:01
# Collecting httplib2<1dev,>=0.15.0
#   Downloading httplib2-0.20.1-py3-none-any.whl (96 kB)
#      |████████████████████████████████| 96 kB 7.0 MB/s  eta 0:00:01
# Requirement already satisfied: pyparsing<3,>=2.4.2 in /home/barzamini/.pyenv/versions/3.7.6/lib/python3.7/site-packages (from httplib2<1dev,>=0.15.0->google-api-python-client) (2.4.7)
# Collecting protobuf>=3.12.0
#   Downloading protobuf-3.19.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 41.1 MB/s eta 0:00:01     |███████████▉                    | 389 kB 41.1 MB/s eta 0:00:01
# Collecting pyasn1-modules>=0.2.1
#   Using cached pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
# Collecting pyasn1<0.5.0,>=0.4.6
#   Using cached pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /home/barzamini/.pyenv/versions/3.7.6/lib/python3.7/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<3.0.0dev,>=1.21.0->google-api-python-client) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in /home/barzamini/.pyenv/versions/3.7.6/lib/python3.7/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<3.0.0dev,>=1.21.0->google-api-python-client) (2.10)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/barzamini/.pyenv/versions/3.7.6/lib/python3.7/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<3.0.0dev,>=1.21.0->google-api-python-client) (2.0.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/barzamini/.pyenv/versions/3.7.6/lib/python3.7/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<3.0.0dev,>=1.21.0->google-api-python-client) (1.26.7)
# Collecting rsa<5,>=3.1.4
#   Using cached rsa-4.7.2-py3-none-any.whl (34 kB)
# Collecting uritemplate<5,>=3.0.0
#   Downloading uritemplate-4.1.1-py2.py3-none-any.whl (10 kB)
# Installing collected packages: pyasn1, rsa, pyasn1-modules, protobuf, cachetools, httplib2, googleapis-common-protos, google-auth, uritemplate, google-auth-httplib2, google-api-core, google-api-python-client
# Successfully installed cachetools-4.2.4 google-api-core-2.1.1 google-api-python-client-2.27.0 google-auth-2.3.1 google-auth-httplib2-0.1.0 googleapis-common-protos-1.53.0 httplib2-0.20.1 protobuf-3.19.0 pyasn1-0.4.8 pyasn1-modules-0.2.8 rsa-4.7.2 uritemplate-4.1.1
# WARNING: You are using pip version 20.3.3; however, version 21.3 is available.
# You should consider upgrading via the '/home/barzamini/.pyenv/versions/3.7.6/bin/python3.7 -m pip install --upgrade pip' command.

# %%
! pip install bs4
# Out:
# Collecting bs4
#   Downloading bs4-0.0.1.tar.gz (1.1 kB)
# Requirement already satisfied: beautifulsoup4 in /home/barzamini/.pyenv/versions/3.7.6/lib/python3.7/site-packages (from bs4) (4.10.0)
# Requirement already satisfied: soupsieve>1.2 in /home/barzamini/.pyenv/versions/3.7.6/lib/python3.7/site-packages (from beautifulsoup4->bs4) (2.2.1)
# Using legacy 'setup.py install' for bs4, since package 'wheel' is not installed.
# Installing collected packages: bs4
#     Running setup.py install for bs4 ... done
# Successfully installed bs4-0.0.1
# WARNING: You are using pip version 20.3.3; however, version 21.3 is available.
# You should consider upgrading via the '/home/barzamini/.pyenv/versions/3.7.6/bin/python3.7 -m pip install --upgrade pip' command.

# %%
from googleapiclient.discovery import build   #Import the library
api_key = "AIzaSyD8oV9Vs8yjNPLAjWPe6emSZf1E865K7uY"
cse_id = "e714535f954174f5d"


def google_query(query, api_key, cse_id, **kwargs):
    query_service = build("customsearch", 
                          "v1", 
                          developerKey=api_key
                          )  
    query_results = query_service.cse().list(q=query,    # Query
                                             cx=cse_id,  # CSE ID
                                             **kwargs    
                                             ).execute()
    return query_results['items']


my_results_list = []
my_results = google_query("what is a car?",
                          api_key, 
                          cse_id, 
                          num = 10
                          )
for result in my_results:
    my_results_list.append(result['link'])
    print(result['link'])
# Out:
# https://en.wikipedia.org/wiki/Car
# https://www.merriam-webster.com/dictionary/car
# https://www.enterprise.com/en/home.html
# https://www.zipcar.com/
# https://turo.com/
# https://www.edmunds.com/appraisal/
# https://www.truecar.com/
# https://www.nationalcar.com/en/home.html
# https://www.consumerreports.org/buying-a-car/leasing-vs-buying-a-new-car-a9135602164/
# https://www.bankrate.com/loans/auto-loans/rates/

# %%
from googleapiclient.discovery import build   #Import the library
api_key = "AIzaSyD8oV9Vs8yjNPLAjWPe6emSZf1E865K7uY"
cse_id = "e714535f954174f5d"


def google_query(query, api_key, cse_id, **kwargs):
    query_service = build("customsearch", 
                          "v1", 
                          developerKey=api_key
                          )  
    query_results = query_service.cse().list(q=query,    # Query
                                             cx=cse_id,  # CSE ID
                                             **kwargs    
                                             ).execute()
    return query_results['items']


my_results_list = []
my_results = google_query("car",
                          api_key, 
                          cse_id, 
                          num = 10
                          )
for result in my_results:
    my_results_list.append(result['link'])
    print(result['link'])
# Out:
# https://en.wikipedia.org/wiki/Car
# https://en.wikipedia.org/wiki/Wiktionary:car
# https://en.wikipedia.org/wiki/Sports_car
# https://en.wikipedia.org/wiki/Car_rental
# https://en.wikipedia.org/wiki/C.a.R.
# https://en.wikipedia.org/wiki/Tesla,_Inc.
# https://en.wikipedia.org/wiki/Self-driving_car
# https://en.wikipedia.org/wiki/2013_Tiananmen_Square_attack
# https://en.wikipedia.org/wiki/Mitsuoka_Orochi
# https://en.wikipedia.org/wiki/Waymo

# %%
import requests
import json

# %%
# Other
starts = list(x for x in range(1,100,10))
res_dict_lsit = []
for start in starts :
    API_KEY = "AIzaSyD8oV9Vs8yjNPLAjWPe6emSZf1E865K7uY"
    SEARCH_ENGINE_ID = "e714535f954174f5d"
    
    query = "What is car?"
    
    url = f"https://www.googleapis.com/customsearch/v1?key={API_KEY}&cx={SEARCH_ENGINE_ID}&q={query}"
    
    params = {'num': 10, 'start': start}
    
    res = requests.get(url, params=params).json()
    
    res_dict_lsit.append(res)
    
#     print(json.dumps(res, indent=4, sort_keys=True))
#     break

# %%
for res in res_dict_lsit:
    try:
        items = res['items']
        for item in items:
            title = item['title']
            print(title)
            print(item['link'])
    except KeyError:
      print(json.dumps(res, indent=4, sort_keys=True))
# Out:
# About John Fuller | HowStuffWorks
# https://www.howstuffworks.com/about-john-fuller.htm
# Car Symbols
# https://www.symbols.com/group/99/Car+Symbols
# About Cherise Threewitt | HowStuffWorks
# https://www.howstuffworks.com/about-cherise-threewitt.htm
# What's so special about Route 66? | HowStuffWorks
# https://www.howstuffworks.com/route-66.htm
# HowStuffWorks - Learn How Everything Works!
# https://www.howstuffworks.com/
# Learn How Everything Works! - HowStuffWorks
# https://www.howstuffworks.com/?page=99&sort=date
# Striped Skunk media - Encyclopedia of Life
# https://eol.org/pages/328593/media?page=5
# Travelling for pleasure: a brief history of tourism | Europeana
# https://www.europeana.eu/en/blog/travelling-for-pleasure-a-brief-history-of-tourism
# Horse-Drawn Vehicle Ahead
# https://www.symbols.com/symbol/horse-drawn-vehicle-ahead
# Search for Asymmetric symbols — Page #9
# https://www.symbols.com/graphical-index.php?symmetry=2&shape=0&color=0&lines=0&crossing=0&p=9
# {
#     "error": {
#         "code": 429,
#         "details": [
#             {
#                 "@type": "type.googleapis.com/google.rpc.ErrorInfo",
#                 "domain": "googleapis.com",
#                 "metadata": {
#                     "consumer": "projects/952366977296",
#                     "quota_limit": "DefaultPerDayPerProject",
#                     "quota_metric": "customsearch.googleapis.com/requests",
#                     "service": "customsearch.googleapis.com"
#                 },
#                 "reason": "RATE_LIMIT_EXCEEDED"
#             }
#         ],
#         "errors": [
#             {
#                 "domain": "global",
#                 "message": "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:952366977296'.",
#                 "reason": "rateLimitExceeded"
#             }
#         ],
#         "message": "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:952366977296'.",
#         "status": "RESOURCE_EXHAUSTED"
#     }
# }
# Typhlonereis - Encyclopedia of Life
# https://eol.org/pages/3095700
# Hyperbionycidae - Encyclopedia of Life
# https://eol.org/pages/46534320
# Neodasyidae - Encyclopedia of Life
# https://eol.org/pages/8739
# Symbols by Alphabetical order: SP
# https://www.symbols.com/symbols/SP
# Dasydytidae - Encyclopedia of Life
# https://eol.org/pages/51892845
# Move to the water for the holidays | Europeana
# https://www.europeana.eu/en/item/2051906/data_euscreenXL_http___openbeelden_nl_media_1997
# unclassified Hexactinellida - Encyclopedia of Life
# https://eol.org/pages/52568252
# unclassified Pterobranchia - Encyclopedia of Life
# https://eol.org/pages/52572082
# Elachista media - Encyclopedia of Life
# https://eol.org/pages/34658/media
# Microcalanus - Encyclopedia of Life
# https://eol.org/pages/46532736
# Xenodasyidae - Encyclopedia of Life
# https://eol.org/pages/8745
# onion data - Encyclopedia of Life
# http://eol.org/pages/17858/data
# Argyrodiaptomus - Encyclopedia of Life
# https://eol.org/pages/4293408
# Redudasyidae - Encyclopedia of Life
# https://eol.org/pages/32146614
# Pseudopetalophthalmus - Encyclopedia of Life
# https://eol.org/pages/44781
# Ceratoporella - Encyclopedia of Life
# https://eol.org/pages/45319906
# Acartia (Acartia) nana Brady 1914 - Encyclopedia of Life
# https://eol.org/pages/45975708
# Brasilomysis - Encyclopedia of Life
# https://eol.org/pages/14361
# Opheodesoma - Encyclopedia of Life
# https://eol.org/pages/2984383
# Katamysis - Encyclopedia of Life
# https://eol.org/pages/39699
# {
#     "error": {
#         "code": 429,
#         "details": [
#             {
#                 "@type": "type.googleapis.com/google.rpc.ErrorInfo",
#                 "domain": "googleapis.com",
#                 "metadata": {
#                     "consumer": "projects/952366977296",
#                     "quota_limit": "DefaultPerDayPerProject",
#                     "quota_metric": "customsearch.googleapis.com/requests",
#                     "service": "customsearch.googleapis.com"
#                 },
#                 "reason": "RATE_LIMIT_EXCEEDED"
#             }
#         ],
#         "errors": [
#             {
#                 "domain": "global",
#                 "message": "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:952366977296'.",
#                 "reason": "rateLimitExceeded"
#             }
#         ],
#         "message": "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:952366977296'.",
#         "status": "RESOURCE_EXHAUSTED"
#     }
# }
# Pseudocyclops obtusatus Brady &amp; Robertson D. 1873
# https://eol.org/pages/46533600
# Parapetalophthalmus - Encyclopedia of Life
# https://eol.org/pages/14202
# Zenkevitchiella - Encyclopedia of Life
# https://eol.org/pages/46532521
# Parasarcophaga - Encyclopedia of Life
# https://eol.org/pages/55363
# Triopsidae data - Encyclopedia of Life
# https://eol.org/pages/6926/data
# Mermis nigrescens data - Encyclopedia of Life
# https://eol.org/pages/464696/data
# Hawksbill Sea Turtle data - Encyclopedia of Life
# https://eol.org/pages/46559472/data
# candyleaf media - Encyclopedia of Life
# https://eol.org/pages/483967/media?license_group=cc_by
# {
#     "error": {
#         "code": 429,
#         "details": [
#             {
#                 "@type": "type.googleapis.com/google.rpc.ErrorInfo",
#                 "domain": "googleapis.com",
#                 "metadata": {
#                     "consumer": "projects/952366977296",
#                     "quota_limit": "DefaultPerDayPerProject",
#                     "quota_metric": "customsearch.googleapis.com/requests",
#                     "service": "customsearch.googleapis.com"
#                 },
#                 "reason": "RATE_LIMIT_EXCEEDED"
#             }
#         ],
#         "errors": [
#             {
#                 "domain": "global",
#                 "message": "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:952366977296'.",
#                 "reason": "rateLimitExceeded"
#             }
#         ],
#         "message": "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:952366977296'.",
#         "status": "RESOURCE_EXHAUSTED"
#     }
# }
# {
#     "kind": "customsearch#search",
#     "queries": {
#         "previousPage": [
#             {
#                 "count": 10,
#                 "cx": "e714535f954174f5d",
#                 "inputEncoding": "utf8",
#                 "outputEncoding": "utf8",
#                 "safe": "off",
#                 "searchTerms": "What is car?",
#                 "startIndex": 61,
#                 "title": "Google Custom Search - What is car?"
#             }
#         ],
#         "request": [
#             {
#                 "count": 10,
#                 "cx": "e714535f954174f5d",
#                 "inputEncoding": "utf8",
#                 "outputEncoding": "utf8",
#                 "safe": "off",
#                 "searchTerms": "What is car?",
#                 "startIndex": 71,
#                 "title": "Google Custom Search - What is car?"
#             }
#         ]
#     },
#     "searchInformation": {
#         "formattedSearchTime": "0.52",
#         "formattedTotalResults": "0",
#         "searchTime": 0.518538,
#         "totalResults": "0"
#     },
#     "url": {
#         "template": "https://www.googleapis.com/customsearch/v1?q={searchTerms}&num={count?}&start={startIndex?}&lr={language?}&safe={safe?}&cx={cx?}&sort={sort?}&filter={filter?}&gl={gl?}&cr={cr?}&googlehost={googleHost?}&c2coff={disableCnTwTranslation?}&hq={hq?}&hl={hl?}&siteSearch={siteSearch?}&siteSearchFilter={siteSearchFilter?}&exactTerms={exactTerms?}&excludeTerms={excludeTerms?}&linkSite={linkSite?}&orTerms={orTerms?}&relatedSite={relatedSite?}&dateRestrict={dateRestrict?}&lowRange={lowRange?}&highRange={highRange?}&searchType={searchType}&fileType={fileType?}&rights={rights?}&imgSize={imgSize?}&imgType={imgType?}&imgColorType={imgColorType?}&imgDominantColor={imgDominantColor?}&alt=json",
#         "type": "application/json"
#     }
# }
# {
#     "kind": "customsearch#search",
#     "queries": {
#         "previousPage": [
#             {
#                 "count": 10,
#                 "cx": "e714535f954174f5d",
#                 "inputEncoding": "utf8",
#                 "outputEncoding": "utf8",
#                 "safe": "off",
#                 "searchTerms": "What is car?",
#                 "startIndex": 71,
#                 "title": "Google Custom Search - What is car?"
#             }
#         ],
#         "request": [
#             {
#                 "count": 10,
#                 "cx": "e714535f954174f5d",
#                 "inputEncoding": "utf8",
#                 "outputEncoding": "utf8",
#                 "safe": "off",
#                 "searchTerms": "What is car?",
#                 "startIndex": 81,
#                 "title": "Google Custom Search - What is car?"
#             }
#         ]
#     },
#     "searchInformation": {
#         "formattedSearchTime": "0.54",
#         "formattedTotalResults": "0",
#         "searchTime": 0.535936,
#         "totalResults": "0"
#     },
#     "url": {
#         "template": "https://www.googleapis.com/customsearch/v1?q={searchTerms}&num={count?}&start={startIndex?}&lr={language?}&safe={safe?}&cx={cx?}&sort={sort?}&filter={filter?}&gl={gl?}&cr={cr?}&googlehost={googleHost?}&c2coff={disableCnTwTranslation?}&hq={hq?}&hl={hl?}&siteSearch={siteSearch?}&siteSearchFilter={siteSearchFilter?}&exactTerms={exactTerms?}&excludeTerms={excludeTerms?}&linkSite={linkSite?}&orTerms={orTerms?}&relatedSite={relatedSite?}&dateRestrict={dateRestrict?}&lowRange={lowRange?}&highRange={highRange?}&searchType={searchType}&fileType={fileType?}&rights={rights?}&imgSize={imgSize?}&imgType={imgType?}&imgColorType={imgColorType?}&imgDominantColor={imgDominantColor?}&alt=json",
#         "type": "application/json"
#     }
# }
# {
#     "error": {
#         "code": 429,
#         "details": [
#             {
#                 "@type": "type.googleapis.com/google.rpc.ErrorInfo",
#                 "domain": "googleapis.com",
#                 "metadata": {
#                     "consumer": "projects/952366977296",
#                     "quota_limit": "DefaultPerDayPerProject",
#                     "quota_metric": "customsearch.googleapis.com/requests",
#                     "service": "customsearch.googleapis.com"
#                 },
#                 "reason": "RATE_LIMIT_EXCEEDED"
#             }
#         ],
#         "errors": [
#             {
#                 "domain": "global",
#                 "message": "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:952366977296'.",
#                 "reason": "rateLimitExceeded"
#             }
#         ],
#         "message": "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:952366977296'.",
#         "status": "RESOURCE_EXHAUSTED"
#     }
# }

# %%
# Britannica
starts = list(x for x in range(1,100,10))
res_dict_lsit = []
for start in starts :
    API_KEY = "AIzaSyD8oV9Vs8yjNPLAjWPe6emSZf1E865K7uY"
#     SEARCH_ENGINE_ID = "e714535f954174f5d"
    SEARCH_ENGINE_ID = "13581eb0fad555f88"
    
    query = "What is car?"
    
    url = f"https://www.googleapis.com/customsearch/v1?key={API_KEY}&cx={SEARCH_ENGINE_ID}&q={query}"
    
    params = {'num': 10, 'start': start}
    
    res = requests.get(url, params=params).json()
    
    res_dict_lsit.append(res)
    
#     print(json.dumps(res, indent=4, sort_keys=True))
#     break

# %%
for res in res_dict_lsit:
    try:
        items = res['items']
        for item in items:
            title = item['title']
            print(title)
            print(item['link'])
    except KeyError:
      print(json.dumps(res, indent=4, sort_keys=True))
# Out:
# automobile | Definition, History, Industry, Design, & Facts | Britannica
# https://www.britannica.com/technology/automobile
# automotive industry | History, Overview, Definition, Developments ...
# https://www.britannica.com/technology/automotive-industry
# Tesla, Inc. | History, Cars, Elon Musk, & Facts | Britannica
# https://www.britannica.com/topic/Tesla-Motors
# sleeping car | railroad vehicle | Britannica
# https://www.britannica.com/technology/sleeping-car
# elevator | vertical transport | Britannica
# https://www.britannica.com/technology/elevator-vertical-transport
# Stock car | freight car | Britannica
# https://www.britannica.com/technology/stock-car-freight-car
# cable car | transportation | Britannica
# https://www.britannica.com/technology/cable-car
# sports-car racing | Britannica
# https://www.britannica.com/sports/sports-car-racing
# dining car | railroad vehicle | Britannica
# https://www.britannica.com/technology/dining-car
# jaunting car | carriage | Britannica
# https://www.britannica.com/technology/jaunting-car
# tank car | railroad vehicle | Britannica
# https://www.britannica.com/technology/tank-car
# automobile racing | Britannica
# https://www.britannica.com/sports/automobile-racing
# speedometer | vehicle instrument | Britannica
# https://www.britannica.com/technology/speedometer
# What Is Jeremy Bentham's “Auto-Icon”? | Britannica
# https://www.britannica.com/story/what-is-jeremy-benthams-auto-icon
# Petrobras scandal | Summary, Explanation, & Operation Car Wash ...
# https://www.britannica.com/event/Petrobras-scandal
# streetcar | Facts, History, & Development | Britannica
# https://www.britannica.com/technology/streetcar
# Toyota Motor Corporation | History & Facts | Britannica
# https://www.britannica.com/topic/Toyota-Motor-Corporation
# mass production - The mass production of automobiles | Britannica
# https://www.britannica.com/technology/mass-production/The-mass-production-of-automobiles
# Separate Car Act | Louisiana, United States [1890] | Britannica
# https://www.britannica.com/topic/Separate-Car-Act
# automobile club | Britannica
# https://www.britannica.com/topic/automobile-club
# tenor and vehicle | literature | Britannica
# https://www.britannica.com/art/tenor-literature
# emission control system | Description, Components, & Facts ...
# https://www.britannica.com/technology/emission-control-system
# locomotive | vehicle | Britannica
# https://www.britannica.com/technology/locomotive-vehicle
# Karl Friedrich Benz | Biography, Facts, Automobile, & Mercedes ...
# https://www.britannica.com/biography/Karl-Benz
# Ford Motor Company | History, Headquarters, & Facts | Britannica
# https://www.britannica.com/topic/Ford-Motor-Company
# Crash | Plot, Cast, Awards, & Facts | Britannica
# https://www.britannica.com/topic/Crash-film-by-Haggis
# sports car | Britannica
# https://www.britannica.com/technology/sports-car
# auto-da-fé | public ceremony | Britannica
# https://www.britannica.com/topic/auto-da-fe
# motor vehicle insurance | Britannica
# https://www.britannica.com/topic/motor-vehicle-insurance
# Volkswagen Group | Overview, History, & Facts | Britannica
# https://www.britannica.com/topic/Volkswagen-Group
# Model T | Description & Facts | Britannica
# https://www.britannica.com/technology/Model-T
# vehicular safety devices | Britannica
# https://www.britannica.com/technology/vehicular-safety-devices
# Brotherhood of Sleeping Car Porters | American labour union ...
# https://www.britannica.com/topic/Brotherhood-of-Sleeping-Car-Porters
# chariot | vehicle | Britannica
# https://www.britannica.com/technology/chariot
# Indianapolis 500 | Cars, Winners, History, & Facts | Britannica
# https://www.britannica.com/sports/Indianapolis-500
# coach | railroad vehicle | Britannica
# https://www.britannica.com/technology/coach-railroad-vehicle
# four-stroke cycle | engineering | Britannica
# https://www.britannica.com/technology/four-stroke-cycle
# automobile - History of the automobile | Britannica
# https://www.britannica.com/technology/automobile/History-of-the-automobile
# tractor | Definition, History, Types, Examples, & Facts | Britannica
# https://www.britannica.com/technology/tractor-vehicle
# Pullman Strike | Causes, Result, Summary, & Significance | Britannica
# https://www.britannica.com/event/Pullman-Strike
# How did Albert Camus die? | Britannica
# https://www.britannica.com/story/how-did-albert-camus-die
# bus | vehicle | Britannica
# https://www.britannica.com/technology/bus-vehicle
# What's the Difference Between Speed and Velocity? | Britannica
# https://www.britannica.com/story/whats-the-difference-between-speed-and-velocity
# drag racing | motor sport | Britannica
# https://www.britannica.com/sports/drag-racing
# launch vehicle - How a launch vehicle works | Britannica
# https://www.britannica.com/technology/launch-vehicle/How-a-launch-vehicle-works
# Honda Motor Company, Ltd. | Japanese corporation | Britannica
# https://www.britannica.com/topic/Honda-Motor-Company-Ltd
# Henry Ford | Biography, Education, Inventions, & Facts | Britannica
# https://www.britannica.com/biography/Henry-Ford
# boxcar | Britannica
# https://www.britannica.com/technology/boxcar
# Lewis Hamilton | Biography, Titles, & Facts | Britannica
# https://www.britannica.com/biography/Lewis-Hamilton
# flatcar | railroad vehicle | Britannica
# https://www.britannica.com/technology/flatcar
# PSA Group | History, Deals, & Facts | Britannica
# https://www.britannica.com/topic/PSA-Peugeot-Citroen-SA
# Citizens' Committee to Test the Constitutionality of the Separate Car ...
# https://www.britannica.com/topic/Citizens-Committee-to-Test-the-Constitutionality-of-the-Separate-Car-Law
# Daimler AG | international automotive company | Britannica
# https://www.britannica.com/topic/Daimler-AG
# National Traffic and Motor Vehicle Safety Act | United States [1966 ...
# https://www.britannica.com/topic/National-Traffic-and-Motor-Vehicle-Safety-Act
# automobile suspension | Britannica
# https://www.britannica.com/technology/automobile-suspension
# George M. Pullman | Biography, Accomplishments, Invention ...
# https://www.britannica.com/biography/George-M-Pullman
# Michael Schumacher | Biography, Wins, Championships, & Facts ...
# https://www.britannica.com/biography/Michael-Schumacher
# rally | automobile racing | Britannica
# https://www.britannica.com/sports/rally-automobile-racing
# flatcar | railroad vehicle | Britannica
# https://www.britannica.com/technology/flatcar
# automobile racing - American, European, and international racing ...
# https://www.britannica.com/sports/automobile-racing/American-European-and-international-racing
# automobile racing - American, European, and international racing ...
# https://www.britannica.com/sports/automobile-racing/American-European-and-international-racing
# Driving Miss Daisy | Plot, Cast, Awards, & Facts | Britannica
# https://www.britannica.com/topic/Driving-Miss-Daisy-film-by-Beresford
# rally | automobile racing | Britannica
# https://www.britannica.com/sports/rally-automobile-racing
# launch vehicle | Types & Definition | Britannica
# https://www.britannica.com/technology/launch-vehicle
# sulky | vehicle | Britannica
# https://www.britannica.com/technology/sulky
# jeep | Definition, History, & Facts | Britannica
# https://www.britannica.com/technology/jeep
# mass transit | Definition, History, Systems, Examples, & Facts ...
# https://www.britannica.com/topic/mass-transit
# mass transit - The automobile and mass transportation | Britannica
# https://www.britannica.com/topic/mass-transit/The-automobile-and-mass-transportation
# Rolls-Royce PLC | British firm | Britannica
# https://www.britannica.com/topic/Rolls-Royce-PLC
# Edsel | automobile | Britannica
# https://www.britannica.com/technology/Edsel
# automotive ceramics | Britannica
# https://www.britannica.com/technology/automotive-ceramics
# electrical system | vehicle | Britannica
# https://www.britannica.com/technology/electrical-system
# Edsel | automobile | Britannica
# https://www.britannica.com/technology/Edsel
# jeep | Definition, History, & Facts | Britannica
# https://www.britannica.com/technology/jeep
# Plessy v. Ferguson | Summary, Ruling, Background, & Impact ...
# https://www.britannica.com/event/Plessy-v-Ferguson-1896
# torsion bar | mechanics | Britannica
# https://www.britannica.com/technology/torsion-bar
# hot rod | car | Britannica
# https://www.britannica.com/sports/hot-rod
# Pullman sleeper | railroad car | Britannica
# https://www.britannica.com/technology/Pullman-sleeper
# unmanned aerial vehicle | Definition, History, Types, & Facts ...
# https://www.britannica.com/technology/unmanned-aerial-vehicle
# Chrysler | American company | Britannica
# https://www.britannica.com/topic/Chrysler
# {
#     "error": {
#         "code": 429,
#         "details": [
#             {
#                 "@type": "type.googleapis.com/google.rpc.ErrorInfo",
#                 "domain": "googleapis.com",
#                 "metadata": {
#                     "consumer": "projects/952366977296",
#                     "quota_limit": "DefaultPerDayPerProject",
#                     "quota_metric": "customsearch.googleapis.com/requests",
#                     "service": "customsearch.googleapis.com"
#                 },
#                 "reason": "RATE_LIMIT_EXCEEDED"
#             }
#         ],
#         "errors": [
#             {
#                 "domain": "global",
#                 "message": "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:952366977296'.",
#                 "reason": "rateLimitExceeded"
#             }
#         ],
#         "message": "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:952366977296'.",
#         "status": "RESOURCE_EXHAUSTED"
#     }
# }
# automobile - Ford and the automotive revolution | Britannica
# https://www.britannica.com/technology/automobile/Ford-and-the-automotive-revolution
# tumbrel | wagon | Britannica
# https://www.britannica.com/technology/tumbrel
# automobile - Tires | Britannica
# https://www.britannica.com/technology/automobile/Tires
# Étienne Lenoir | Belgian inventor | Britannica
# https://www.britannica.com/biography/Etienne-Lenoir
# automobile - Emission controls | Britannica
# https://www.britannica.com/technology/automobile/Emission-controls
# Homer Plessy | American shoemaker | Britannica
# https://www.britannica.com/biography/Homer-Plessy
# electrical system | vehicle | Britannica
# https://www.britannica.com/technology/electrical-system
# armoured vehicle | Britannica
# https://www.britannica.com/technology/armoured-vehicle
# stock-car racing | sport | Britannica
# https://www.britannica.com/sports/stock-car-racing
# NASCAR | sports organization | Britannica
# https://www.britannica.com/sports/NASCAR

# %%
# wikipedia
starts = list(x for x in range(1,100,10))
res_dict_lsit = []
for start in starts :
    API_KEY = "AIzaSyD8oV9Vs8yjNPLAjWPe6emSZf1E865K7uY"
    SEARCH_ENGINE_ID = "c05384d3c7df544cd"
    
    query = "What is car?"
    
    url = f"https://www.googleapis.com/customsearch/v1?key={API_KEY}&cx={SEARCH_ENGINE_ID}&q={query}"
    
    params = {'num': 10, 'start': start}
    
    res = requests.get(url, params=params).json()
    
    res_dict_lsit.append(res)

# %%
for res in res_dict_lsit:
    try:
        items = res['items']
        for item in items:
            title = item['title']
#             if 'Wikipedia' not in title:
            print(title)
    except KeyError:
      print(json.dumps(res, indent=4, sort_keys=True))
# Out:
# Car - Wikipedia
# Automotive industry - Wikipedia
# Auto racing - Wikipedia
# Carsharing - Wikipedia
# Car rental - Wikipedia
# Traffic collision - Wikipedia
# Vehicle insurance - Wikipedia
# Vehicle - Wikipedia
# Car dealership - Wikipedia
# Automotive battery - Wikipedia
# Car platform - Wikipedia
# In-car entertainment - Wikipedia
# Car wash - Wikipedia
# Car tuning - Wikipedia
# Chimeric antigen receptor T cell - Wikipedia
# Vehicle audio - Wikipedia
# Electric car - Wikipedia
# Motor vehicle - Wikipedia
# Car Talk - Wikipedia
# Vehicle leasing - Wikipedia
# Automotive design - Wikipedia
# Central African Republic - Wikipedia
# Car club - Wikipedia
# Car bomb - Wikipedia
# Vehicle title - Wikipedia
# Car seat - Wikipedia
# The Car - Wikipedia
# CAR-15 - Wikipedia
# Presidential state car (United States) - Wikipedia
# Car and Driver - Wikipedia
# Car classification - Wikipedia
# Car Wash (song) - Wikipedia
# Vehicle insurance in the United States - Wikipedia
# Auto detailing - Wikipedia
# Car suspension - Wikipedia
# Car spotting - Wikipedia
# Car Seat Headrest - Wikipedia
# Kit car - Wikipedia
# Vehicle inspection - Wikipedia
# Car phone - Wikipedia
# Irish Car Bomb - Wikipedia
# Automotive paint - Wikipedia
# Auto show - Wikipedia
# Vehicle recycling - Wikipedia
# Operation Car Wash - Wikipedia
# Trunk (car) - Wikipedia
# Immobiliser - Wikipedia
# Tire - Wikipedia
# Auto mechanic - Wikipedia
# Car spotting - Wikipedia
# Car spotting - Wikipedia
# Vehicle frame - Wikipedia
# Car Radio (song) - Wikipedia
# Sports car racing - Wikipedia
# Spoiler (car) - Wikipedia
# Automotive head unit - Wikipedia
# Automobile auxiliary power outlet - Wikipedia
# Vehicle weight - Wikipedia
# Crossover (automobile) - Wikipedia
# Parking lot - Wikipedia
# Lemon (automobile) - Wikipedia
# Sports car - Wikipedia
# List of auto parts - Wikipedia
# Automatic transmission - Wikipedia
# Car door - Wikipedia
# Car chase - Wikipedia
# Cars 2 - Wikipedia
# Sport utility vehicle - Wikipedia
# Car boot sale - Wikipedia
# Cars (film) - Wikipedia
# Car ownership - Wikipedia
# Cars (film) - Wikipedia
# Airbag - Wikipedia
# Sedan (automobile) - Wikipedia
# Automobile repair shop - Wikipedia
# Cars 3 - Wikipedia
# Self-driving car - Wikipedia
# Chrysler K platform - Wikipedia
# Car crusher - Wikipedia
# Car layout - Wikipedia
# Car boot - Wikipedia
# Jack (device) - Wikipedia
# Van - Wikipedia
# Dashboard - Wikipedia
# Catalytic converter - Wikipedia
# Car SOS - Wikipedia
# KITT - Wikipedia
# Service (motor vehicle) - Wikipedia
# Vehicle tracking system - Wikipedia
# Motor vehicle registration - Wikipedia
# Vehicle licence - Wikipedia
# Catalytic converter - Wikipedia
# Jump start (vehicle) - Wikipedia
# KITT - Wikipedia
# Model year - Wikipedia
# Car 54, Where Are You? - Wikipedia
# Bumper (car) - Wikipedia
# Chitty Chitty Bang Bang (car) - Wikipedia
# Hood (car) - Wikipedia
# Car door - Wikipedia

# %%
# Credo
starts = list(x for x in range(1,100,10))
res_dict_lsit = []
for start in starts :
    API_KEY = "AIzaSyD8oV9Vs8yjNPLAjWPe6emSZf1E865K7uY"
    SEARCH_ENGINE_ID = "5d8fe349f2e7066a7"
    
    query = "car"
    
    url = f"https://www.googleapis.com/customsearch/v1?key={API_KEY}&cx={SEARCH_ENGINE_ID}&q={query}"
    
    params = {'num': 10, 'start': start}
    
    res = requests.get(url, params=params).json()
    
    res_dict_lsit.append(res)
    
#     print(json.dumps(res, indent=4, sort_keys=True))
#     break

# %%
for res in res_dict_lsit:
    try:
        items = res['items']
        for item in items:
            title = item['title']
            print(title)
            print(item['link'])
    except KeyError:
      print(json.dumps(res, indent=4, sort_keys=True))
# Out:
# https://search.credoreference.com/usage_logging/target?url=http%3A%2F%2Fwww.notulaebotanicae.ro%2Findex.php%2Fnbha%2Farticle%2Fview%2F10298&id=public.doaj&access_token=42a5c72f82898da1059873844ee49d9a
# https://search.credoreference.com/usage_logging/target?url=http%3A%2F%2Fwww.bbc.co.uk%2Fnews%2Fuk-scotland-north-east-orkney-shetland-38378087&id=public.bbcnews&access_token=0a0eed238da34adb3783622cc6f678ac
# http://search.credoreference.com/usage_logging/target?url=http%3A%2F%2Fnews.bbc.co.uk%2F1%2Fhi%2Fengland%2F2667675.stm&id=public.bbcnews&access_token=2aec114ff4954020de5694da2eca69ae
# https://search.credoreference.com/usage_logging/target?url=http%3A%2F%2Fwww.bbc.co.uk%2Fnews%2Fworld-europe-37812906&id=public.bbcnews&access_token=0a0eed238da34adb3783622cc6f678ac
# https://search.credoreference.com/usage_logging/target?url=http%3A%2F%2Fwww.bbc.co.uk%2Fnews%2Fworld-asia-38499188&id=public.bbcnews&access_token=6edf86696715c01750934a4fa6555be4
# http://search.credoreference.com/usage_logging/target?url=http%3A%2F%2Fwww.cafyd.com%2FREVISTA%2Feditorial38.pdf&id=public.doaj&access_token=285d000d57ebe5933d2c7329a5771a15
# https://search.credoreference.com/usage_logging/target?url=http%3A%2F%2Fwww.bbc.co.uk%2Fnews%2Fscience-environment-38146250&id=public.bbcnews&access_token=997e9d47f7bbc2f02c12074b44304228
# {
#     "kind": "customsearch#search",
#     "queries": {
#         "previousPage": [
#             {
#                 "count": 10,
#                 "cx": "5d8fe349f2e7066a7",
#                 "inputEncoding": "utf8",
#                 "outputEncoding": "utf8",
#                 "safe": "off",
#                 "searchTerms": "car",
#                 "startIndex": 1,
#                 "title": "Google Custom Search - car"
#             }
#         ],
#         "request": [
#             {
#                 "count": 10,
#                 "cx": "5d8fe349f2e7066a7",
#                 "inputEncoding": "utf8",
#                 "outputEncoding": "utf8",
#                 "safe": "off",
#                 "searchTerms": "car",
#                 "startIndex": 11,
#                 "title": "Google Custom Search - car"
#             }
#         ]
#     },
#     "searchInformation": {
#         "formattedSearchTime": "0.18",
#         "formattedTotalResults": "0",
#         "searchTime": 0.181166,
#         "totalResults": "0"
#     },
#     "url": {
#         "template": "https://www.googleapis.com/customsearch/v1?q={searchTerms}&num={count?}&start={startIndex?}&lr={language?}&safe={safe?}&cx={cx?}&sort={sort?}&filter={filter?}&gl={gl?}&cr={cr?}&googlehost={googleHost?}&c2coff={disableCnTwTranslation?}&hq={hq?}&hl={hl?}&siteSearch={siteSearch?}&siteSearchFilter={siteSearchFilter?}&exactTerms={exactTerms?}&excludeTerms={excludeTerms?}&linkSite={linkSite?}&orTerms={orTerms?}&relatedSite={relatedSite?}&dateRestrict={dateRestrict?}&lowRange={lowRange?}&highRange={highRange?}&searchType={searchType}&fileType={fileType?}&rights={rights?}&imgSize={imgSize?}&imgType={imgType?}&imgColorType={imgColorType?}&imgDominantColor={imgDominantColor?}&alt=json",
#         "type": "application/json"
#     }
# }
# {
#     "kind": "customsearch#search",
#     "queries": {
#         "previousPage": [
#             {
#                 "count": 10,
#                 "cx": "5d8fe349f2e7066a7",
#                 "inputEncoding": "utf8",
#                 "outputEncoding": "utf8",
#                 "safe": "off",
#                 "searchTerms": "car",
#                 "startIndex": 11,
#                 "title": "Google Custom Search - car"
#             }
#         ],
#         "request": [
#             {
#                 "count": 10,
#                 "cx": "5d8fe349f2e7066a7",
#                 "inputEncoding": "utf8",
#                 "outputEncoding": "utf8",
#                 "safe": "off",
#                 "searchTerms": "car",
#                 "startIndex": 21,
#                 "title": "Google Custom Search - car"
#             }
#         ]
#     },
#     "searchInformation": {
#         "formattedSearchTime": "0.20",
#         "formattedTotalResults": "0",
#         "searchTime": 0.196978,
#         "totalResults": "0"
#     },
#     "url": {
#         "template": "https://www.googleapis.com/customsearch/v1?q={searchTerms}&num={count?}&start={startIndex?}&lr={language?}&safe={safe?}&cx={cx?}&sort={sort?}&filter={filter?}&gl={gl?}&cr={cr?}&googlehost={googleHost?}&c2coff={disableCnTwTranslation?}&hq={hq?}&hl={hl?}&siteSearch={siteSearch?}&siteSearchFilter={siteSearchFilter?}&exactTerms={exactTerms?}&excludeTerms={excludeTerms?}&linkSite={linkSite?}&orTerms={orTerms?}&relatedSite={relatedSite?}&dateRestrict={dateRestrict?}&lowRange={lowRange?}&highRange={highRange?}&searchType={searchType}&fileType={fileType?}&rights={rights?}&imgSize={imgSize?}&imgType={imgType?}&imgColorType={imgColorType?}&imgDominantColor={imgDominantColor?}&alt=json",
#         "type": "application/json"
#     }
# }
# {
#     "kind": "customsearch#search",
#     "queries": {
#         "previousPage": [
#             {
#                 "count": 10,
#                 "cx": "5d8fe349f2e7066a7",
#                 "inputEncoding": "utf8",
#                 "outputEncoding": "utf8",
#                 "safe": "off",
#                 "searchTerms": "car",
#                 "startIndex": 21,
#                 "title": "Google Custom Search - car"
#             }
#         ],
#         "request": [
#             {
#                 "count": 10,
#                 "cx": "5d8fe349f2e7066a7",
#                 "inputEncoding": "utf8",
#                 "outputEncoding": "utf8",
#                 "safe": "off",
#                 "searchTerms": "car",
#                 "startIndex": 31,
#                 "title": "Google Custom Search - car"
#             }
#         ]
#     },
#     "searchInformation": {
#         "formattedSearchTime": "0.14",
#         "formattedTotalResults": "0",
#         "searchTime": 0.141729,
#         "totalResults": "0"
#     },
#     "url": {
#         "template": "https://www.googleapis.com/customsearch/v1?q={searchTerms}&num={count?}&start={startIndex?}&lr={language?}&safe={safe?}&cx={cx?}&sort={sort?}&filter={filter?}&gl={gl?}&cr={cr?}&googlehost={googleHost?}&c2coff={disableCnTwTranslation?}&hq={hq?}&hl={hl?}&siteSearch={siteSearch?}&siteSearchFilter={siteSearchFilter?}&exactTerms={exactTerms?}&excludeTerms={excludeTerms?}&linkSite={linkSite?}&orTerms={orTerms?}&relatedSite={relatedSite?}&dateRestrict={dateRestrict?}&lowRange={lowRange?}&highRange={highRange?}&searchType={searchType}&fileType={fileType?}&rights={rights?}&imgSize={imgSize?}&imgType={imgType?}&imgColorType={imgColorType?}&imgDominantColor={imgDominantColor?}&alt=json",
#         "type": "application/json"
#     }
# }
# {
#     "kind": "customsearch#search",
#     "queries": {
#         "previousPage": [
#             {
#                 "count": 10,
#                 "cx": "5d8fe349f2e7066a7",
#                 "inputEncoding": "utf8",
#                 "outputEncoding": "utf8",
#                 "safe": "off",
#                 "searchTerms": "car",
#                 "startIndex": 31,
#                 "title": "Google Custom Search - car"
#             }
#         ],
#         "request": [
#             {
#                 "count": 10,
#                 "cx": "5d8fe349f2e7066a7",
#                 "inputEncoding": "utf8",
#                 "outputEncoding": "utf8",
#                 "safe": "off",
#                 "searchTerms": "car",
#                 "startIndex": 41,
#                 "title": "Google Custom Search - car"
#             }
#         ]
#     },
#     "searchInformation": {
#         "formattedSearchTime": "0.16",
#         "formattedTotalResults": "0",
#         "searchTime": 0.156273,
#         "totalResults": "0"
#     },
#     "url": {
#         "template": "https://www.googleapis.com/customsearch/v1?q={searchTerms}&num={count?}&start={startIndex?}&lr={language?}&safe={safe?}&cx={cx?}&sort={sort?}&filter={filter?}&gl={gl?}&cr={cr?}&googlehost={googleHost?}&c2coff={disableCnTwTranslation?}&hq={hq?}&hl={hl?}&siteSearch={siteSearch?}&siteSearchFilter={siteSearchFilter?}&exactTerms={exactTerms?}&excludeTerms={excludeTerms?}&linkSite={linkSite?}&orTerms={orTerms?}&relatedSite={relatedSite?}&dateRestrict={dateRestrict?}&lowRange={lowRange?}&highRange={highRange?}&searchType={searchType}&fileType={fileType?}&rights={rights?}&imgSize={imgSize?}&imgType={imgType?}&imgColorType={imgColorType?}&imgDominantColor={imgDominantColor?}&alt=json",
#         "type": "application/json"
#     }
# }
# {
#     "kind": "customsearch#search",
#     "queries": {
#         "previousPage": [
#             {
#                 "count": 10,
#                 "cx": "5d8fe349f2e7066a7",
#                 "inputEncoding": "utf8",
#                 "outputEncoding": "utf8",
#                 "safe": "off",
#                 "searchTerms": "car",
#                 "startIndex": 41,
#                 "title": "Google Custom Search - car"
#             }
#         ],
#         "request": [
#             {
#                 "count": 10,
#                 "cx": "5d8fe349f2e7066a7",
#                 "inputEncoding": "utf8",
#                 "outputEncoding": "utf8",
#                 "safe": "off",
#                 "searchTerms": "car",
#                 "startIndex": 51,
#                 "title": "Google Custom Search - car"
#             }
#         ]
#     },
#     "searchInformation": {
#         "formattedSearchTime": "0.13",
#         "formattedTotalResults": "0",
#         "searchTime": 0.133162,
#         "totalResults": "0"
#     },
#     "url": {
#         "template": "https://www.googleapis.com/customsearch/v1?q={searchTerms}&num={count?}&start={startIndex?}&lr={language?}&safe={safe?}&cx={cx?}&sort={sort?}&filter={filter?}&gl={gl?}&cr={cr?}&googlehost={googleHost?}&c2coff={disableCnTwTranslation?}&hq={hq?}&hl={hl?}&siteSearch={siteSearch?}&siteSearchFilter={siteSearchFilter?}&exactTerms={exactTerms?}&excludeTerms={excludeTerms?}&linkSite={linkSite?}&orTerms={orTerms?}&relatedSite={relatedSite?}&dateRestrict={dateRestrict?}&lowRange={lowRange?}&highRange={highRange?}&searchType={searchType}&fileType={fileType?}&rights={rights?}&imgSize={imgSize?}&imgType={imgType?}&imgColorType={imgColorType?}&imgDominantColor={imgDominantColor?}&alt=json",
#         "type": "application/json"
#     }
# }
# {
#     "kind": "customsearch#search",
#     "queries": {
#         "previousPage": [
#             {
#                 "count": 10,
#                 "cx": "5d8fe349f2e7066a7",
#                 "inputEncoding": "utf8",
#                 "outputEncoding": "utf8",
#                 "safe": "off",
#                 "searchTerms": "car",
#                 "startIndex": 51,
#                 "title": "Google Custom Search - car"
#             }
#         ],
#         "request": [
#             {
#                 "count": 10,
#                 "cx": "5d8fe349f2e7066a7",
#                 "inputEncoding": "utf8",
#                 "outputEncoding": "utf8",
#                 "safe": "off",
#                 "searchTerms": "car",
#                 "startIndex": 61,
#                 "title": "Google Custom Search - car"
#             }
#         ]
#     },
#     "searchInformation": {
#         "formattedSearchTime": "0.16",
#         "formattedTotalResults": "0",
#         "searchTime": 0.157363,
#         "totalResults": "0"
#     },
#     "url": {
#         "template": "https://www.googleapis.com/customsearch/v1?q={searchTerms}&num={count?}&start={startIndex?}&lr={language?}&safe={safe?}&cx={cx?}&sort={sort?}&filter={filter?}&gl={gl?}&cr={cr?}&googlehost={googleHost?}&c2coff={disableCnTwTranslation?}&hq={hq?}&hl={hl?}&siteSearch={siteSearch?}&siteSearchFilter={siteSearchFilter?}&exactTerms={exactTerms?}&excludeTerms={excludeTerms?}&linkSite={linkSite?}&orTerms={orTerms?}&relatedSite={relatedSite?}&dateRestrict={dateRestrict?}&lowRange={lowRange?}&highRange={highRange?}&searchType={searchType}&fileType={fileType?}&rights={rights?}&imgSize={imgSize?}&imgType={imgType?}&imgColorType={imgColorType?}&imgDominantColor={imgDominantColor?}&alt=json",
#         "type": "application/json"
#     }
# }
# {
#     "kind": "customsearch#search",
#     "queries": {
#         "previousPage": [
#             {
#                 "count": 10,
#                 "cx": "5d8fe349f2e7066a7",
#                 "inputEncoding": "utf8",
#                 "outputEncoding": "utf8",
#                 "safe": "off",
#                 "searchTerms": "car",
#                 "startIndex": 61,
#                 "title": "Google Custom Search - car"
#             }
#         ],
#         "request": [
#             {
#                 "count": 10,
#                 "cx": "5d8fe349f2e7066a7",
#                 "inputEncoding": "utf8",
#                 "outputEncoding": "utf8",
#                 "safe": "off",
#                 "searchTerms": "car",
#                 "startIndex": 71,
#                 "title": "Google Custom Search - car"
#             }
#         ]
#     },
#     "searchInformation": {
#         "formattedSearchTime": "0.20",
#         "formattedTotalResults": "0",
#         "searchTime": 0.197844,
#         "totalResults": "0"
#     },
#     "url": {
#         "template": "https://www.googleapis.com/customsearch/v1?q={searchTerms}&num={count?}&start={startIndex?}&lr={language?}&safe={safe?}&cx={cx?}&sort={sort?}&filter={filter?}&gl={gl?}&cr={cr?}&googlehost={googleHost?}&c2coff={disableCnTwTranslation?}&hq={hq?}&hl={hl?}&siteSearch={siteSearch?}&siteSearchFilter={siteSearchFilter?}&exactTerms={exactTerms?}&excludeTerms={excludeTerms?}&linkSite={linkSite?}&orTerms={orTerms?}&relatedSite={relatedSite?}&dateRestrict={dateRestrict?}&lowRange={lowRange?}&highRange={highRange?}&searchType={searchType}&fileType={fileType?}&rights={rights?}&imgSize={imgSize?}&imgType={imgType?}&imgColorType={imgColorType?}&imgDominantColor={imgDominantColor?}&alt=json",
#         "type": "application/json"
#     }
# }
# {
#     "kind": "customsearch#search",
#     "queries": {
#         "previousPage": [
#             {
#                 "count": 10,
#                 "cx": "5d8fe349f2e7066a7",
#                 "inputEncoding": "utf8",
#                 "outputEncoding": "utf8",
#                 "safe": "off",
#                 "searchTerms": "car",
#                 "startIndex": 71,
#                 "title": "Google Custom Search - car"
#             }
#         ],
#         "request": [
#             {
#                 "count": 10,
#                 "cx": "5d8fe349f2e7066a7",
#                 "inputEncoding": "utf8",
#                 "outputEncoding": "utf8",
#                 "safe": "off",
#                 "searchTerms": "car",
#                 "startIndex": 81,
#                 "title": "Google Custom Search - car"
#             }
#         ]
#     },
#     "searchInformation": {
#         "formattedSearchTime": "0.15",
#         "formattedTotalResults": "0",
#         "searchTime": 0.151204,
#         "totalResults": "0"
#     },
#     "url": {
#         "template": "https://www.googleapis.com/customsearch/v1?q={searchTerms}&num={count?}&start={startIndex?}&lr={language?}&safe={safe?}&cx={cx?}&sort={sort?}&filter={filter?}&gl={gl?}&cr={cr?}&googlehost={googleHost?}&c2coff={disableCnTwTranslation?}&hq={hq?}&hl={hl?}&siteSearch={siteSearch?}&siteSearchFilter={siteSearchFilter?}&exactTerms={exactTerms?}&excludeTerms={excludeTerms?}&linkSite={linkSite?}&orTerms={orTerms?}&relatedSite={relatedSite?}&dateRestrict={dateRestrict?}&lowRange={lowRange?}&highRange={highRange?}&searchType={searchType}&fileType={fileType?}&rights={rights?}&imgSize={imgSize?}&imgType={imgType?}&imgColorType={imgColorType?}&imgDominantColor={imgDominantColor?}&alt=json",
#         "type": "application/json"
#     }
# }
# {
#     "kind": "customsearch#search",
#     "queries": {
#         "previousPage": [
#             {
#                 "count": 10,
#                 "cx": "5d8fe349f2e7066a7",
#                 "inputEncoding": "utf8",
#                 "outputEncoding": "utf8",
#                 "safe": "off",
#                 "searchTerms": "car",
#                 "startIndex": 81,
#                 "title": "Google Custom Search - car"
#             }
#         ],
#         "request": [
#             {
#                 "count": 10,
#                 "cx": "5d8fe349f2e7066a7",
#                 "inputEncoding": "utf8",
#                 "outputEncoding": "utf8",
#                 "safe": "off",
#                 "searchTerms": "car",
#                 "startIndex": 91,
#                 "title": "Google Custom Search - car"
#             }
#         ]
#     },
#     "searchInformation": {
#         "formattedSearchTime": "0.12",
#         "formattedTotalResults": "0",
#         "searchTime": 0.12485,
#         "totalResults": "0"
#     },
#     "url": {
#         "template": "https://www.googleapis.com/customsearch/v1?q={searchTerms}&num={count?}&start={startIndex?}&lr={language?}&safe={safe?}&cx={cx?}&sort={sort?}&filter={filter?}&gl={gl?}&cr={cr?}&googlehost={googleHost?}&c2coff={disableCnTwTranslation?}&hq={hq?}&hl={hl?}&siteSearch={siteSearch?}&siteSearchFilter={siteSearchFilter?}&exactTerms={exactTerms?}&excludeTerms={excludeTerms?}&linkSite={linkSite?}&orTerms={orTerms?}&relatedSite={relatedSite?}&dateRestrict={dateRestrict?}&lowRange={lowRange?}&highRange={highRange?}&searchType={searchType}&fileType={fileType?}&rights={rights?}&imgSize={imgSize?}&imgType={imgType?}&imgColorType={imgColorType?}&imgDominantColor={imgDominantColor?}&alt=json",
#         "type": "application/json"
#     }
# }

# %%
import requests

URL = "https://www.britannica.com/technology/automobile"
page = requests.get(URL)

print(page.text)
# Out:
# <!doctype html>
#
# <html data-ytrk-page="TOPIC PAGINATED LARGE" lang="en" class="ui-unknown0 ui-unknown">
#
# <head prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb#">
#
#     <meta charset="utf-8">
#     <meta http-equiv="Content-Type" content="text/html; charset=UTF-8" />
#     <meta name="viewport" content="width=device-width, initial-scale=1.0" />
#
#     <meta property="fb:pages" content="74442380906" />
#
# 	<link rel="dns-prefetch" href="https://cdn.britannica.com/mendel-resources/3-53">
# 	<link rel="preconnect" href="https://cdn.britannica.com/mendel-resources/3-53">
#
#     <meta name="description" content="Automobile, or car, a usually four-wheeled vehicle designed primarily for passenger transportation and commonly propelled by an internal-combustion engine using a volatile fuel. Learn more about automotive design and the history of cars in this article." />
#
#     <meta name="keywords" content="automobile, encyclopedia, encyclopeadia, britannica, article" />
#
#     <link rel="canonical" href="https://www.britannica.com/technology/automobile" />
#     <script type="text/javascript" data-type="Init Mendel">
#
#     window.$UI = {};
#
#     window.Constants = {"LICENSE_URL": "/bps/license","DEFAULT_TEST_VERSION": "A","DEFAULT_STATE": "XX","QUIZ_URL": "/quiz","SPOTLIGHT_BROWSE_URL": "/stories/spotlight","CONTENT_TYPE_TEXT": "text/plain;charset=UTF-8","TOPIC_MEDIA_PATH": "/images-videos","DEBUG_URL": "/debug","ERROR_404_URL": "/error404","TOPIC_QUOTES_PATH": "/quotes","INSTANT_ARTICLES_URL": "/instant-articles","TOPIC_PAGE_CONTENT_AJAX_URL": "/topic-content/page","INFINITE_SCROLL_PREFIX_URL": "/scroll","CC_USD": "USD","SURVEY_URL": "/survey","CATEGORY_BROWSE_URL": "/browse","STORY_BROWSE_URL": "/stories","IN_THIS_WEEK_BROWSE_URL": "/week-in-review","COUNTRY_US": "US","OPEN_MEDIA_OVERLAY_PARAMETER": "/media","FACTS_URL": "/facts","GAMES_BROWSE_WORDSEARCH_URL": "/games/Word-Search","NEWSLETTER_SUBSCRIPTION_URL": "/newsletter-subscription","INSIGHTS_LANDING_PAGE_URL_2": "/factsmatter","HOMEPAGE_VIDEO_ADMIN_URL": "/homepage-videos-admin","INSIGHTS_LANDING_PAGE_URL_1": "/insights","MAINTENANCE_ERROR_URL": "https://maintenance.eb.com","IMARS_EDITOR_ID": "12365882","PROFILE_EB_EDITOR_URL": "/editor","WEB_INF_RESOURCES_PATH": "WEB-INF/resources","TOPIC_ADDITIONAL_INFO_PATH": "/additional-info","CC_INR": "INR","ARTICLE_PRINT_URL": "/print/article","FIRST_EDITION_URL": "/subscriber/firstedition","WW1_PORTAL_URL": "/discover/World-War-I","PROFILE_USER_URL": "/user","MENDEL_COOKIE": "__mendel","DEMYSTIFIED_BROWSE_URL": "/stories/demystified","LIST_BROWSE_URL": "/list/browse","PROFILE_EXPERT_URL": "/contributor","USER_PROFILE_PICTURE_URL": "/image/profile","ASSEMBLY_IMAGE_URL": "/image/assembly","DAY_IN_HISTORY_URL": "/on-this-day","DEFAULT_CURRENCY": "USD","GAMES_HOMEPAGE_URL": "/games","CONTENT_TYPE_XML": "text/xml;charset=UTF-8","AJAX_PREFIX_URL": "/ajax","TOPIC_BROWSE_URL": "/topic-browse","MARKETING_CONTENT": "/marketing-content","ENV_RUNTIME": "runtime","USER_PROFILE_PARTNER_LOGO_URL": "/image/profile-partner","GALLERY_URL": "/gallery","CONTENT_TYPE_HTML": "text/html;charset=UTF-8","ENV_LOCAL": "override","MEDIA_OVERLAY_URL": "/media-overlay","ENV_DEV": "development","MEDIA_URL": "/media","PODCASTS_URL": "/podcasts","STAND_ALONE_VIDEO_URL": "/video","MORE_ON_THIS_DAY_URL": "/more-on-this-day","SEARCH_PAGE_URL": "/search","TOPIC_CONTENT_AJAX_URL": "/topic-content/topic","ENV_BRANCH": "branch","ERROR_URL": "/error","MAIN_VERSION": "mainVersion","DEFAULT_S3_REGION": "US_EAST_1","LOGINBOX_URL": "/auth/loginbox","QUIZ_BROWSE_URL": "/quiz/browse","BIO_BROWSE_URL": "/biographies","LIST_URL": "/list","ALPHA_BROWSE_URL": "/sitemap","GAME_URL": "/game","CONTENT_TYPE_JSON": "application/json","COBRAND_IMAGE_URL": "/image/cobrand","SUBMISSION_URL": "/submission","EB_LOG_OUT": "/auth2/logout","ENV_PRODUCTION": "production","CONTENTFUL_ADMIN_PREFIX_URL": "/contentful-admin","TOPIC_AJAX_URL": "/ajax/topic","GAMES_BROWSE_CROSSWORD_URL": "/games/Crossword-Puzzle","WTFACT_BROWSE_URL": "/stories/wtfact","FEATURED_CONTENT_ADMIN_URL": "/fc-admin","VIDEO_CHANNEL_URL": "/videos","GALLERY_BROWSE_URL": "/gallery/browse","CACHE_URL": "/cache","COMPANION_BROWSE_URL": "/stories/companion","MEDIA_FOLDER": "/eb-media","SHOW_ALL_CONTRIBUTORS": "/additional-info#contributors","BRITANNICA_EDITORS_ID": "4419","EXPLORE_BROWSE": "/explore","TOPIC_SUMMARY_URL": "/summary","ENV_CACHE_DISABLED": "mendelCache","STORY_URL": "/story","DEFAULT_COUNTRY": "US","NAVBAR_URL": "/ajax/navbar","EB_LOGIN_URL": "/auth/eb-login","NEW_ARTICLES_URL": "/new-articles",};
#     window.CDN = "https://cdn.britannica.com";
#     window.CAM_LOGIN_URL = "https://cam.britannica.com";
#     window.CAM_SIGN_UP_URL = "https://cam.britannica.com/registration"
#
#     window.Mendel = {
#      	"config" : {
# 			"page": "Topic",
# 			"videoPlayerId": "DkXxjTZZ",
# 			"sharedUrl": "https://www.britannica.com/technology/automobile",
# 	        "resourcesPrefixUrl": "https://cdn.britannica.com/mendel-resources/3-53/[url]?v=3.53.17",
# 			"userInfo": { "type": "ANONYMOUS"
# 			             ,"currency": "USD"
# 			             ,"country": "US"
# 					     ,"state": "IL"
# 			             ,"bcomId": "4958167163835545566"
# 				         ,"hasAds": true
# 					     ,"testVersion": "C"
# 				         ,"privacyInfo": {"consentLocation":false,"gdpr":false,"ccpa":false,"needConsent":false}
# 						 ,"consumerId": ""
# 						 ,"instId": ""
# 						 ,"consumerUserName": ""
# 						 ,"instUserName": ""
# 			},
# 			"isLoggedInAsUser": false,
# 			"analytics": {  "gaId": "UA-6636134-11" },
# 			"isPhone": false,
# 			"isDesktop": true,
# 			"logoutUrl": "/auth2/logout",
# 			"selfServiceUrl": "https://myaccount.britannica.com",
# 			"cdnUrl": "https://cdn.britannica.com",
# 	        "fetchOffset": 800,
# 	        "isMetered": true,
#
# 			"mendelCookieName": "__mendel",
# 			"mendelCookie": {"pagesViewed":1,"surveyShown":false,"topicInitialSequence":1},
#
#
# 			"autocompleteToSearchPage": false,"topicUrl": "/technology/automobile"
#         ,"freeTopicReason": "NO_REFERRER"
#         ,"topicId": 44957
# 	    ,"template": "DESKTOP"
# 	    ,"type": "CORE"
# 	    ,"hasEditMode": false
# 		,"hasToc": true,"infiniteScrollList": [{"p":13,"t":44957},{"p":1,"t":371219},{"p":1,"t":213238},{"p":1,"t":1666233},{"p":1,"t":67416},{"p":1,"t":507195},{"p":1,"t":14594},{"p":1,"t":315736},{"p":1,"t":1952506},{"p":1,"t":557506}]
#         ,"sequence": 1
#         ,"topics": {}
# 		},
# 		chatbot: {
# 			answerService: {
# 				url: 'https://chatbot.api.eb.com/api/qna',
# 				apiKey: 'YH4dIgRoMX77z56YfLcz24aur7nONAEI6lziQKpX',
# 			},
# 			feedbackService: {
# 				url: 'https://4ltuaewqxb.execute-api.us-east-1.amazonaws.com/production/feedback',
# 				apiKey: 'YYFYIE3qaS4i6vGDOj2TE1kPBYpSWkK68Uy2L0ME',
# 			},
# 		}
#     };
#
# 	</script>
#
#
#
#
#
#
#
#
#
# <script   class="marketing-page-info" type="application/json">
# {"pageType":"Topic","templateName":"DESKTOP","pageNumber":1,"pagesTotal":13,"pageId":44957,"pageLength":985,"initialLoad":true,"metered":true}
# </script>
#
#
#
#
#
#
#
#
#
# <script   class="marketing-content-info" type="application/json">
# [{"id":1012,"name":"SUBSCRIPTION_LINK_DESKTOP","selector":"#fake"}]
# </script>
#
# <script>
# 	Mendel.BC = {"loggedIn":false,"category":"Cars & Other Vehicles","lastUpdated":"Nov 02, 2021","contributorName":"Ken W. Purdy"}</script><meta property="fb:app_id" content="1887621861548296"/>
#
# 	<meta name="twitter:card" content="summary_large_image" />
# 	<meta name="twitter:site" content="@britannica" />
# 	<meta name="twitter:image" content="https://cdn.britannica.com/16/126216-050-D9865939/Automobiles-John-F-Fitzgerald-Expressway-Massachusetts-Boston.jpg" />
# 	<meta name="twitter:description" content="Automobile, or car, a usually four-wheeled vehicle designed primarily for passenger transportation and commonly propelled by an internal-combustion engine using a volatile fuel. Learn more about automotive design and the history of cars in this article."/>
#
# 	<meta property="og:type"  content="ARTICLE"/>
# 	<meta property="og:title" content="automobile | Definition, History, Industry, Design, & Facts"/>
# 	<meta property="og:description" content="Automobile, or car, a usually four-wheeled vehicle designed primarily for passenger transportation and commonly propelled by an internal-combustion engine using a volatile fuel. Learn more about automotive design and the history of cars in this article."/>
# 	<meta property="og:site_name" content="Encyclopedia Britannica" />
# 	<meta property="og:url" content="https://www.britannica.com/technology/automobile"/>
# 	<meta property="og:image" content="https://cdn.britannica.com/16/126216-050-D9865939/Automobiles-John-F-Fitzgerald-Expressway-Massachusetts-Boston.jpg" />
# 	<meta property="og:image:type" content="image/jpeg" />
#
# 	<script type="text/javascript" data-type="init opengraph">
# 	Mendel.openGraph = {"type":"ARTICLE","title":"automobile | Definition, History, Industry, Design, & Facts","description":"Automobile, or car, a usually four-wheeled vehicle designed primarily for passenger transportation and commonly propelled by an internal-combustion engine using a volatile fuel. Learn more about automotive design and the history of cars in this article.","imageUrl":"https://cdn.britannica.com/16/126216-050-D9865939/Automobiles-John-F-Fitzgerald-Expressway-Massachusetts-Boston.jpg","imageType":"image/jpeg","pageUrl":"https://www.britannica.com/technology/automobile"}</script>
#
# <title>automobile | Definition, History, Industry, Design, & Facts | Britannica</title>
#
#     <link rel="preconnect" href="https://fonts.googleapis.com/">
# <link rel="dns-prefetch" href="https://fonts.googleapis.com/" >
# <link rel="stylesheet" href="https://fonts.googleapis.com/icon?family=Material+Icons">
# <link href="https://cdn.britannica.com/mendel-resources/3-53/dist/vendor-bundle.css?v=3.53.17" rel="stylesheet" />
#     <link href="https://cdn.britannica.com/mendel-resources/3-53/dist/mendel-css.css?v=3.53.17" rel="stylesheet" />
# 	<link href="https://cdn.britannica.com/mendel-resources/3-53/dist/topic-page.css?v=3.53.17" rel="stylesheet" />
#
#     <script type="text/javascript">
#         if ('scrollRestoration' in history) { history.scrollRestoration = 'manual'; }
#     </script>
#
#     <script
#         src="https://www.googleoptimize.com/optimize.js?id=OPT-N7CJGBC"
#         async
#     ></script>
# <script src="https://cdn.britannica.com/mendel-resources/3-53/js/iab.js?v=3.53.17" type="text/javascript" charset="UTF-8"></script>
# 	<script type="text/javascript">
# googletag = {
#   cmd: []
# };
# </script>
#
# <script class="ads-script" type="application/json">
# {"ORATV":[{"id":111,"type":"ORATV","selector":".AM3","injector":"after","displayType":"REGULAR"}],"DFP":[{"id":26,"type":"DFP","selector":".infinite-scroll-container.article.last aside","injector":"append","adParameters":{"targeting":{"TEMPLATE":"1","ARTICLE":"44957"},"size":[[300,250]],"cssClass":"sticky-da-bot","pos":"BOT","replace":"true","global":"true","id":"DESKTOP"},"displayType":"REGULAR"},{"id":106,"type":"DFP","selector":".pl728","injector":"prepend","adParameters":{"targeting":{"TEMPLATE":"1","ARTICLE":"44957"},"size":[[728,90],[970,250]],"pos":"TOP","id":"DESKTOP"},"displayType":"REGULAR"},{"id":178,"type":"DFP","selector":".infinite-scroll-container.article.last aside","injector":"prepend","adParameters":{"targeting":{"TEMPLATE":"1","ARTICLE":"44957"},"size":[[300,250]],"cssClass":"sticky-da","pos":"TOP","replace":"true","global":"true","id":"DESKTOP"},"displayType":"REGULAR"},{"id":182,"type":"DFP","injector":"after","adParameters":{"targeting":{"TEMPLATE":"1","ARTICLE":"44957"},"size":[[728,90]],"pos":"CATFISH","id":"DESKTOP"},"displayType":"STATIC_CATFISH"}]}</script>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <script type="text/javascript">
# 	Mendel.AD = {
# 	    providers : {},
# 		managers  : {},
# 		display  :  {},
# 	    cmd       : [],
# 		info      : {
#
# 	"catfishTimeout"     : 60,
# 	"catfish2CloseButtonTimeout": 65,
# 	"googleGPTId"        : "15510053",
# 	"googleAdsId"        : "0081271244777268",
# 	"dfpLazyLoad"        : false,
# 	"dfpLazyLoadParams"  : {fetchMarginPercent:300,renderMarginPercent:200,mobileScaling:2.0},
# 	"dfpUnitPrefix"      : "",
# 	"catfishShown"       : false,
# 	"prerollAd"          : true && Mendel.config.isDesktop,
# 	"oraTvCodeVersion"   : 2,
# 	"analytics"          : ["oratv"]
# 	,"refreshInfo"       : [{"refreshType":"PAGE","max":12,"timer":30,"parameters":{
# "newAdUnit": true
# }}]
# 	,"a9Id"              : "3022"
#
# 					}
# 	};
#
# 	__ADMANAGERS  = Mendel.AD.managers;
# 	__ADPROVIDERS = Mendel.AD.providers;
# 	__ADINFO      = Mendel.AD.info;
# 	__ADREFRESH   = Mendel.AD.info.refreshInfo;
# 	__ADCMD       = Mendel.AD.cmd;
# </script>
# <script src="//js-sec.indexww.com/ht/htw-britannica.js" type="text/javascript"></script>
# <script src="https://securepubads.g.doubleclick.net/tag/js/gpt.js"></script>
# <script src="//c.amazon-adsystem.com/aax2/apstag.js" type="text/javascript"></script>
# 	<script type="text/javascript" data-type="Amazon a9">
# 	!function(a9,a){if(a[a9])return;function q(c,r){a[a9]._Q.push([c,r])}a[a9]={init:function(){q("i",arguments)},fetchBids:function(){q("f",arguments)},setDisplayBids:function(){},targetingKeys:function(){return[]},_Q:[]};}("apstag",window);
# 	</script>
#
# <script type="text/javascript" src="https://cdn.britannica.com/mendel-resources/3-53/dist/mam.js?v=3.53.17"></script>
#
# 	<script id="ns_script_dc" data-key="12ca4747-8e80-4a36-b550-dc239c18b954" data-e="5" src="//includemodal.global.ssl.fastly.net/sp.js" type="text/javascript" async></script>
# <script type="text/javascript">
# 		!(function(o,n,t){t=o.createElement(n),o=o.getElementsByTagName(n)[0],t.async=1,t.src="https://superficialsquare.com/v2efnImPApSzhnLlHe1yjXrMv18oN6sVdzmho_QRB6Zxhy_rgT68LFVeCAMempYpY",o.parentNode.insertBefore(t,o)})(document,"script"),(function(o,n){o[n]=o[n]||function(){(o[n].q=o[n].q||[]).push(arguments)}})(window,"admiral");!(function(c,e,o,t,n){function r(o,t){(function n(){try{return 0<(localStorage.getItem("v4ac1eiZr0")||"").split(",")[4]}catch(o){}return!1})()&&(t=c[e].pubads())&&t.setTargeting("admiral-engaged","true")}(n=c[e]=c[e]||{}).cmd=n.cmd||[],typeof n.pubads===o?r():typeof n.cmd.unshift===o?n.cmd.unshift(r):n.cmd.push(r)})(window,"googletag","function");
# 	</script>
# <script>
# 	            dataLayer = [];
#             </script>
# 		   <script type="text/javascript">(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# 		       new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# 		       j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 		       '//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# 		   })(window,document,'script','dataLayer','GTM-5W6NC8');
# 		   </script>
# 		<script type='text/javascript'>
# 	window._vwo_code = window._vwo_code || (function(){
# 	var account_id=331471,
# 	settings_tolerance=2000,
# 	library_tolerance=2500,
# 	use_existing_jquery=false,
# 	is_spa=1,
# 	hide_element='none',
#
# 	f=false,d=document,code={use_existing_jquery:function(){return use_existing_jquery;},library_tolerance:function(){return library_tolerance;},finish:function(){if(!f){f=true;var a=d.getElementById('_vis_opt_path_hides');if(a)a.parentNode.removeChild(a);}},finished:function(){return f;},load:function(a){var b=d.createElement('script');b.src=a;b.type='text/javascript';b.innerText;b.onerror=function(){_vwo_code.finish();};d.getElementsByTagName('head')[0].appendChild(b);},init:function(){
# 	window.settings_timer=setTimeout('_vwo_code.finish()',settings_tolerance);var a=d.createElement('style'),b=hide_element?hide_element+'{opacity:0 !important;filter:alpha(opacity=0) !important;background:none !important;}':'',h=d.getElementsByTagName('head')[0];a.setAttribute('id','_vis_opt_path_hides');a.setAttribute('type','text/css');if(a.styleSheet)a.styleSheet.cssText=b;else a.appendChild(d.createTextNode(b));h.appendChild(a);this.load('https://dev.visualwebsiteoptimizer.com/j.php?a='+account_id+'&u='+encodeURIComponent(d.URL)+'&f='+(+is_spa)+'&r='+Math.random());return settings_timer; }};window._vwo_settings_timer = code.init(); return code; }());
# </script>
#
# <meta http-equiv="last-modified" content="2021-11-02" /></head>
#
# <body data-leg="C" class="new-topic topic-desktop first-page-true user-ANONYMOUS user-ads  md-desktop   leg-c chatbot-enabled">
#
#
#
#
#
#
#
#
#
# <script  id="json-navbar-info"  type="application/json">
# {"extraLinks":[{"title":"Quizzes","url":"/quiz/browse"},{"title":"Games","url":"/games"},{"title":"On This Day","url":"/on-this-day"}],"featureLinks":[{"title":"Quizzes","url":"/quiz/browse","description":"Can you get to the top of the leaderboard?"},{"title":"Games","url":"/games","description":"Cryptic crosswords and more. Happy puzzling!"},{"title":"Podcasts","url":"/podcasts","description":"Stay curious on the go."},{"title":"On This Day","url":"/on-this-day","description":"What happened on your birthday?"},{"title":"Biographies","url":"/biographies","description":"Explore extraordinary lives."},{"title":"Week In Review","url":"/week-in-review","description":"A weekly recap of key events and fun facts."},{"title":"Topic Summaries","url":"/summary","description":"Summaries, quick-facts, and timelines on key topics"},{"title":"Infographics","url":"https://www.britannica.com/study/infographics","description":"Explore the world through maps, charts, and graphs.","newTab":true},{"title":"Demystified","url":"/stories/demystified","description":"Insight into some of life's big mysteries."},{"title":"Lists","url":"/list/browse","description":"Find out what tops our Editors’ lists. "},{"title":"#WTFact","url":"/stories/wtfact","description":"Stories so weird you’ll exclaim: “What the Fact!”"},{"title":"Companions","url":"/stories/companion","description":"A more concise complement to our top articles."},{"title":"Image Galleries","url":"/gallery/browse","description":"Browse editorially curated collections."},{"title":"Spotlight","url":"/stories/spotlight","description":"Get more context behind trending news and events."},{"title":"The Forum","url":"/stories/the-forum","description":"Analysis, research, and ideas from leading experts."}],"featuredFeature":{"title":"Lay, Lie, Lied, Lain: When Do We Use Which?","url":"/story/lay-lie-lied-lain-when-do-we-use-which","description":"Demystified / Literature","image":{"id":0,"url":"/59/195959-131-01E0E29B/ginger-cat-bed-focus-floor-carpet.jpg","altText":"A ginger cat sleeps in his soft cozy bed on a floor carpet, soft focus","credit":"© Alena Ozerova/Shutterstock.com","fullUrl":"https://cdn.britannica.com/59/195959-131-01E0E29B/ginger-cat-bed-focus-floor-carpet.jpg"}},"categoryLinks":[{"id":10000,"title":"Entertainment & Pop Culture","urlTitle":"Entertainment-Pop-Culture","description":"Entertainment and leisure activities have been a part of culture in one form or another since the ancient times. Dance performances, live music, and storytelling have a long tradition throughout history, even as the styles and available methods of delivery have shifted dramatically.","image":{"id":0,"url":"/04/167104-050-A0D0F726.jpg","altText":"Entertainment & Pop Culture","fullUrl":"https://cdn.britannica.com/04/167104-050-A0D0F726.jpg"}},{"id":5000,"title":"Geography & Travel","urlTitle":"Geography-Travel","description":"Planet Earth contains some extraordinarily diverse environments, some of which are easily habitable and some not so much. In different areas of Earth, one might find sweltering deserts, dense tropical rainforests, or bone-chilling tundras. Each biome and habitat comes with its own selection of flora and fauna, and it may include physical features such as canyons, volcanoes, rivers, or caves. Human beings have built homes in many different environments, settling the area and organizing it into units such as cities, states, regions, and countries, each with its own points of interest. Shifting trends in human migration have resulted in a human geography that is profoundly different from that of centuries ago.","image":{"id":0,"url":"/17/2317-050-758D0E55/World-map-descriptions-Herodotus-Black-Sea.jpg","altText":"Geography & Travel","fullUrl":"https://cdn.britannica.com/17/2317-050-758D0E55/World-map-descriptions-Herodotus-Black-Sea.jpg"}},{"id":3000,"title":"Health & Medicine","urlTitle":"Health-Medicine","description":"The study of the human mind and body, how these function, and how the ...
# </script>
#
# <header id="header" class="bg-navy shadow-lg">
#     <div class="grid gx-0 align-items-center">
#         <div class="col-auto order-1 order-sm-0">
#             <a href="/" class="mx-10 mx-sm-20 d-block">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <img loading="lazy" src="https://cdn.britannica.com/mendel/eb-logo/b-50-pb5.png" alt="Encyclopedia Britannica logo"  height="30" width="123"/>
# </a>
#         </div>
#         <div class="col-auto order-0 order-sm-1">
#             <button class="js-toggle js-toggle-hamburger btn btn-link link-white btn-sm rounded-0 px-15">
#                 <em class="material-icons inactive-icon" data-icon="menu"></em>
# 	<em class="material-icons active-icon" data-icon="close"></em>
# 	<span class="d-none d-sm-inline-block ml-5">Browse</span>
#             </button>
#             <button class="js-toggle js-toggle-search-flyout btn btn-link link-white btn-sm rounded-0 px-15">
#                 <em class="material-icons inactive-icon" data-icon="search"></em>
# 	<em class="material-icons active-icon" data-icon="close"></em>
# 	<span class="d-none d-sm-inline-block ml-5">Search</span>
#             </button>
#         </div>
#         <div class="col d-none d-sm-flex align-items-center justify-content-md-start justify-content-end order-2">
#             <a class="link-white font-14 ml-20 " href="/quiz/browse">
#                     Quizzes</a>
#             <a class="link-white font-14 ml-20 ml-md-35" href="/games">
#                     Games</a>
#             <a class="link-white font-14 ml-20 ml-md-35" href="/on-this-day">
#                     On This Day</a>
#             </div>
#         <div class="col col-sm-auto text-right order-3 mr-lg-15">
#             <SPAN class="marketing-HEADER_SUBSCRIPTION_DESKTOP2 marketing-content" data-marketing-id="HEADER_SUBSCRIPTION_DESKTOP2"><a href="https://premium.britannica.com/premium-membership/?utm_source=premium&utm_medium=global-nav&utm_campaign=evergreen" class="subscribe-link btn btn-sm btn-outline-white-orange py-5 mr-10" target="_blank" rel="noopener">
#    Subscribe
# </a></SPAN><button class="js-toggle-user-dropdown js-toggle btn btn-sm btn-link link-white rounded-0 pl-15 pr-10">
#                         <span class="d-inline-block mr-5">Login</span>
#                         <em class="material-icons inactive-icon d-inline-block" data-icon="keyboard_arrow_down"></em>
# 	<em class="material-icons active-icon d-inline-block" data-icon="keyboard_arrow_up"></em>
# 	</button>
#                 </div>
#     </div>
#     <div id="global-nav-react">
#         <ul class="d-none">
#             <li><a href="/browse/Entertainment-Pop-Culture">Entertainment & Pop Culture</a></li>
#             <li><a href="/browse/Geography-Travel">Geography & Travel</a></li>
#             <li><a href="/browse/Health-Medicine">Health & Medicine</a></li>
#             <li><a href="/browse/Lifestyles-Social-Issues">Lifestyles & Social Issues</a></li>
#             <li><a href="/browse/Literature">Literature</a></li>
#             <li><a href="/browse/Philosophy-Religion">Philosophy & Religion</a></li>
#             <li><a href="/browse/Politics-Law-Government">Politics, Law & Government</a></li>
#             <li><a href="/browse/Science">Science</a></li>
#             <li><a href="/browse/Sports-Recreation">Sports & Recreation</a></li>
#             <li><a href="/browse/Technology">Technology</a></li>
#             <li><a href="/browse/Visual-Arts">Visual Arts</a></li>
#             <li><a href="/browse/World-History">World History</a></li>
#             </ul>
#         <ul class="d-none">
#             <li><a href="/quiz/browse">Quizzes</a></li>
#             <li><a href="/games">Games</a></li>
#             <li><a href="/podcasts">Podcasts</a></li>
#             <li><a href="/on-this-day">On This Day</a></li>
#             <li><a href="/biographies">Biographies</a></li>
#             <li><a href="/week-in-review">Week In Review</a></li>
#             <li><a href="/summary">Topic Summaries</a></li>
#             <li><a href="https://www.britannica.com/study/infographics">Infographics</a></li>
#             <li><a href="/stories/demystified">Demystified</a></li>
#             <li><a href="/list/browse">Lists</a></li>
#             <li><a href="/stories/wtfact">#WTFact</a></li>
#             <li><a href="/stories/companion">Companions</a></li>
#             <li><a href="/gallery/browse">Image Galleries</a></li>
#             <li><a href="/stories/spotlight">Spotlight</a></li>
#             <li><a href="/stories/the-forum">The Forum</a></li>
#             </ul>
#         <ul class="d-none">
#             <li><a href="/videos/Entertainment-Pop-Culture">Entertainment & Pop Culture</a></li>
#             <li><a href="/videos/Geography-Travel">Geography & Travel</a></li>
#             <li><a href="/videos/Health-Medicine">Health & Medicine</a></li>
#             <li><a href="/videos/Lifestyles-Social-Issues">Lifestyles & Social Issues</a></li>
#             <li><a href="/videos/Literature">Literature</a></li>
#             <li><a href="/videos/Philosophy-Religion">Philosophy & Religion</a></li>
#             <li><a href="/videos/Politics-Law-Government">Politics, Law & Government</a></li>
#             <li><a href="/videos/Science">Science</a></li>
#             <li><a href="/videos/Sports-Recreation">Sports & Recreation</a></li>
#             <li><a href="/videos/Technology">Technology</a></li>
#             <li><a href="/videos/Visual-Arts">Visual Arts</a></li>
#             <li><a href="/videos/World-History">World History</a></li>
#             </ul>
#         <ul class="d-none">
#             <li><a href="/videos/britannica-classics">Britannica Classics<br/>Check out these retro videos from Encyclopedia Britannica’s archives.</a></li>
#             <li><a href="/videos/demystified">Demystified Videos<br/>In Demystified, Britannica has all the answers to your burning questions.</a></li>
#             <li><a href="/videos/wtfact">#WTFact Videos<br/>In #WTFact Britannica shares some of the most bizarre facts we can find.</a></li>
#             <li><a href="/videos/this-week-in-history">This Time in History<br/>In these videos, find out what happened this month (or any month!) in history.</a></li>
#             <li><a href="/videos/explains">Britannica Explains<br/>In these videos, Britannica explains a variety of topics and answers frequently asked questions.</a></li>
#             </ul>
#     </div>
# </header>
#
# <main>
#
# 	    <div class="md-page-wrapper">
#
# 	        <div id="content" class="md-content">
#
# 		        <div class="md-article-container template-desktop infinite-pagination">
# 			<div class="infinite-scroll-container article last">
# 	        <article class="article-content content md-expanded" data-topic-id="44957">
#
#             <div class="pl728 toolbar-ad"></div>
#
#             <div class="grid gx-0">
#
# 	            <div class="col-auto">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <div class="family-panel md-article-drawer position-relative d-flex border-right-sm open">
#     <div class="drawer open">
#
#
#
#
# 	<div class="family-panel-header grid gx-0 align-items-center border-bottom bg-white">
#         <div class="col">
#             <div class="py-15 px-20 text-truncate">
#                 <a class="font-serif font-weight-bold font-14 text-black link-blue" href="/technology/automobile">
#                     automobile
#                 </a>
#             </div>
#         </div>
#         <div class="col-auto d-sm-none">
#             <button class="js-sections-button btn-link btn-sm btn py-5 pl-0 pr-10 mr-10">
#                 <em class="material-icons " data-icon="arrow_drop_down"></em>
#
#                 Sections &amp; Media
#             </button>
#         </div>
#     </div>
#
# 	<div class="family-section-content ml-50 ml-sm-0 grid g-0 flex-column bg-gray-50">
#
#
#
#
#         <div class="TOC js-section section col expanded">
#             <div class="h-100 d-flex flex-column ">
#                 <div class="section-title border-bottom bg-white col-auto d-flex justify-content-between align-items-center">
#                     <a
#                         href="/technology/automobile"
#                         class="border-yellow border-left-5 label text-black link-blue d-inline-flex align-items-center px-15 py-10"
#                     >
#                         <em class="material-icons mr-5" data-icon="article"></em>
# 	Article
#                     </a>
#                     <button aria-label="expand/collapse panel" class="js-toggle-btn toggle-btn btn btn-unstyled pe-auto col h-100 justify-content-end">
#                         <div class="btn btn-circle btn-outline-navy btn-sm mr-15 border-gray-200">
#                             <em class="material-icons toggle-icon" data-icon="expand_more"></em>
#
#                         </div>
#                     </button>
#                 </div>
#                 <div class="toc section-content">
#
#
#                             <ul class="list-unstyled mb-0 w-100" data-level="h1"><li data-target="#ref1"><a href="/technology/automobile">Introduction</a></li><li data-target="#ref259040"><a href="/technology/automobile#ref259040">Automotive design</a><ul class="list-unstyled" data-level="h2"><li data-target="#ref259041"><a href="/technology/automobile#ref259041">Body</a></li></ul><ul class="list-unstyled" data-level="h2"><li data-target="#ref259042"><a href="/technology/automobile/Chassis">Chassis</a></li></ul><ul class="list-unstyled" data-level="h2"><li data-target="#ref259043"><a href="/technology/automobile/Chassis#ref259043">Engine</a></li></ul><ul class="list-unstyled" data-level="h2"><li data-target="#ref259044"><a href="/technology/automobile/Chassis#ref259044">Fuel</a></li></ul><ul class="list-unstyled" data-level="h2"><li data-target="#ref259045"><a href="/technology/automobile/Chassis#ref259045">Lubrication</a></li></ul><ul class="list-unstyled" data-level="h2"><li data-target="#ref259046"><a href="/technology/automobile/Cooling-system">Cooling system</a></li></ul><ul class="list-unstyled" data-level="h2"><li data-target="#ref259047"><a href="/technology/automobile/Cooling-system#ref259047">Electrical system</a></li></ul><ul class="list-unstyled" data-level="h2"><li data-target="#ref259048"><a href="/technology/automobile/Transmission">Transmission</a></li></ul><ul class="list-unstyled" data-level="h2"><li data-target="#ref259049"><a href="/technology/automobile/Transmission#ref259049">Other mechanical subsystems</a><ul class="list-unstyled" data-level="h3"><li data-target="#ref259050"><a href="/technology/automobile/Transmission#ref259050">Axles</a></li></ul><ul class="list-unstyled" data-level="h3"><li data-target="#ref259051"><a href="/technology/automobile/Brakes">Brakes</a></li></ul><ul class="list-unstyled" data-level="h3"><li data-target="#ref259052"><a href="/technology/automobile/Brakes#ref259052">Steering</a></li></ul><ul class="list-unstyled" data-level="h3"><li data-target="#ref259053"><a href="/technology/automobile/Brakes#ref259053">Suspension</a></li></ul></li></ul><ul class="list-unstyled" data-level="h2"><li data-target="#ref259054"><a href="/technology/automobile/Tires">Tires</a></li></ul><ul class="list-unstyled" data-level="h2"><li data-target="#ref259055"><a href="/technology/automobile/Tires#ref259055">Security systems</a></li></ul><ul class="list-unstyled" data-level="h2"><li data-target="#ref259056"><a href="/technology/automobile/Tires#ref259056">Safety systems</a></li></ul><ul class="list-unstyled" data-level="h2"><li data-target="#ref259057"><a href="/technology/automobile/Emission-controls">Emission controls</a></li></ul><ul class="list-unstyled" data-level="h2"><li data-target="#ref259058"><a href="/technology/automobile/Emission-controls#ref259058">Electric and hybrid vehicles</a></li></ul><ul class="list-unstyled" data-level="h2"><li data-target="#ref259059"><a href="/technology/automobile/Emission-controls#ref259059">Experimental systems</a></li></ul></li><li data-target="#ref64377"><a href="/technology/automobile/History-of-the-automobile">History of the automobile</a><ul class="list-unstyled" data-level="h2"><li data-target="#ref259060"><a href="/technology/automobile/History-of-the-automobile#ref259060">The age of steam</a></li></ul><ul class="list-unstyled" data-level="h2"><li data-target="#ref259061"><a href="/technology/automobile/Early-electric-automobiles">Early electric automobiles</a></li></ul><ul class="list-unstyled" data-level="h2"><li data-target="#ref259062"><a href="/technology/automobile/Early-electric-automobiles#ref259062">Development of the gasoline car</a><ul class="list-unstyled" data-level="h3"><li data-target="#ref259063" class="has-children"><a href="/technology/automobile/Early-electric-automobiles#ref259063">Germany</a><ul class="list-unstyled" data-level="h4"><li data-target="#ref259064"><a href="/technology/automobile/Early-electric-automobiles#ref259064" ...
#
#
#
#                 </div>
#             </div>
#         </div>
#
#
#
#
#
#
#                 <div class="SUMMARY js-section section col-auto">
#                     <div class="h-100 d-flex flex-column">
#                         <div class="section-title border-bottom bg-white col-auto d-flex justify-content-between align-items-center">
#                             <a
#                                 href="/summary/automobile"
#                                 class="border-white border-left-5 label px-15 py-10 text-black link-blue d-inline-flex align-items-center"
#
#                             >
#                                 <em class="material-icons group-icon mr-5 SUMMARY" data-icon=""></em>
# 	Fast Facts
#                             </a>
#                             <button aria-label="expand/collapse panel" class="js-toggle-btn toggle-btn btn btn-unstyled pe-auto col h-100 justify-content-end">
#                                 <div class="btn btn-circle btn-outline-navy btn-sm mr-15 border-gray-200">
#                                     <em class="material-icons toggle-icon" data-icon="expand_more"></em>
#
#                                 </div>
#                             </button>
#                         </div>
#                         <div class="section-content">
#                             <ul class="list-unstyled mb-0 pb-10">
#
#                                     <li data-target="#automobile">
#                                         <a href="/summary/automobile" >2-Min Summary</a>
#                                     </li>
#
#                                     <li data-target="#facts-automobile">
#                                         <a href="/facts/automobile" >Facts & Related Content</a>
#                                     </li>
#
#                             </ul>
#                         </div>
#                     </div>
#                 </div>
#
#
#                 <div class="MEDIA js-section section col-auto">
#                     <div class="h-100 d-flex flex-column">
#                         <div class="section-title border-bottom bg-white col-auto d-flex justify-content-between align-items-center">
#                             <a
#                                 href="/technology/automobile/images-videos"
#                                 class="border-white border-left-5 label px-15 py-10 text-black link-blue d-inline-flex align-items-center"
#
#                             >
#                                 <em class="material-icons group-icon mr-5 MEDIA" data-icon=""></em>
# 	Media
#                             </a>
#                             <button aria-label="expand/collapse panel" class="js-toggle-btn toggle-btn btn btn-unstyled pe-auto col h-100 justify-content-end">
#                                 <div class="btn btn-circle btn-outline-navy btn-sm mr-15 border-gray-200">
#                                     <em class="material-icons toggle-icon" data-icon="expand_more"></em>
#
#                                 </div>
#                             </button>
#                         </div>
#                         <div class="section-content">
#                             <ul class="list-unstyled mb-0 pb-10">
#
#                                     <li data-target="#Videos-automobile">
#                                         <a href="/technology/automobile/images-videos#Videos" >Videos</a>
#                                     </li>
#
#                                     <li data-target="#Images-automobile">
#                                         <a href="/technology/automobile/images-videos#Images" >Images</a>
#                                     </li>
#
#                             </ul>
#                         </div>
#                     </div>
#                 </div>
#
#
#                 <div class="INFO js-section section col-auto">
#                     <div class="h-100 d-flex flex-column">
#                         <div class="section-title border-bottom bg-white col-auto d-flex justify-content-between align-items-center">
#                             <a
#                                 href="/technology/automobile/additional-info"
#                                 class="border-white border-left-5 label px-15 py-10 text-black link-blue d-inline-flex align-items-center"
#                                 rel="nofollow"
#                             >
#                                 <em class="material-icons group-icon mr-5 INFO" data-icon=""></em>
# 	Additional Info
#                             </a>
#                             <button aria-label="expand/collapse panel" class="js-toggle-btn toggle-btn btn btn-unstyled pe-auto col h-100 justify-content-end">
#                                 <div class="btn btn-circle btn-outline-navy btn-sm mr-15 border-gray-200">
#                                     <em class="material-icons toggle-icon" data-icon="expand_more"></em>
#
#                                 </div>
#                             </button>
#                         </div>
#                         <div class="section-content">
#                             <ul class="list-unstyled mb-0 pb-10">
#
#                                     <li data-target="#Additional-Reading">
#                                         <a href="/technology/automobile/additional-info#Additional-Reading" rel="nofollow">Additional Reading</a>
#                                     </li>
#
#                                     <li data-target="#More-Articles">
#                                         <a href="/technology/automobile/additional-info#More-Articles" rel="nofollow">More Articles On This Topic</a>
#                                     </li>
#
#                                     <li data-target="#contributors-automobile">
#                                         <a href="/technology/automobile/additional-info#contributors" rel="nofollow">Contributors</a>
#                                     </li>
#
#                                     <li data-target="#history-automobile">
#                                         <a href="/technology/automobile/additional-info#history" rel="nofollow">Article History</a>
#                                     </li>
#
#                             </ul>
#                         </div>
#                     </div>
#                 </div>
#
#
#
#
#     </div>
#
#
#
#     </div>
#     <button class="drawerToggle btn position-sticky btn-navy btn-circle rounded d-none d-sm-flex " type="button" aria-label="Toggle Drawer">
#         <em class="material-icons " data-icon="keyboard_arrow_left"></em>
#
#     </button>
# </div>
#
#
# </div>
#
#                 <div class="col pt-50 pt-sm-0">
#                     <div class="container p-0 p-sm-30">
#
#                         <div class="grid gx-0 gx-sm-20">
#                             <div class="col-sm">
#                                 <div class="infinite-pagination-container">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 		<script type="application/ld+json">
# 		{
# 			"@context" : "https://schema.org",
# 			"@type" : "BreadcrumbList",
# 			"itemListElement" :
# 			[
#
#
# 			{
# 			"@type" : "ListItem",
# 			"position" : 1,
# 			"item" :
# 			{
# 			"@id" : "https://www.britannica.com/browse/Technology",
# 			"name": "Technology"
# 			}
# 			}
#
# 			,
# 			{
# 			"@type" : "ListItem",
# 			"position" : 2,
# 			"item" :
# 			{
# 			"@id" : "https://www.britannica.com/browse/Cars-Vehicles",
# 			"name": "Cars &amp; Other Vehicles"
# 			}
# 			}
#
# 			]
# 		}
# 		</script>
#
#
#
# 	<nav class="breadcrumb ml-20 mt-10 ml-sm-0 mt-sm-0">
# 		<span class="breadcrumb-item ">
# 			<a href="/" class="">Home</a>
# 		</span>
#
# 			<span class="breadcrumb-item ">
#
#
#
# 						<a class="" href="/browse/Technology">Technology</a>
#
#
# 			</span>
#
# 			<span class="breadcrumb-item ">
#
#
#
# 						<a class="" href="/browse/Cars-Vehicles">Cars &amp; Other Vehicles</a>
#
#
# 			</span>
#
# 	</nav>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <div class="grey-box grey-box-top">
# 	<div class="topic-header">
# 	<div>
# 		<h1 class="mb-0">automobile</h1>
#
# 		<div class="caption mt-5">Alternate titles: auto, car, motorcar</div>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <div class="md-topic-tools mt-15 mb-15" data-topic-id="44957">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <button class="js-print-modal-button js-modal btn btn-sm btn-outline-blue border shadow-sm mr-5 pr-10" data-modal="[data-topic-id=44957] .md-print-modal">
#             <em class="material-icons mr-5 ml-n10 my-n5" data-icon="print"></em>
#
#
#                     Print
#         </button>
#
#
#
#                 <div class="md-print-modal size-lg d-none">
# 	<div class="md-modal-body">
# 		<div class="h2 font-serif d-flex align-items-center pb-15 border-bottom">
# 			<em class="material-icons text-blue mr-10">print</em>
# 			Print
# 		</div>
# 		<div class="mt-20 mb-10">
# 			Please select which sections you would like to print:
# 		</div>
# 		<form action="/print/article/44957" method="post" target="_blank" rel="noopener">
# 			<div class="print-box-items">
# 				<ul class="list-unstyled">
# 					<li><label><input class="mr-10" type="checkbox" name="sequence[]" value="0">Table Of Contents</label></li>
# 				</ul>
# 			</div>
# 			<input type="submit" class="btn btn-blue md-disabled" value="Print" />
# 		</form>
# 	</div>
# </div>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <button class="js-modal qa-cite-modal-button btn btn-sm btn-outline-blue border shadow-sm mr-5 pr-10" data-modal="[data-topic-id=44957]  .md-cite-modal">
#             <em class="material-icons mr-5 ml-n10 my-n5" data-icon="verified"></em>
#
#
#     Cite
#         </button>
#
#
#
#
# <div class="md-cite-modal size-lg d-none">
# 	<div class="md-modal-body">
# 		<div class="h2 font-serif d-flex align-items-center pb-15 border-bottom mb-15">
# 			<em class="material-icons text-blue mr-10">verified</em>Cite
# 		</div>
# 		<div class="font-serif">
# 			While every effort has been made to follow citation style rules, there may be some discrepancies.
# 			Please refer to the appropriate style manual or other sources if you have any questions.
# 		</div>
# 		<div class="label mt-20 mb-10">Select Citation Style</div>
# 		<select class="js-citation-format-select form-select">
# 			<option selected value="mla">MLA</option>
# 			<option value="apa">APA</option>
# 			<option value="chicago">Chicago Manual of Style</option>
# 		</select>
#
# 		<div
# 			class="citation font-serif border rounded p-15 mt-20"
# 			data-authors="Ken W. Purdy,
#
# 				 Christopher G. Foster,
#
# 				 Orville C. Cromer,
#
# 				 George C. Cromer"
# 			data-title="automobile"
# 			data-published-date="2 Nov. 2021"
# 			data-url="https://www.britannica.com/technology/automobile"
# 		>
# 			<div class="citation-text"></div>
# 		</div>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <button class="js-copy-citation-button mt-20 btn btn-sm btn-outline-blue border shadow-sm mr-5 pr-10" >
#             <em class="material-icons mr-5 ml-n10 my-n5" data-icon="file_copy"></em>
#
#
# 			<span class="js-citation-status-text">Copy Citation</span>
#         </button>
#
#
#
# 	</div>
# </div>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <button class="js-share-modal-button js-modal  btn btn-sm btn-outline-blue border shadow-sm mr-5 pr-10" data-modal=" .md-share-modal">
#             <em class="material-icons mr-5 ml-n10 my-n5" data-icon="share"></em>
#
#
#             Share
#         </button>
#
#
#
#
#
#
# <div class="md-share-modal size-lg d-none">
#     <div class="md-modal-body">
#         <div class="h2 font-serif d-flex align-items-center pb-15 border-bottom">
#             <em class="material-icons text-blue mr-10" data-icon="share"></em>
#
#             Share
#         </div>
#         <div class="label my-20">Share to social media</div>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <div class="md-social-toolbar-circle d-flex align-items-start inverted"
#      data-value="share"
#      title="automobile"
#      data-url="https://www.britannica.com/technology/automobile"
# >
#
#
#         <a class="social-icon facebook justify-content-center d-flex align-items-center align-self-center" data-provider="facebook" href="https://www.facebook.com/BRITANNICA/" target="_blank" rel="noopener"><span>Facebook</span></a>
#
#
#         <a class="social-icon twitter justify-content-center d-flex align-items-center align-self-center" data-provider="twitter" href="https://twitter.com/britannica" target="_blank" rel="noopener"><span>Twitter</span></a>
#
#
#
#
#
# </div>
#
#
#
#         <div class="label pt-20 mt-20 mb-5 border-top">URL</div>
#         <a class="font-serif text-truncate d-inline-block" href="https://www.britannica.com/technology/automobile">https://www.britannica.com/technology/automobile</a>
#     </div>
# </div>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <button class="js-tooltip btn btn-sm btn-outline-blue border shadow-sm mr-5 pr-10" >
#             <em class="material-icons mr-5 ml-n10 my-n5" data-icon="more_vert"></em>
#
#
#             More
#         </button>
#
#
#
#         <div class="md-more-popover popover popover-sm py-5 px-0 font-14 z-1">
#
#             <button class="js-feedback-modal-button js-modal btn btn-sm btn-link" data-modal=".md-feedback-modal">Give Feedback</button>
#
#                 <button class="js-modal btn btn-sm btn-link" data-modal="[data-topic-id=44957] .md-websites-modal">External Websites</button>
#
#         </div>
#
#         <div class="md-feedback-modal size-lg d-none">
# 	<div class="md-modal-body">
# 		<div class="h2 font-serif pb-15 border-bottom">
# 			Feedback
# 		</div>
#
# 		<form method="post" action="/submission/feedback/44957">
#
# 			<div class="my-20">
# 				Corrections? Updates? Omissions? Let us know if you have suggestions to improve this article (requires login).
# 			</div>
#
# 			<div class="type-menu">
# 				<label for="feedback-type" class="label mb-10">Feedback Type</label>
# 				<select id="feedback-type" class="form-select mb-30" name="feedbackTypeId" required>
# ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <img loading="lazy" src="https://cdn.britannica.com/w:400,h:300,c:crop/16/126216-050-D9865939/Automobiles-John-F-Fitzgerald-Expressway-Massachusetts-Boston.jpg" alt="John F. Fitzgerald Expressway"    />
#
#
# <button class="btn btn-circle position-absolute shadow btn-white" aria-label="Zoom in">
# 									<em class="material-icons link-blue" data-icon="zoom_in"></em>
# 	</button>
# 							</a>
# 							<div class="card-body p-10 font-14">
# 									John F. Fitzgerald Expressway </div>
# 							</div>
# 					</div>
# 				</div>
#
#
#     </div>
#
#
#
#
#
#
#
#
#
#     <button disabled class="prev-button js-prev-button position-absolute btn btn-circle shadow btn-lg btn-blue " aria-label="Previous">
#         <span class="material-icons md-24" data-icon="keyboard_arrow_left"></span>
#     </button>
#     <button disabled class="next-button js-next-button position-absolute btn btn-circle shadow btn-lg btn-blue " aria-label="Next">
#         <span class="material-icons md-24" data-icon="keyboard_arrow_right"></span>
#     </button>
# </div>
#
# </div>
# <div class="text-center py-10">
# 				<a class="font-weight-bold" href="/technology/automobile/images-videos">See all media</a>
# 			</div>
# 		<div class="facts-list pt-20 border-top">
# 		<dl class="js-fact py-5 mb-10 position-relative ">
# 				<dt class="d-inline">Key People:</dt>
# 				<dd class="d-inline">
# 					<span class="fact-item"><a href="/biography/Henry-Ford" topicid="213223">Henry Ford</a></span>
# 							<span class="fact-item"><a href="/biography/Walter-P-Chrysler" topicid="116389">Walter P. Chrysler</a></span>
# 							<span class="fact-item"><a href="/biography/Robert-S-McNamara" topicid="355213">Robert S. McNamara</a></span>
# 							<span class="fact-item"><a href="/biography/Alfred-P-Sloan-Jr" topicid="548879">Alfred P. Sloan, Jr.</a></span>
# 							<span class="fact-item"><a href="/biography/Patricia-Russo" topicid="1013745">Patricia Russo</a></span>
# 							</dd>
# 				<button class="js-more-btn d-none btn btn-unstyled font-12 position-absolute bottom-5 right-0 bg-white" aria-label="Toggle more/less fact data">
# 					...<em class="js-content link-blue">(Show more)</em>
# 				</button>
# 			</dl>
# 		<dl class="js-fact py-5 mb-0 position-relative line-clamp clamp-3">
# 				<dt class="d-inline">Related Topics:</dt>
# 				<dd class="d-inline">
# 					<span class="fact-item"><a href="/technology/Model-T" topicid="387041">Model T</a></span>
# 							<span class="fact-item"><a href="/technology/DeLorean-DMC-12" topicid="2089518">DeLorean DMC-12</a></span>
# 							<span class="fact-item"><a href="/technology/Edsel" topicid="179398">Edsel</a></span>
# 							<span class="fact-item"><a href="/technology/electric-automobile" topicid="182400">electric automobile</a></span>
# 							<span class="fact-item"><a href="/topic/Ford-999" topicid="2173961">Ford 999</a></span>
# 							</dd>
# 				<button class="js-more-btn d-none btn btn-unstyled font-12 position-absolute bottom-5 right-0 bg-white" aria-label="Toggle more/less fact data">
# 					...<em class="js-content link-blue">(Show more)</em>
# 				</button>
# 			</dl>
# 		</div>
# 	<div class="text-center mt-20">
# 			<a class="btn btn-sm btn-outline-blue border" href="/facts/automobile">
# 				See all facts and data &rarr;
# 			</a>
# 		</div>
# 	</div><!--[BEFORE-ARTICLE]--><span class="marker before-article"></span><section id="ref1" data-level="1"><p class="topic-paragraph"><strong><span id="ref527638"></span>automobile</strong>, byname <strong>auto</strong>, also called <strong>motorcar</strong> or <strong>car</strong>,  a usually four-wheeled vehicle designed primarily for passenger <a href="https://www.britannica.com/technology/transportation-technology" class="md-crosslink autoxref">transportation</a> and commonly propelled by an <a href="https://www.britannica.com/technology/internal-combustion-engine" class="md-crosslink autoxref">internal-combustion engine</a> using a volatile fuel.</p><!--[P1]--><span class="marker p1"></span><!--[AM1]--><span class="marker AM1 am-inline"></span><!--[MOD1]--><span class="marker MOD1 mod-inline"></span></section>          <!--[H2]--><span class="marker h2"></span><section id="ref259040" data-level="1"> <h2 class="h1">Automotive design</h2> <p class="topic-paragraph">The modern automobile is a complex technical system employing subsystems with specific <span id="ref527639"></span><a href="https://www.britannica.com/topic/industrial-design" class="md-crosslink">design</a> functions. Some of these consist of thousands of component parts that have evolved from breakthroughs in existing <a href="https://www.britannica.com/technology/technology" class="md-crosslink autoxref">technology</a> or from new technologies such as electronic computers, high-strength plastics, and new alloys of steel and nonferrous metals. Some subsystems have come about as a result of factors such as <a href="https://www.britannica.com/science/air-pollution" class="md-crosslink autoxref">air pollution</a>, safety legislation, and competition between manufacturers throughout the world.</p><!--[P2]--><span class="marker p2"></span><div class="assemblies"><div class="w-100"><figure class="md-assembly card print-false" data-assembly-id="120667"><div class="md-assembly-wrapper" data-type="image"><a style="--aspect-ratio: 16/9" href="https://cdn.britannica.com/84/91384-050-DA3570A0/components-automobile.jpg" class="position-relative d-flex align-items-center justify-content-center media-overlay-link card-media" data-href="/media/1/44957/120667"><img loading="lazy" src="https://cdn.britannica.com/s:690x388,c:crop/84/91384-050-DA3570A0/components-automobile.jpg" alt="automobile" data-width="1600" data-height="853"><button class="btn btn-circle position-absolute shadow btn-white" aria-label="Zoom in"><em class="material-icons link-blue" data-icon="zoom_in"></em></button></a></div><figcaption class="card-body"><a class="md-assembly-title font-weight-bold mb-5 d-inline-block font-16 font-sans-serif media-overlay-link" href="https://cdn.britannica.com/84/91384-050-DA3570A0/components-automobile.jpg" data-href="/media/1/44957/120667">automobile</a><div class="md-assembly-caption text-muted font-14 font-serif">The major functional components of an automobile.</div><cite class="credit d-block mt-5">Encyclopædia Britannica, Inc.</cite></figcaption></figure></div></div><!--[AM2]--><span class="marker AM2 am-inline"></span><a href="/quiz/transportation-and-technology-firsts-quiz" class="info-module quiz-module p-5 d-block border m-sm-50 mb-30">
#     <div class="wrapper p-30">
#         <div class="grid">
#             <div class="col-md-auto col-100 mb-15 mb-sm-0">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <img loading="lazy" src="https://cdn.britannica.com/78/194978-131-7B55B72C/Hindenburg-zeppelin-crashing-1937.jpg" alt="Hindenburg zeppelin crashing, 1937"    />
#
#
# </div>
#             <div class="col-md col-100">
#                 <div class="label text-black font-13 font-weight-bold text-uppercase">Britannica Quiz</div>
#                 <div class="title font-18 font-weight-bold lh-base mb-5" href="/quiz/transportation-and-technology-firsts-quiz">Transportation and Technology Firsts Quiz</div>
#                 <div class="font-14 text-muted lh-base">Where was the first practical subway line in the United States? Who was the first woman to break the&nbsp;sound barrier? Test your knowledge. Take the quiz.</div>
#             </div>
#         </div>
#     </div>
# </a><span class="marker MOD2 mod-inline"></span> <p class="topic-paragraph">Passenger cars have emerged as the primary means of family transportation, with an estimated 1.4 billion in operation worldwide. About one-quarter of these are in the <span id="ref527640"></span><a href="https://www.britannica.com/place/United-States" class="md-crosslink">United States</a>, where more than three trillion miles (almost five trillion kilometres) are traveled each year. In recent years, Americans have been offered hundreds of different models, about half of them from foreign manufacturers. To capitalize on their <a href="https://www.merriam-webster.com/dictionary/proprietary" class="md-dictionary-link md-dictionary-tt-off" data-term="proprietary">proprietary</a> technological advances, manufacturers introduce new designs ever more frequently. With some 70 million new units built each year worldwide, manufacturers have been able to split the market into many very small segments that nonetheless remain profitable.</p><!--[P3]--><span class="marker p3"></span><!--[AM3]--><span class="marker AM3 am-inline"></span><!--[MOD3]--><span class="marker MOD3 mod-inline"></span> <p class="topic-paragraph">New technical developments are recognized to be the key to successful competition. Research and development engineers and scientists have been employed by all automobile manufacturers and suppliers to improve the body, chassis, engine, drivetrain, control systems, safety systems, and emission-control systems.</p><!--[P4]--><span class="marker p4"></span><!--[AM4]--><span class="marker AM4 am-inline"></span><DIV class="marketing-INLINE_SUBSCRIPTION marketing-content" data-marketing-id="INLINE_SUBSCRIPTION"><div class="bc-article-inline-dialogue" style="margin:0 auto 20px auto;height:154px;max-width:800px;"></div></DIV><span class="marker MOD4 mod-inline"></span> <p class="topic-paragraph">These outstanding technical advancements are not made without economic consequences. According to a study by Ward’s Communications Incorporated, the average cost for a new American car increased $4,700 (in terms of the value of the dollar in 2000) between 1980 and 2001 because of <a href="https://www.merriam-webster.com/dictionary/mandated" class="md-dictionary-link md-dictionary-tt-off" data-term="mandated">mandated</a> safety and emission-control performance requirements (such as the addition of air bags and <a href="https://www.britannica.com/technology/catalytic-converter" class="md-crosslink">catalytic converters</a>). New requirements continued to be <a href="https://www.merriam-webster.com/dictionary/implemented" class="md-dictionary-link md-dictionary-tt-off" data-term="implemented">implemented</a> in subsequent years. The addition of computer technology was another factor driving up car prices, which increased by 29 percent between 2009 and 2019. This is in addition to the consumer costs associated with engineering improvements in fuel economy, which may be offset by reduced fuel purchases.</p><!--[P5]--><span class="marker p5"></span><!--[AM5]--><span class="marker AM5 am-inline"></span><!--[MOD5]--><span class="marker MOD5 mod-inline"></span> <p class="topic-paragraph">Vehicle design depends to a large extent on its intended use. Automobiles for off-road use must be durable, simple systems with high resistance to severe overloads and extremes in operating conditions. Conversely, products that are intended for high-speed, limited-access road systems require more passenger comfort options, increased engine performance, and optimized high-speed handling and vehicle stability. Stability depends principally on the distribution of weight between the front and rear wheels, the height of the <a href="https://www.britannica.com/science/centre-of-gravity" class="md-crosslink autoxref">centre of gravity</a> and its position relative to the aerodynamic centre of pressure of the vehicle, suspension characteristics, and the selection of which wheels are used for propuls ...
#
#
# </div>
# </div>
#
#                                 <div class="infinite-pagination-button d-flex justify-content-center border border-top-0">
#                                         <button class="js-load-next btn btn-sm btn-blue mt-30 pr-10 mb-100">
#                                             Load Next Page
#                                             <em class="material-icons " data-icon="keyboard_arrow_down"></em>
# 	</button>
#                                     </div>
#                                 </div>
#
#                             <aside class="col-md-da-300"></aside>
#                         </div>
#                     </div>
#                 </div>
#
#             </div>
#
#         </article></div>
#         </div></div>
# 	    </div>
# 	</main>
#
#     <div id="chatbot-container"></div>
#     <div id="md-footer"></div> <iframe name="__uspapiLocator" style="display:none;height:0;opacity:0;visibility:hidden;border:0;width:0;"></iframe>
# 	<script type="text/javascript">
# 			__ADCMD.push( () => {
# 				__$.setDebug( false );
# 				__AD.initAdsManager();
# 			});
# 		</script>
#
# 		<noscript><iframe src="//www.googletagmanager.com/ns.html?id=GTM-5W6NC8" height="0" width="0" style="display:none;visibility:hidden"></iframe></noscript>
# 		<script type="text/javascript" id="_informizely_script_tag">
# var IzWidget = IzWidget || {};
# (function (d)
# { var scriptElement = d.createElement('script'); scriptElement.type = 'text/javascript'; scriptElement.async = true; scriptElement.src = "https://insitez.blob.core.windows.net/site/f780f33e-a610-4ac2-af81-3eb184037547.js"; var node = d.getElementById('_informizely_script_tag'); node.parentNode.insertBefore(scriptElement, node); }
# )(document);
# </script>
#
# <script src="https://cdn.britannica.com/mendel-resources/3-53/js/libs/jquery-3.5.0.min.js?v=3.53.17"></script>
# <script type="text/javascript" src="https://cdn.britannica.com/mendel-resources/3-53/js/libs/prebid4.12.0.js?v=3.53.17" async="async"></script>
# 	<script type="text/javascript">
# 	window.pbjs = window.pbjs || {};
#     pbjs.que = pbjs.que || [];
# 	</script>
# <script src="//content.jwplatform.com/libraries/DkXxjTZZ.js"></script><script type="text/javascript" data-type="Init Mendel Code Splitting">
#               (function() {
#                 $.ajax({
#                   dataType: 'script',
#                   cache: true,
#                   url: 'https://cdn.britannica.com/mendel-resources/3-53/dist/topic-page.js?v=3.53.17'
#                 });
#               })();
#             </script>
# 		<script type="text/javascript" src="https://www.googletagmanager.com/gtag/js?id=UA-6636134-11" async="async"></script>
#     <script type="text/javascript">
#         function gaPageLoad(pathname, documentLocation) {
#             pathname = pathname || location.pathname;
#             documentLocation = documentLocation || document.querySelector('html').getAttribute('data-ytrk-page');
#
#             if (documentLocation) {
#                 documentLocation = documentLocation.replace(/ /g, '/');
#                 window.dataLayer = window.dataLayer || [];
#
#                 function gtag() {
#                     dataLayer.push(arguments);
#                 }
#
#                 gtag('js', new Date());
#
#                 gtag('set', {
#                     'dimension1': 'ANONYMOUS',
#                     'dimension2': 'C',
#                 });
#
#                 gtag('config', 'UA-6636134-11', {
#                     'page_path': documentLocation + pathname + decodeURI(location.search),
#                     'link_attribution': true,
#                 });
#             }
#         }
#
#         gaPageLoad();
#     </script>
# <script type="text/javascript">
#     EBStat={accountId:-1,hostnameOverride:'webstats.eb.com',domain:'www.britannica.com', json:''};
#     </script>
#
#     <script type="text/javascript">
#             ( function() {
#                 $.ajax( { dataType: 'script', cache: true, url: '//www.britannica.com/webstats/mendelstats.js?v=1' } )
#                  .done( function() {
#                      try {writeStat(null,EBStat);}
#                      catch(err){}
#                  } );
#             })();
#             </script>
#         <script defer src="https://static.cloudflareinsights.com/beacon.min.js" data-cf-beacon='{"rayId":"6a8fd9474e29631a","token":"5cc7d7124de641b181da990fc8c9a0b6","version":"2021.10.0","si":100}'></script>
# </body>
# </html>

# %%
! pip install requests-html
# Out:
# Collecting requests-html
#   Downloading requests_html-0.10.0-py3-none-any.whl (13 kB)
# Requirement already satisfied: requests in /home/barzamini/.pyenv/versions/3.7.6/lib/python3.7/site-packages (from requests-html) (2.26.0)
# Requirement already satisfied: bs4 in /home/barzamini/.pyenv/versions/3.7.6/lib/python3.7/site-packages (from requests-html) (0.0.1)
# Collecting pyppeteer>=0.0.14
#   Downloading pyppeteer-0.2.6-py3-none-any.whl (83 kB)
#      |████████████████████████████████| 83 kB 584 kB/s  eta 0:00:01
# Requirement already satisfied: urllib3<2.0.0,>=1.25.8 in /home/barzamini/.pyenv/versions/3.7.6/lib/python3.7/site-packages (from pyppeteer>=0.0.14->requests-html) (1.26.7)
# Requirement already satisfied: importlib-metadata>=1.4 in /home/barzamini/.pyenv/versions/3.7.6/lib/python3.7/site-packages (from pyppeteer>=0.0.14->requests-html) (3.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.42.1 in /home/barzamini/.pyenv/versions/3.7.6/lib/python3.7/site-packages (from pyppeteer>=0.0.14->requests-html) (4.62.3)
# Collecting appdirs<2.0.0,>=1.4.3
#   Using cached appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Requirement already satisfied: typing-extensions>=3.6.4 in /home/barzamini/.pyenv/versions/3.7.6/lib/python3.7/site-packages (from importlib-metadata>=1.4->pyppeteer>=0.0.14->requests-html) (3.7.4.3)
# Requirement already satisfied: zipp>=0.5 in /home/barzamini/.pyenv/versions/3.7.6/lib/python3.7/site-packages (from importlib-metadata>=1.4->pyppeteer>=0.0.14->requests-html) (3.4.0)
# Collecting pyee<9.0.0,>=8.1.0
#   Downloading pyee-8.2.2-py2.py3-none-any.whl (12 kB)
# Collecting websockets<10.0,>=9.1
#   Downloading websockets-9.1-cp37-cp37m-manylinux2010_x86_64.whl (103 kB)
#      |████████████████████████████████| 103 kB 44.4 MB/s eta 0:00:01
# Requirement already satisfied: beautifulsoup4 in /home/barzamini/.pyenv/versions/3.7.6/lib/python3.7/site-packages (from bs4->requests-html) (4.10.0)
# Requirement already satisfied: soupsieve>1.2 in /home/barzamini/.pyenv/versions/3.7.6/lib/python3.7/site-packages (from beautifulsoup4->bs4->requests-html) (2.2.1)
# Collecting fake-useragent
#   Downloading fake-useragent-0.1.11.tar.gz (13 kB)
# Collecting parse
#   Downloading parse-1.19.0.tar.gz (30 kB)
# Collecting pyquery
#   Downloading pyquery-1.4.3-py3-none-any.whl (22 kB)
# Collecting cssselect>0.7.9
#   Downloading cssselect-1.1.0-py2.py3-none-any.whl (16 kB)
# Collecting lxml>=2.1
#   Downloading lxml-4.6.4-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (6.3 MB)
#      |████████████████████████████████| 6.3 MB 60.3 MB/s eta 0:00:01
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/barzamini/.pyenv/versions/3.7.6/lib/python3.7/site-packages (from requests->requests-html) (2.0.7)
# Requirement already satisfied: idna<4,>=2.5 in /home/barzamini/.pyenv/versions/3.7.6/lib/python3.7/site-packages (from requests->requests-html) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /home/barzamini/.pyenv/versions/3.7.6/lib/python3.7/site-packages (from requests->requests-html) (2021.10.8)
# Collecting w3lib
#   Downloading w3lib-1.22.0-py2.py3-none-any.whl (20 kB)
# Requirement already satisfied: six>=1.4.1 in /home/barzamini/.pyenv/versions/3.7.6/lib/python3.7/site-packages (from w3lib->requests-html) (1.15.0)
# Using legacy 'setup.py install' for fake-useragent, since package 'wheel' is not installed.
# Using legacy 'setup.py install' for parse, since package 'wheel' is not installed.
# Installing collected packages: websockets, pyee, lxml, cssselect, appdirs, w3lib, pyquery, pyppeteer, parse, fake-useragent, requests-html
#     Running setup.py install for parse ... done
#     Running setup.py install for fake-useragent ... done
# Successfully installed appdirs-1.4.4 cssselect-1.1.0 fake-useragent-0.1.11 lxml-4.6.4 parse-1.19.0 pyee-8.2.2 pyppeteer-0.2.6 pyquery-1.4.3 requests-html-0.10.0 w3lib-1.22.0 websockets-9.1
# WARNING: You are using pip version 20.3.3; however, version 21.3.1 is available.
# You should consider upgrading via the '/home/barzamini/.pyenv/versions/3.7.6/bin/python3.7 -m pip install --upgrade pip' command.

# %%
import requests_html
import csv

# %%
import asyncio
# import HTMLSession from requests_html
from requests_html import AsyncHTMLSession

if asyncio.get_event_loop().is_running(): # Only patch if needed (i.e. running in Notebook, Spyder, etc)
    import nest_asyncio
    nest_asyncio.apply()

urls = ["https://www.britannica.com/technology/automobile"]
    
async def work(s, url):
    resp = await s.get(url)
    resp.html.arender()
    return resp
    
async def main(urls):
    asession = AsyncHTMLSession()
    task = (work(asession, url) for url in urls)
    return await asyncio.gather(*task)

# %%
results = asyncio.run(main(urls))
# Out:
# /home/barzamini/.pyenv/versions/3.7.6/lib/python3.7/site-packages/ipykernel_launcher.py:13: RuntimeWarning: coroutine 'HTML.arender' was never awaited
#   del sys.path[0]
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback

# %%
import asyncio
# import HTMLSession from requests_html
from requests_html import AsyncHTMLSession

if asyncio.get_event_loop().is_running(): # Only patch if needed (i.e. running in Notebook, Spyder, etc)
    import nest_asyncio
    nest_asyncio.apply()

# create an HTML Session object
asession = AsyncHTMLSession()
 
# Use the object above to connect to needed webpage
r = await asession.get("https://www.britannica.com/technology/automobile")
    
# Run JavaScript code on webpage
# resp.html.arender()

# %%
from requests_html import HTMLSession
# create an HTML Session object
session = HTMLSession()
 
# Use the object above to connect to needed webpage
resp = session.get("https://www.britannica.com/technology/automobile")
    
# Run JavaScript code on webpage
# resp.html.arender()

# %%
import requests
from bs4 import BeautifulSoup

# %%
URL = "https://www.britannica.com/technology/automobile"
page = requests.get(URL)

# %%
soup = BeautifulSoup(page.content, "html.parser")
soup
# Out:
# <!DOCTYPE html>
#
# <html class="ui-unknown0 ui-unknown" data-ytrk-page="TOPIC PAGINATED LARGE" lang="en">
# <head prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb#">
# <meta charset="utf-8"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type">
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta content="74442380906" property="fb:pages"/>
# <link href="https://cdn.britannica.com/mendel-resources/3-53" rel="dns-prefetch"/>
# <link href="https://cdn.britannica.com/mendel-resources/3-53" rel="preconnect"/>
# <meta content="Automobile, or car, a usually four-wheeled vehicle designed primarily for passenger transportation and commonly propelled by an internal-combustion engine using a volatile fuel. Learn more about automotive design and the history of cars in this article." name="description"/>
# <meta content="automobile, encyclopedia, encyclopeadia, britannica, article" name="keywords"/>
# <link href="https://www.britannica.com/technology/automobile" rel="canonical">
# <script data-type="Init Mendel" type="text/javascript">
#
#     window.$UI = {};
#
#     window.Constants = {"LICENSE_URL": "/bps/license","DEFAULT_TEST_VERSION": "A","DEFAULT_STATE": "XX","QUIZ_URL": "/quiz","SPOTLIGHT_BROWSE_URL": "/stories/spotlight","CONTENT_TYPE_TEXT": "text/plain;charset=UTF-8","TOPIC_MEDIA_PATH": "/images-videos","DEBUG_URL": "/debug","ERROR_404_URL": "/error404","TOPIC_QUOTES_PATH": "/quotes","INSTANT_ARTICLES_URL": "/instant-articles","TOPIC_PAGE_CONTENT_AJAX_URL": "/topic-content/page","INFINITE_SCROLL_PREFIX_URL": "/scroll","CC_USD": "USD","SURVEY_URL": "/survey","CATEGORY_BROWSE_URL": "/browse","STORY_BROWSE_URL": "/stories","IN_THIS_WEEK_BROWSE_URL": "/week-in-review","COUNTRY_US": "US","OPEN_MEDIA_OVERLAY_PARAMETER": "/media","FACTS_URL": "/facts","GAMES_BROWSE_WORDSEARCH_URL": "/games/Word-Search","NEWSLETTER_SUBSCRIPTION_URL": "/newsletter-subscription","INSIGHTS_LANDING_PAGE_URL_2": "/factsmatter","HOMEPAGE_VIDEO_ADMIN_URL": "/homepage-videos-admin","INSIGHTS_LANDING_PAGE_URL_1": "/insights","MAINTENANCE_ERROR_URL": "https://maintenance.eb.com","IMARS_EDITOR_ID": "12365882","PROFILE_EB_EDITOR_URL": "/editor","WEB_INF_RESOURCES_PATH": "WEB-INF/resources","TOPIC_ADDITIONAL_INFO_PATH": "/additional-info","CC_INR": "INR","ARTICLE_PRINT_URL": "/print/article","FIRST_EDITION_URL": "/subscriber/firstedition","WW1_PORTAL_URL": "/discover/World-War-I","PROFILE_USER_URL": "/user","MENDEL_COOKIE": "__mendel","DEMYSTIFIED_BROWSE_URL": "/stories/demystified","LIST_BROWSE_URL": "/list/browse","PROFILE_EXPERT_URL": "/contributor","USER_PROFILE_PICTURE_URL": "/image/profile","ASSEMBLY_IMAGE_URL": "/image/assembly","DAY_IN_HISTORY_URL": "/on-this-day","DEFAULT_CURRENCY": "USD","GAMES_HOMEPAGE_URL": "/games","CONTENT_TYPE_XML": "text/xml;charset=UTF-8","AJAX_PREFIX_URL": "/ajax","TOPIC_BROWSE_URL": "/topic-browse","MARKETING_CONTENT": "/marketing-content","ENV_RUNTIME": "runtime","USER_PROFILE_PARTNER_LOGO_URL": "/image/profile-partner","GALLERY_URL": "/gallery","CONTENT_TYPE_HTML": "text/html;charset=UTF-8","ENV_LOCAL": "override","MEDIA_OVERLAY_URL": "/media-overlay","ENV_DEV": "development","MEDIA_URL": "/media","PODCASTS_URL": "/podcasts","STAND_ALONE_VIDEO_URL": "/video","MORE_ON_THIS_DAY_URL": "/more-on-this-day","SEARCH_PAGE_URL": "/search","TOPIC_CONTENT_AJAX_URL": "/topic-content/topic","ENV_BRANCH": "branch","ERROR_URL": "/error","MAIN_VERSION": "mainVersion","DEFAULT_S3_REGION": "US_EAST_1","LOGINBOX_URL": "/auth/loginbox","QUIZ_BROWSE_URL": "/quiz/browse","BIO_BROWSE_URL": "/biographies","LIST_URL": "/list","ALPHA_BROWSE_URL": "/sitemap","GAME_URL": "/game","CONTENT_TYPE_JSON": "application/json","COBRAND_IMAGE_URL": "/image/cobrand","SUBMISSION_URL": "/submission","EB_LOG_OUT": "/auth2/logout","ENV_PRODUCTION": "production","CONTENTFUL_ADMIN_PREFIX_URL": "/contentful-admin","TOPIC_AJAX_URL": "/ajax/topic","GAMES_BROWSE_CROSSWORD_URL": "/games/Crossword-Puzzle","WTFACT_BROWSE_URL": "/stories/wtfact","FEATURED_CONTENT_ADMIN_URL": "/fc-admin","VIDEO_CHANNEL_URL": "/videos","GALLERY_BROWSE_URL": "/gallery/browse","CACHE_URL": "/cache","COMPANION_BROWSE_URL": "/stories/companion","MEDIA_FOLDER": "/eb-media","SHOW_ALL_CONTRIBUTORS": "/additional-info#contributors","BRITANNICA_EDITORS_ID": "4419","EXPLORE_BROWSE": "/explore","TOPIC_SUMMARY_URL": "/summary","ENV_CACHE_DISABLED": "mendelCache","STORY_URL": "/story","DEFAULT_COUNTRY": "US","NAVBAR_URL": "/ajax/navbar","EB_LOGIN_URL": "/auth/eb-login","NEW_ARTICLES_URL": "/new-articles",};
#     window.CDN = "https://cdn.britannica.com";
#     window.CAM_LOGIN_URL = "https://cam.britannica.com";
#     window.CAM_SIGN_UP_URL = "https://cam.britannica.com/registration"
#
#     window.Mendel = {
#      	"config" : {
# 			"page": "Topic",
# 			"videoPlayerId": "DkXxjTZZ",
# 			"sharedUrl": "https://www.britannica.com/technology/automobile",
# 	        "resourcesPrefixUrl": "https://cdn.britannica.com/mendel-resources/3-53/[url]?v=3.53.17",
# 			"userInfo": { "type": "ANONYMOUS"
# 			             ,"currency": "USD"
# 			             ,"country": "US"
# 					     ,"state": "IL"
# 			             ,"bcomId": "-1202384376230855234"
# 				         ,"hasAds": true
# 					     ,"testVersion": "B"
# 				         ,"privacyInfo": {"consentLocation":false,"gdpr":false,"ccpa":false,"needConsent":false}
# 						 ,"consumerId": ""
# 						 ,"instId": ""
# 						 ,"consumerUserName": ""
# 						 ,"instUserName": ""
# 			},
# 			"isLoggedInAsUser": false,
# 			"analytics": {  "gaId": "UA-6636134-11" },
# 			"isPhone": false,
# 			"isDesktop": true,
# 			"logoutUrl": "/auth2/logout",
# 			"selfServiceUrl": "https://myaccount.britannica.com",
# 			"cdnUrl": "https://cdn.britannica.com",
# 	        "fetchOffset": 800,
# 	        "isMetered": true,
#
# 			"mendelCookieName": "__mendel",
# 			"mendelCookie": {"pagesViewed":1,"surveyShown":false,"topicInitialSequence":1},
#
#
# 			"autocompleteToSearchPage": false,"topicUrl": "/technology/automobile"
#         ,"freeTopicReason": "NO_REFERRER"
#         ,"topicId": 44957
# 	    ,"template": "DESKTOP"
# 	    ,"type": "CORE"
# 	    ,"hasEditMode": false
# 		,"hasToc": true,"infiniteScrollList": [{"p":13,"t":44957},{"p":1,"t":371219},{"p":1,"t":213238},{"p":1,"t":1666233},{"p":1,"t":67416},{"p":1,"t":507195},{"p":1,"t":14594},{"p":1,"t":315736},{"p":1,"t":1952506},{"p":1,"t":557506}]
#         ,"sequence": 1
#         ,"topics": {}
# 		},
# 		chatbot: {
# 			answerService: {
# 				url: 'https://chatbot.api.eb.com/api/qna',
# 				apiKey: 'YH4dIgRoMX77z56YfLcz24aur7nONAEI6lziQKpX',
# 			},
# 			feedbackService: {
# 				url: 'https://4ltuaewqxb.execute-api.us-east-1.amazonaws.com/production/feedback',
# 				apiKey: 'YYFYIE3qaS4i6vGDOj2TE1kPBYpSWkK68Uy2L0ME',
# 			},
# 		}
#     };
#
# 	</script>
# <script class="marketing-page-info" type="application/json">
# {"pageType":"Topic","templateName":"DESKTOP","pageNumber":1,"pagesTotal":13,"pageId":44957,"pageLength":985,"initialLoad":true,"metered":true}
# </script>
# <script class="marketing-content-info" type="application/json">
# [{"id":1012,"name":"SUBSCRIPTION_LINK_DESKTOP","selector":"#fake"}]
# </script>
# <script>
# 	Mendel.BC = {"loggedIn":false,"category":"Cars & Other Vehicles","lastUpdated":"Nov 02, 2021","contributorName":"Christopher G. Foster"}</script><meta content="1887621861548296" property="fb:app_id"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="@britannica" name="twitter:site"/>
# <meta content="https://cdn.britannica.com/16/126216-050-D9865939/Automobiles-John-F-Fitzgerald-Expressway-Massachusetts-Boston.jpg" name="twitter:image"/>
# <meta content="Automobile, or car, a usually four-wheeled vehicle designed primarily for passenger transportation and commonly propelled by an internal-combustion engine using a volatile fuel. Learn more about automotive design and the history of cars in this article." name="twitter:description"/>
# <meta content="ARTICLE" property="og:type"/>
# <meta content="automobile | Definition, History, Industry, Design, &amp; Facts" property="og:title"/>
# <meta content="Automobile, or car, a usually four-wheeled vehicle designed primarily for passenger transportation and commonly propelled by an internal-combustion engine using a volatile fuel. Learn more about automotive design and the history of cars in this article." property="og:description"/>
# <meta content="Encyclopedia Britannica" property="og:site_name"/>
# <meta content="https://www.britannica.com/technology/automobile" property="og:url"/>
# <meta content="https://cdn.britannica.com/16/126216-050-D9865939/Automobiles-John-F-Fitzgerald-Expressway-Massachusetts-Boston.jpg" property="og:image"/>
# <meta content="image/jpeg" property="og:image:type"/>
# <script data-type="init opengraph" type="text/javascript">
# 	Mendel.openGraph = {"type":"ARTICLE","title":"automobile | Definition, History, Industry, Design, & Facts","description":"Automobile, or car, a usually four-wheeled vehicle designed primarily for passenger transportation and commonly propelled by an internal-combustion engine using a volatile fuel. Learn more about automotive design and the history of cars in this article.","imageUrl":"https://cdn.britannica.com/16/126216-050-D9865939/Automobiles-John-F-Fitzgerald-Expressway-Massachusetts-Boston.jpg","imageType":"image/jpeg","pageUrl":"https://www.britannica.com/technology/automobile"}</script>
# <title>automobile | Definition, History, Industry, Design, &amp; Facts | Britannica</title>
# <link href="https://fonts.googleapis.com/" rel="preconnect"/>
# <link href="https://fonts.googleapis.com/" rel="dns-prefetch"/>
# <link href="https://fonts.googleapis.com/icon?family=Material+Icons" rel="stylesheet"/>
# <link href="https://cdn.britannica.com/mendel-resources/3-53/dist/vendor-bundle.css?v=3.53.17" rel="stylesheet">
# <link href="https://cdn.britannica.com/mendel-resources/3-53/dist/mendel-css.css?v=3.53.17" rel="stylesheet">
# <link href="https://cdn.britannica.com/mendel-resources/3-53/dist/topic-page.css?v=3.53.17" rel="stylesheet">
# <script type="text/javascript">
#         if ('scrollRestoration' in history) { history.scrollRestoration = 'manual'; }
#     </script>
# <script async="" src="https://www.googleoptimize.com/optimize.js?id=OPT-N7CJGBC"></script>
# <script charset="UTF-8" src="https://cdn.britannica.com/mendel-resources/3-53/js/iab.js?v=3.53.17" type="text/javascript"></script>
# <script type="text/javascript">
# googletag = {
#   cmd: []
# };
# </script>
# <script class="ads-script" type="application/json">
# {"ORATV":[{"id":111,"type":"ORATV","selector":".AM3","injector":"after","displayType":"REGULAR"}],"DFP":[{"id":26,"type":"DFP","selector":".infinite-scroll-container.article.last aside","injector":"append","adParameters":{"targeting":{"TEMPLATE":"1","ARTICLE":"44957"},"size":[[300,250]],"cssClass":"sticky-da-bot","pos":"BOT","replace":"true","global":"true","id":"DESKTOP"},"displayType":"REGULAR"},{"id":106,"type":"DFP","selector":".pl728","injector":"prepend","adParameters":{"targeting":{"TEMPLATE":"1","ARTICLE":"44957"},"size":[[728,90],[970,250]],"pos":"TOP","id":"DESKTOP"},"displayType":"REGULAR"},{"id":178,"type":"DFP","selector":".infinite-scroll-container.article.last aside","injector":"prepend","adParameters":{"targeting":{"TEMPLATE":"1","ARTICLE":"44957"},"size":[[300,250]],"cssClass":"sticky-da","pos":"TOP","replace":"true","global":"true","id":"DESKTOP"},"displayType":"REGULAR"},{"id":182,"type":"DFP","injector":"after","adParameters":{"targeting":{"TEMPLATE":"1","ARTICLE":"44957"},"size":[[728,90]],"pos":"CATFISH","id":"DESKTOP"},"displayType":"STATIC_CATFISH"}]}</script>
# <script type="text/javascript">
# 	Mendel.AD = {
# 	    providers : {},
# 		managers  : {},
# 		display  :  {},
# 	    cmd       : [],
# 		info      : {
#
# 	"catfishTimeout"     : 60,
# 	"catfish2CloseButtonTimeout": 65,
# 	"googleGPTId"        : "15510053",
# 	"googleAdsId"        : "0081271244777268",
# 	"dfpLazyLoad"        : false,
# 	"dfpLazyLoadParams"  : {fetchMarginPercent:300,renderMarginPercent:200,mobileScaling:2.0},
# 	"dfpUnitPrefix"      : "",
# 	"catfishShown"       : false,
# 	"prerollAd"          : true && Mendel.config.isDesktop,
# 	"oraTvCodeVersion"   : 2,
# 	"analytics"          : ["oratv"]
# 	,"refreshInfo"       : [{"refreshType":"PAGE","max":12,"timer":30,"parameters":{
# "newAdUnit": true
# }}]
# 	,"a9Id"              : "3022"
#
# 					}
# 	};
#
# 	__ADMANAGERS  = Mendel.AD.managers;
# 	__ADPROVIDERS = Mendel.AD.providers;
# 	__ADINFO      = Mendel.AD.info;
# 	__ADREFRESH   = Mendel.AD.info.refreshInfo;
# 	__ADCMD       = Mendel.AD.cmd;
# </script>
# <script src="//js-sec.indexww.com/ht/htw-britannica.js" type="text/javascript"></script>
# <script src="https://securepubads.g.doubleclick.net/tag/js/gpt.js"></script>
# <script src="//c.amazon-adsystem.com/aax2/apstag.js" type="text/javascript"></script>
# <script data-type="Amazon a9" type="text/javascript">
# 	!function(a9,a){if(a[a9])return;function q(c,r){a[a9]._Q.push([c,r])}a[a9]={init:function(){q("i",arguments)},fetchBids:function(){q("f",arguments)},setDisplayBids:function(){},targetingKeys:function(){return[]},_Q:[]};}("apstag",window);
# 	</script>
# <script src="https://cdn.britannica.com/mendel-resources/3-53/dist/mam.js?v=3.53.17" type="text/javascript"></script>
# <script async="" data-e="5" data-key="12ca4747-8e80-4a36-b550-dc239c18b954" id="ns_script_dc" src="//includemodal.global.ssl.fastly.net/sp.js" type="text/javascript"></script>
# <script type="text/javascript">
# 		!(function(o,n,t){t=o.createElement(n),o=o.getElementsByTagName(n)[0],t.async=1,t.src="https://superficialsquare.com/v2efnImPApSzhnLlHe1yjXrMv18oN6sVdzmho_QRB6Zxhy_rgT68LFVeCAMempYpY",o.parentNode.insertBefore(t,o)})(document,"script"),(function(o,n){o[n]=o[n]||function(){(o[n].q=o[n].q||[]).push(arguments)}})(window,"admiral");!(function(c,e,o,t,n){function r(o,t){(function n(){try{return 0<(localStorage.getItem("v4ac1eiZr0")||"").split(",")[4]}catch(o){}return!1})()&&(t=c[e].pubads())&&t.setTargeting("admiral-engaged","true")}(n=c[e]=c[e]||{}).cmd=n.cmd||[],typeof n.pubads===o?r():typeof n.cmd.unshift===o?n.cmd.unshift(r):n.cmd.push(r)})(window,"googletag","function");
# 	</script>
# <script>
# 	            dataLayer = [];
#             </script>
# <script type="text/javascript">(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# 		       new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# 		       j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 		       '//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# 		   })(window,document,'script','dataLayer','GTM-5W6NC8');
# 		   </script>
# <script type="text/javascript">
# 	window._vwo_code = window._vwo_code || (function(){
# 	var account_id=331471,
# 	settings_tolerance=2000,
# 	library_tolerance=2500,
# 	use_existing_jquery=false,
# 	is_spa=1,
# 	hide_element='none',
#
# 	f=false,d=document,code={use_existing_jquery:function(){return use_existing_jquery;},library_tolerance:function(){return library_tolerance;},finish:function(){if(!f){f=true;var a=d.getElementById('_vis_opt_path_hides');if(a)a.parentNode.removeChild(a);}},finished:function(){return f;},load:function(a){var b=d.createElement('script');b.src=a;b.type='text/javascript';b.innerText;b.onerror=function(){_vwo_code.finish();};d.getElementsByTagName('head')[0].appendChild(b);},init:function(){
# 	window.settings_timer=setTimeout('_vwo_code.finish()',settings_tolerance);var a=d.createElement('style'),b=hide_element?hide_element+'{opacity:0 !important;filter:alpha(opacity=0) !important;background:none !important;}':'',h=d.getElementsByTagName('head')[0];a.setAttribute('id','_vis_opt_path_hides');a.setAttribute('type','text/css');if(a.styleSheet)a.styleSheet.cssText=b;else a.appendChild(d.createTextNode(b));h.appendChild(a);this.load('https://dev.visualwebsiteoptimizer.com/j.php?a='+account_id+'&u='+encodeURIComponent(d.URL)+'&f='+(+is_spa)+'&r='+Math.random());return settings_timer; }};window._vwo_settings_timer = code.init(); return code; }());
# </script>
# <meta content="2021-11-02" http-equiv="last-modified"/></link></link></link></link></meta></head>
# <body class="new-topic topic-desktop first-page-true user-ANONYMOUS user-ads md-desktop leg-b chatbot-enabled" data-leg="B">
# <script id="json-navbar-info" type="application/json">
# {"extraLinks":[{"title":"Quizzes","url":"/quiz/browse"},{"title":"Games","url":"/games"},{"title":"On This Day","url":"/on-this-day"}],"featureLinks":[{"title":"Quizzes","url":"/quiz/browse","description":"Can you get to the top of the leaderboard?"},{"title":"Games","url":"/games","description":"Cryptic crosswords and more. Happy puzzling!"},{"title":"Podcasts","url":"/podcasts","description":"Stay curious on the go."},{"title":"On This Day","url":"/on-this-day","description":"What happened on your birthday?"},{"title":"Biographies","url":"/biographies","description":"Explore extraordinary lives."},{"title":"Week In Review","url":"/week-in-review","description":"A weekly recap of key events and fun facts."},{"title":"Topic Summaries","url":"/summary","description":"Summaries, quick-facts, and timelines on key topics"},{"title":"Infographics","url":"https://www.britannica.com/study/infographics","description":"Explore the world through maps, charts, and graphs.","newTab":true},{"title":"Demystified","url":"/stories/demystified","description":"Insight into some of life's big mysteries."},{"title":"Lists","url":"/list/browse","description":"Find out what tops our Editors’ lists. "},{"title":"#WTFact","url":"/stories/wtfact","description":"Stories so weird you’ll exclaim: “What the Fact!”"},{"title":"Companions","url":"/stories/companion","description":"A more concise complement to our top articles."},{"title":"Image Galleries","url":"/gallery/browse","description":"Browse editorially curated collections."},{"title":"Spotlight","url":"/stories/spotlight","description":"Get more context behind trending news and events."},{"title":"The Forum","url":"/stories/the-forum","description":"Analysis, research, and ideas from leading experts."}],"featuredFeature":{"title":"Why Do Some Cicadas Appear Only Every 17 Years?","url":"/story/why-do-some-cicadas-appear-only-every-17-years","description":"Demystified / Science","image":{"id":0,"url":"/54/222554-131-1976D74D/periodical-cicada.jpg","altText":"Periodical Cicada, Adult, Magicicada spp. Requires 17 years to complete development. Nymph splits its skin, and transforms into an adult. Feeds on sap of tree roots. Northern Illinois Brood. This brood is the largest emergence of cicadas anywhere","credit":"© Ed Reschke-Stone/Getty Images","fullUrl":"https://cdn.britannica.com/54/222554-131-1976D74D/periodical-cicada.jpg"}},"categoryLinks":[{"id":10000,"title":"Entertainment & Pop Culture","urlTitle":"Entertainment-Pop-Culture","description":"Entertainment and leisure activities have been a part of culture in one form or another since the ancient times. Dance performances, live music, and storytelling have a long tradition throughout history, even as the styles and available methods of delivery have shifted dramatically.","image":{"id":0,"url":"/04/167104-050-A0D0F726.jpg","altText":"Entertainment & Pop Culture","fullUrl":"https://cdn.britannica.com/04/167104-050-A0D0F726.jpg"}},{"id":5000,"title":"Geography & Travel","urlTitle":"Geography-Travel","description":"Planet Earth contains some extraordinarily diverse environments, some of which are easily habitable and some not so much. In different areas of Earth, one might find sweltering deserts, dense tropical rainforests, or bone-chilling tundras. Each biome and habitat comes with its own selection of flora and fauna, and it may include physical features such as canyons, volcanoes, rivers, or caves. Human beings have built homes in many different environments, settling the area and organizing it into units such as cities, states, regions, and countries, each with its own points of interest. Shifting trends in human migration have resulted in a human geography that is profoundly different from that of centuries ago.","image":{"id":0,"url":"/17/2317-050-758D0E55/World-map-descriptions-Herodotus-Black-Sea.jpg","altText":"Geography & Travel","fullUrl":"https://cdn.britannica.com/17/2317-050-758D0E55/World-map-descriptions-Herodotus-Black-Sea.jpg"}}, ...
# </script>
# <header class="bg-navy shadow-lg" id="header">
# <div class="grid gx-0 align-items-center">
# <div class="col-auto order-1 order-sm-0">
# <a class="mx-10 mx-sm-20 d-block" href="/">
# <img alt="Encyclopedia Britannica logo" height="30" loading="lazy" src="https://cdn.britannica.com/mendel/eb-logo/b-50-pb5.png" width="123"/>
# </a>
# </div>
# <div class="col-auto order-0 order-sm-1">
# <button class="js-toggle js-toggle-hamburger btn btn-link link-white btn-sm rounded-0 px-15">
# <em class="material-icons inactive-icon" data-icon="menu"></em>
# <em class="material-icons active-icon" data-icon="close"></em>
# <span class="d-none d-sm-inline-block ml-5">Browse</span>
# </button>
# <button class="js-toggle js-toggle-search-flyout btn btn-link link-white btn-sm rounded-0 px-15">
# <em class="material-icons inactive-icon" data-icon="search"></em>
# <em class="material-icons active-icon" data-icon="close"></em>
# <span class="d-none d-sm-inline-block ml-5">Search</span>
# </button>
# </div>
# <div class="col d-none d-sm-flex align-items-center justify-content-md-start justify-content-end order-2">
# <a class="link-white font-14 ml-20" href="/quiz/browse">
#                     Quizzes</a>
# <a class="link-white font-14 ml-20 ml-md-35" href="/games">
#                     Games</a>
# <a class="link-white font-14 ml-20 ml-md-35" href="/on-this-day">
#                     On This Day</a>
# </div>
# <div class="col col-sm-auto text-right order-3 mr-lg-15">
# <span class="marketing-HEADER_SUBSCRIPTION_DESKTOP2 marketing-content" data-marketing-id="HEADER_SUBSCRIPTION_DESKTOP2"><a class="subscribe-link btn btn-sm btn-outline-white-orange py-5 mr-10" href="https://premium.britannica.com/premium-membership/?utm_source=premium&amp;utm_medium=global-nav&amp;utm_campaign=evergreen" rel="noopener" target="_blank">
#    Subscribe
# </a></span><button class="js-toggle-user-dropdown js-toggle btn btn-sm btn-link link-white rounded-0 pl-15 pr-10">
# <span class="d-inline-block mr-5">Login</span>
# <em class="material-icons inactive-icon d-inline-block" data-icon="keyboard_arrow_down"></em>
# <em class="material-icons active-icon d-inline-block" data-icon="keyboard_arrow_up"></em>
# </button>
# </div>
# </div>
# <div id="global-nav-react">
# <ul class="d-none">
# <li><a href="/browse/Entertainment-Pop-Culture">Entertainment &amp; Pop Culture</a></li>
# <li><a href="/browse/Geography-Travel">Geography &amp; Travel</a></li>
# <li><a href="/browse/Health-Medicine">Health &amp; Medicine</a></li>
# <li><a href="/browse/Lifestyles-Social-Issues">Lifestyles &amp; Social Issues</a></li>
# <li><a href="/browse/Literature">Literature</a></li>
# <li><a href="/browse/Philosophy-Religion">Philosophy &amp; Religion</a></li>
# <li><a href="/browse/Politics-Law-Government">Politics, Law &amp; Government</a></li>
# <li><a href="/browse/Science">Science</a></li>
# <li><a href="/browse/Sports-Recreation">Sports &amp; Recreation</a></li>
# <li><a href="/browse/Technology">Technology</a></li>
# <li><a href="/browse/Visual-Arts">Visual Arts</a></li>
# <li><a href="/browse/World-History">World History</a></li>
# </ul>
# <ul class="d-none">
# <li><a href="/quiz/browse">Quizzes</a></li>
# <li><a href="/games">Games</a></li>
# <li><a href="/podcasts">Podcasts</a></li>
# <li><a href="/on-this-day">On This Day</a></li>
# <li><a href="/biographies">Biographies</a></li>
# <li><a href="/week-in-review">Week In Review</a></li>
# <li><a href="/summary">Topic Summaries</a></li>
# <li><a href="https://www.britannica.com/study/infographics">Infographics</a></li>
# <li><a href="/stories/demystified">Demystified</a></li>
# <li><a href="/list/browse">Lists</a></li>
# <li><a href="/stories/wtfact">#WTFact</a></li>
# <li><a href="/stories/companion">Companions</a></li>
# <li><a href="/gallery/browse">Image Galleries</a></li>
# <li><a href="/stories/spotlight">Spotlight</a></li>
# <li><a href="/stories/the-forum">The Forum</a></li>
# </ul>
# <ul class="d-none">
# <li><a href="/videos/Entertainment-Pop-Culture">Entertainment &amp; Pop Culture</a></li>
# <li><a href="/videos/Geography-Travel">Geography &amp; Travel</a></li>
# <li><a href="/videos/Health-Medicine">Health &amp; Medicine</a></li>
# <li><a href="/videos/Lifestyles-Social-Issues">Lifestyles &amp; Social Issues</a></li>
# <li><a href="/videos/Literature">Literature</a></li>
# <li><a href="/videos/Philosophy-Religion">Philosophy &amp; Religion</a></li>
# <li><a href="/videos/Politics-Law-Government">Politics, Law &amp; Government</a></li>
# <li><a href="/videos/Science">Science</a></li>
# <li><a href="/videos/Sports-Recreation">Sports &amp; Recreation</a></li>
# <li><a href="/videos/Technology">Technology</a></li>
# <li><a href="/videos/Visual-Arts">Visual Arts</a></li>
# <li><a href="/videos/World-History">World History</a></li>
# </ul>
# <ul class="d-none">
# <li><a href="/videos/britannica-classics">Britannica Classics<br/>Check out these retro videos from Encyclopedia Britannica’s archives.</a></li>
# <li><a href="/videos/demystified">Demystified Videos<br/>In Demystified, Britannica has all the answers to your burning questions.</a></li>
# <li><a href="/videos/wtfact">#WTFact Videos<br/>In #WTFact Britannica shares some of the most bizarre facts we can find.</a></li>
# <li><a href="/videos/this-week-in-history">This Time in History<br/>In these videos, find out what happened this month (or any month!) in history.</a></li>
# <li><a href="/videos/explains">Britannica Explains<br/>In these videos, Britannica explains a variety of topics and answers frequently asked questions.</a></li>
# </ul>
# </div>
# </header>
# <main>
# <div class="md-page-wrapper">
# <div class="md-content" id="content">
# <div class="md-article-container template-desktop infinite-pagination">
# <div class="infinite-scroll-container article last">
# <article class="article-content content md-expanded" data-topic-id="44957">
# <div class="pl728 toolbar-ad"></div>
# <div class="grid gx-0">
# <div class="col-auto">
# <div class="family-panel md-article-drawer position-relative d-flex border-right-sm open">
# <div class="drawer open">
# <div class="family-panel-header grid gx-0 align-items-center border-bottom bg-white">
# <div class="col">
# <div class="py-15 px-20 text-truncate">
# <a class="font-serif font-weight-bold font-14 text-black link-blue" href="/technology/automobile">
#                     automobile
#                 </a>
# </div>
# </div>
# <div class="col-auto d-sm-none">
# <button class="js-sections-button btn-link btn-sm btn py-5 pl-0 pr-10 mr-10">
# <em class="material-icons" data-icon="arrow_drop_down"></em>
#
#                 Sections &amp; Media
#             </button>
# </div>
# </div>
# <div class="family-section-content ml-50 ml-sm-0 grid g-0 flex-column bg-gray-50">
# <div class="TOC js-section section col expanded">
# <div class="h-100 d-flex flex-column">
# <div class="section-title border-bottom bg-white col-auto d-flex justify-content-between align-items-center">
# <a class="border-yellow border-left-5 label text-black link-blue d-inline-flex align-items-center px-15 py-10" href="/technology/automobile">
# <em class="material-icons mr-5" data-icon="article"></em>
# 	Article
#                     </a>
# <button aria-label="expand/collapse panel" class="js-toggle-btn toggle-btn btn btn-unstyled pe-auto col h-100 justify-content-end">
# <div class="btn btn-circle btn-outline-navy btn-sm mr-15 border-gray-200">
# <em class="material-icons toggle-icon" data-icon="expand_more"></em>
# </div>
# </button>
# </div>
# <div class="toc section-content">
# <ul class="list-unstyled mb-0 w-100" data-level="h1"><li data-target="#ref1"><a href="/technology/automobile">Introduction</a></li><li data-target="#ref259040"><a href="/technology/automobile#ref259040">Automotive design</a><ul class="list-unstyled" data-level="h2"><li data-target="#ref259041"><a href="/technology/automobile#ref259041">Body</a></li></ul><ul class="list-unstyled" data-level="h2"><li data-target="#ref259042"><a href="/technology/automobile/Chassis">Chassis</a></li></ul><ul class="list-unstyled" data-level="h2"><li data-target="#ref259043"><a href="/technology/automobile/Chassis#ref259043">Engine</a></li></ul><ul class="list-unstyled" data-level="h2"><li data-target="#ref259044"><a href="/technology/automobile/Chassis#ref259044">Fuel</a></li></ul><ul class="list-unstyled" data-level="h2"><li data-target="#ref259045"><a href="/technology/automobile/Chassis#ref259045">Lubrication</a></li></ul><ul class="list-unstyled" data-level="h2"><li data-target="#ref259046"><a href="/technology/automobile/Cooling-system">Cooling system</a></li></ul><ul class="list-unstyled" data-level="h2"><li data-target="#ref259047"><a href="/technology/automobile/Cooling-system#ref259047">Electrical system</a></li></ul><ul class="list-unstyled" data-level="h2"><li data-target="#ref259048"><a href="/technology/automobile/Transmission">Transmission</a></li></ul><ul class="list-unstyled" data-level="h2"><li data-target="#ref259049"><a href="/technology/automobile/Transmission#ref259049">Other mechanical subsystems</a><ul class="list-unstyled" data-level="h3"><li data-target="#ref259050"><a href="/technology/automobile/Transmission#ref259050">Axles</a></li></ul><ul class="list-unstyled" data-level="h3"><li data-target="#ref259051"><a href="/technology/automobile/Brakes">Brakes</a></li></ul><ul class="list-unstyled" data-level="h3"><li data-target="#ref259052"><a href="/technology/automobile/Brakes#ref259052">Steering</a></li></ul><ul class="list-unstyled" data-level="h3"><li data-target="#ref259053"><a href="/technology/automobile/Brakes#ref259053">Suspension</a></li></ul></li></ul><ul class="list-unstyled" data-level="h2"><li data-target="#ref259054"><a href="/technology/automobile/Tires">Tires</a></li></ul><ul class="list-unstyled" data-level="h2"><li data-target="#ref259055"><a href="/technology/automobile/Tires#ref259055">Security systems</a></li></ul><ul class="list-unstyled" data-level="h2"><li data-target="#ref259056"><a href="/technology/automobile/Tires#ref259056">Safety systems</a></li></ul><ul class="list-unstyled" data-level="h2"><li data-target="#ref259057"><a href="/technology/automobile/Emission-controls">Emission controls</a></li></ul><ul class="list-unstyled" data-level="h2"><li data-target="#ref259058"><a href="/technology/automobile/Emission-controls#ref259058">Electric and hybrid vehicles</a></li></ul><ul class="list-unstyled" data-level="h2"><li data-target="#ref259059"><a href="/technology/automobile/Emission-controls#ref259059">Experimental systems</a></li></ul></li><li data-target="#ref64377"><a href="/technology/automobile/History-of-the-automobile">History of the automobile</a><ul class="list-unstyled" data-level="h2"><li data-target="#ref259060"><a href="/technology/automobile/History-of-the-automobile#ref259060">The age of steam</a></li></ul><ul class="list-unstyled" data-level="h2"><li data-target="#ref259061"><a href="/technology/automobile/Early-electric-automobiles">Early electric automobiles</a></li></ul><ul class="list-unstyled" data-level="h2"><li data-target="#ref259062"><a href="/technology/automobile/Early-electric-automobiles#ref259062">Development of the gasoline car</a><ul class="list-unstyled" data-level="h3"><li class="has-children" data-target="#ref259063"><a href="/technology/automobile/Early-electric-automobiles#ref259063">Germany</a><ul class="list-unstyled" data-level="h4"><li data-target="#ref259064"><a href="/technology/automobile/Early-electric-automobiles#ref259064">Karl Benz</a></li></ul><ul  ...
# </div>
# </div>
# </div>
# <div class="SUMMARY js-section section col-auto">
# <div class="h-100 d-flex flex-column">
# <div class="section-title border-bottom bg-white col-auto d-flex justify-content-between align-items-center">
# <a class="border-white border-left-5 label px-15 py-10 text-black link-blue d-inline-flex align-items-center" href="/summary/automobile">
# <em class="material-icons group-icon mr-5 SUMMARY" data-icon=""></em>
# 	Fast Facts
#                             </a>
# <button aria-label="expand/collapse panel" class="js-toggle-btn toggle-btn btn btn-unstyled pe-auto col h-100 justify-content-end">
# <div class="btn btn-circle btn-outline-navy btn-sm mr-15 border-gray-200">
# <em class="material-icons toggle-icon" data-icon="expand_more"></em>
# </div>
# </button>
# </div>
# <div class="section-content">
# <ul class="list-unstyled mb-0 pb-10">
# <li data-target="#automobile">
# <a href="/summary/automobile">2-Min Summary</a>
# </li>
# <li data-target="#facts-automobile">
# <a href="/facts/automobile">Facts &amp; Related Content</a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="MEDIA js-section section col-auto">
# <div class="h-100 d-flex flex-column">
# <div class="section-title border-bottom bg-white col-auto d-flex justify-content-between align-items-center">
# <a class="border-white border-left-5 label px-15 py-10 text-black link-blue d-inline-flex align-items-center" href="/technology/automobile/images-videos">
# <em class="material-icons group-icon mr-5 MEDIA" data-icon=""></em>
# 	Media
#                             </a>
# <button aria-label="expand/collapse panel" class="js-toggle-btn toggle-btn btn btn-unstyled pe-auto col h-100 justify-content-end">
# <div class="btn btn-circle btn-outline-navy btn-sm mr-15 border-gray-200">
# <em class="material-icons toggle-icon" data-icon="expand_more"></em>
# </div>
# </button>
# </div>
# <div class="section-content">
# <ul class="list-unstyled mb-0 pb-10">
# <li data-target="#Videos-automobile">
# <a href="/technology/automobile/images-videos#Videos">Videos</a>
# </li>
# <li data-target="#Images-automobile">
# <a href="/technology/automobile/images-videos#Images">Images</a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="INFO js-section section col-auto">
# <div class="h-100 d-flex flex-column">
# <div class="section-title border-bottom bg-white col-auto d-flex justify-content-between align-items-center">
# <a class="border-white border-left-5 label px-15 py-10 text-black link-blue d-inline-flex align-items-center" href="/technology/automobile/additional-info" rel="nofollow">
# <em class="material-icons group-icon mr-5 INFO" data-icon=""></em>
# 	Additional Info
#                             </a>
# <button aria-label="expand/collapse panel" class="js-toggle-btn toggle-btn btn btn-unstyled pe-auto col h-100 justify-content-end">
# <div class="btn btn-circle btn-outline-navy btn-sm mr-15 border-gray-200">
# <em class="material-icons toggle-icon" data-icon="expand_more"></em>
# </div>
# </button>
# </div>
# <div class="section-content">
# <ul class="list-unstyled mb-0 pb-10">
# <li data-target="#Additional-Reading">
# <a href="/technology/automobile/additional-info#Additional-Reading" rel="nofollow">Additional Reading</a>
# </li>
# <li data-target="#More-Articles">
# <a href="/technology/automobile/additional-info#More-Articles" rel="nofollow">More Articles On This Topic</a>
# </li>
# <li data-target="#contributors-automobile">
# <a href="/technology/automobile/additional-info#contributors" rel="nofollow">Contributors</a>
# </li>
# <li data-target="#history-automobile">
# <a href="/technology/automobile/additional-info#history" rel="nofollow">Article History</a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# <button aria-label="Toggle Drawer" class="drawerToggle btn position-sticky btn-navy btn-circle rounded d-none d-sm-flex" type="button">
# <em class="material-icons" data-icon="keyboard_arrow_left"></em>
# </button>
# </div>
# </div>
# <div class="col pt-50 pt-sm-0">
# <div class="container p-0 p-sm-30">
# <div class="grid gx-0 gx-sm-20">
# <div class="col-sm">
# <div class="infinite-pagination-container">
# <script type="application/ld+json">
# 		{
# 			"@context" : "https://schema.org",
# 			"@type" : "BreadcrumbList",
# 			"itemListElement" :
# 			[
#
#
# 			{
# 			"@type" : "ListItem",
# 			"position" : 1,
# 			"item" :
# 			{
# 			"@id" : "https://www.britannica.com/browse/Technology",
# 			"name": "Technology"
# 			}
# 			}
#
# 			,
# 			{
# 			"@type" : "ListItem",
# 			"position" : 2,
# 			"item" :
# 			{
# 			"@id" : "https://www.britannica.com/browse/Cars-Vehicles",
# 			"name": "Cars &amp; Other Vehicles"
# 			}
# 			}
#
# 			]
# 		}
# 		</script>
# <nav class="breadcrumb ml-20 mt-10 ml-sm-0 mt-sm-0">
# <span class="breadcrumb-item">
# <a class="" href="/">Home</a>
# </span>
# <span class="breadcrumb-item">
# <a class="" href="/browse/Technology">Technology</a>
# </span>
# <span class="breadcrumb-item">
# <a class="" href="/browse/Cars-Vehicles">Cars &amp; Other Vehicles</a>
# </span>
# </nav>
# <div class="grey-box grey-box-top">
# <div class="topic-header">
# <div>
# <h1 class="mb-0">automobile</h1>
# <div class="caption mt-5">Alternate titles: auto, car, motorcar</div>
# <div class="md-topic-tools mt-15 mb-15" data-topic-id="44957">
# <button class="js-print-modal-button js-modal btn btn-sm btn-outline-blue border shadow-sm mr-5 pr-10" data-modal="[data-topic-id=44957] .md-print-modal">
# <em class="material-icons mr-5 ml-n10 my-n5" data-icon="print"></em>
#
#
#                     Print
#         </button>
# <div class="md-print-modal size-lg d-none">
# <div class="md-modal-body">
# <div class="h2 font-serif d-flex align-items-center pb-15 border-bottom">
# <em class="material-icons text-blue mr-10">print</em>
# 			Print
# 		</div>
# <div class="mt-20 mb-10">
# 			Please select which sections you would like to print:
# 		</div>
# <form action="/print/article/44957" method="post" rel="noopener" target="_blank">
# <div class="print-box-items">
# <ul class="list-unstyled">
# <li><label><input class="mr-10" name="sequence[]" type="checkbox" value="0"/>Table Of Contents</label></li>
# </ul>
# </div>
# <input class="btn btn-blue md-disabled" type="submit" value="Print">
# </input></form>
# </div>
# </div>
# <button class="js-modal qa-cite-modal-button btn btn-sm btn-outline-blue border shadow-sm mr-5 pr-10" data-modal="[data-topic-id=44957]  .md-cite-modal">
# <em class="material-icons mr-5 ml-n10 my-n5" data-icon="verified"></em>
#
#
#     Cite
#         </button>
# <div class="md-cite-modal size-lg d-none">
# <div class="md-modal-body">
# <div class="h2 font-serif d-flex align-items-center pb-15 border-bottom mb-15">
# <em class="material-icons text-blue mr-10">verified</em>Cite
# 		</div>
# <div class="font-serif">
# 			While every effort has been made to follow citation style rules, there may be some discrepancies.
# 			Please refer to the appropriate style manual or other sources if you have any questions.
# 		</div>
# <div class="label mt-20 mb-10">Select Citation Style</div>
# <select class="js-citation-format-select form-select">
# <option selected="" value="mla">MLA</option>
# <option value="apa">APA</option>
# <option value="chicago">Chicago Manual of Style</option>
# </select>
# <div class="citation font-serif border rounded p-15 mt-20" data-authors="Christopher G. Foster,
#
# 				 Ken W. Purdy,
#
# 				 Orville C. Cromer,
#
# 				 George C. Cromer" data-published-date="2 Nov. 2021" data-title="automobile" data-url="https://www.britannica.com/technology/automobile">
# <div class="citation-text"></div>
# </div>
# <button class="js-copy-citation-button mt-20 btn btn-sm btn-outline-blue border shadow-sm mr-5 pr-10">
# <em class="material-icons mr-5 ml-n10 my-n5" data-icon="file_copy"></em>
# <span class="js-citation-status-text">Copy Citation</span>
# </button>
# </div>
# </div>
# <button class="js-share-modal-button js-modal btn btn-sm btn-outline-blue border shadow-sm mr-5 pr-10" data-modal=" .md-share-modal">
# <em class="material-icons mr-5 ml-n10 my-n5" data-icon="share"></em>
#
#
#             Share
#         </button>
# <div class="md-share-modal size-lg d-none">
# <div class="md-modal-body">
# <div class="h2 font-serif d-flex align-items-center pb-15 border-bottom">
# <em class="material-icons text-blue mr-10" data-icon="share"></em>
#
#             Share
#         </div>
# <div class="label my-20">Share to social media</div>
# <div class="md-social-toolbar-circle d-flex align-items-start inverted" data-url="https://www.britannica.com/technology/automobile" data-value="share" title="automobile">
# <a class="social-icon facebook justify-content-center d-flex align-items-center align-self-center" data-provider="facebook" href="https://www.facebook.com/BRITANNICA/" rel="noopener" target="_blank"><span>Facebook</span></a>
# <a class="social-icon twitter justify-content-center d-flex align-items-center align-self-center" data-provider="twitter" href="https://twitter.com/britannica" rel="noopener" target="_blank"><span>Twitter</span></a>
# </div>
# <div class="label pt-20 mt-20 mb-5 border-top">URL</div>
# <a class="font-serif text-truncate d-inline-block" href="https://www.britannica.com/technology/automobile">https://www.britannica.com/technology/automobile</a>
# </div>
# </div>
# <button class="js-tooltip btn btn-sm btn-outline-blue border shadow-sm mr-5 pr-10">
# <em class="material-icons mr-5 ml-n10 my-n5" data-icon="more_vert"></em>
#
#
#             More
#         </button>
# <div class="md-more-popover popover popover-sm py-5 px-0 font-14 z-1">
# <button class="js-feedback-modal-button js-modal btn btn-sm btn-link" data-modal=".md-feedback-modal">Give Feedback</button>
# <button class="js-modal btn btn-sm btn-link" data-modal="[data-topic-id=44957] .md-websites-modal">External Websites</button>
# </div>
# <div class="md-feedback-modal size-lg d-none">
# <div class="md-modal-body">
# <div class="h2 font-serif pb-15 border-bottom">
# 			Feedback
# 		</div>
# <form action="/submission/feedback/44957" method="post">
# <div class="my-20">
# 				Corrections? Updates? Omissions? Let us know if you have suggestions to improve this article (requires login).
# 			</div>
# <div class="type-menu">
# <label class="label mb-10" for="feedback-type">Feedback Type</label>
# <select class="form-select mb-30" id="feedback-type" name="feedbackTypeId" required="">
# <option selected="selected" value="">Select a type (Required)</option>
# <option value="1">Factual Correction</option>
# <option value="2">Spelling/Grammar Correction</option>
# <option value="3">Link Correction</option>
# <option value="4">Additional Information</option>
# <option value="5">Other</option>
# </select>
# </div>
# <label class="label mb-10" for="feedback">Your Feedback</label>
# <textarea class="form-control mb-30" id="feedback" maxlength="3000" name="feedback" required="" rows="7"></textarea>
# <button class="btn btn-blue" type="submit">Submit Feedback</button>
# </form>
# <div class="success-messaging d-none mt-30">
# <div class="title">Thank you for your feedback</div>
# <p>Our editors will review what you’ve submitted and determine whether to revise the article.</p>
# <a class="promo" href="http://corporate.britannica.com/publishing-partner-program/" rel="noopener" target="_blank">
# 				Join <strong>Britannica's Publishing Partner Program</strong> and our community of experts to gain a global audience for your work!
# 			</a>
# </div>
# </div>
# </div>
# <div class="md-websites-modal size-lg d-none">
# <div class="md-modal-body">
# <div class="h2 font-serif pb-15 border-bottom">
#                     External Websites
#                 </div>
# <div class="pb-20">
# <ul class="list-unstyled mt-20 lh-lg">
# <li><a class="external" href="https://www.livescience.com/37538-who-invented-the-car.html" rel="noopener" target="_blank">LiveScience - Who Invented the Car?</a></li>
# </ul>
# </div>
# <div class="md-websites-ebk-title">Britannica Websites</div>
# <div class="md-websites-ebk-subtitle">Articles from Britannica Encyclopedias for elementary and high school students.</div>
# <ul class="list-unstyled bps-topic-web-sites lh-lg">
# <li><a class="external" href="https://kids.britannica.com/kids/article/car/352807" rel="noopener" target="_blank">car - Children's Encyclopedia (Ages 8-11)</a></li>
# <li><a class="external" href="https://kids.britannica.com/students/article/automobile/273028" rel="noopener" target="_blank">automobile - Student Encyclopedia (Ages 11 and up)</a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# <div class="md-byline pb-10 font-14">
# <span class="written-by label">By</span>
# <a href="/contributor/Christopher-G-Foster/5914">Christopher G. Foster</a>
#
# 			| <a class="see-all" href="/technology/automobile/additional-info#contributors" rel="nofollow">See All Contributors</a>
# <span class="last-updated mt-5">
#
# 				|
# 				<span class="text-gray-600 font-sans-serif">
# 					Last Updated:
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <time datetime="2021-11-02T00:00:00CDT">Nov 2, 2021</time>
# </span>
#
#
# 				|
# 				<a href="/technology/automobile/additional-info#history" rel="nofollow">View Edit History</a>
# </span>
# </div>
# <hr class="grey-box-line my-0"/>
# </div>
# <div class="topic-content pt-15">
# <script class="topic-json" type="application/json">
# {
#        "44957": {
#             "url": "/technology/automobile",
#             "shareUrl": "https://www.britannica.com/technology/automobile",
#             "title": "automobile | Definition, History, Industry, Design, & Facts",
#             "documentGroup": "TOPIC PAGINATED LARGE",
#             "template": "DESKTOP"
#        }
#    }
# </script>
# <div class="js-qf-module qf-module border p-20 pt-0 ml-md-20 mx-auto mb-20 font-14 float-lg-right bg-white">
# <div class="bg-gray-100 qa-fast-facts p-10 font-14 mx-n20 mb-20 border-bottom text-center">
# <div class="d-flex align-items-center justify-content-center">
# <em class="material-icons bolt-fast-facts font-18" data-icon="bolt"></em>
# <span class="font-weight-bold text-uppercase font-14">
# 					Fast Facts
# 				</span>
# </div>
# <div>
# <a class="summary-link" href="/summary/automobile">
# 						2-Min Summary</a>
# <a class="summary-link" href="/facts/automobile">
# 						Facts &amp; Related Content</a>
# </div>
# </div>
# <div class="m-n10">
# <div class="slider js-slider position-relative d-inline-flex align-items-center mw-100 media-slider card-snap-slider col-100">
# <div class="slider-container js-slider-container overflow-hidden d-flex col-100">
# <div class="rw-track w-100">
# <div class="p-10 d-inline-flex col-100">
# <div class="card w-100">
# <a class="media-overlay-link card-media d-flex align-items-center justify-content-center" data-href="/media/1/44957/122183" href="https://cdn.britannica.com/16/126216-050-D9865939/Automobiles-John-F-Fitzgerald-Expressway-Massachusetts-Boston.jpg" style="--aspect-ratio: 4/3">
# <img alt="John F. Fitzgerald Expressway" loading="lazy" src="https://cdn.britannica.com/w:400,h:300,c:crop/16/126216-050-D9865939/Automobiles-John-F-Fitzgerald-Expressway-Massachusetts-Boston.jpg"/>
# <button aria-label="Zoom in" class="btn btn-circle position-absolute shadow btn-white">
# <em class="material-icons link-blue" data-icon="zoom_in"></em>
# </button>
# </a>
# <div class="card-body p-10 font-14">
# 									John F. Fitzgerald Expressway </div>
# </div>
# </div>
# </div>
# </div>
# <button aria-label="Previous" class="prev-button js-prev-button position-absolute btn btn-circle shadow btn-lg btn-blue" disabled="">
# <span class="material-icons md-24" data-icon="keyboard_arrow_left"></span>
# </button>
# <button aria-label="Next" class="next-button js-next-button position-absolute btn btn-circle shadow btn-lg btn-blue" disabled="">
# <span class="material-icons md-24" data-icon="keyboard_arrow_right"></span>
# </button>
# </div>
# </div>
# <div class="text-center py-10">
# <a class="font-weight-bold" href="/technology/automobile/images-videos">See all media</a>
# </div>
# <div class="facts-list pt-20 border-top">
# <dl class="js-fact py-5 mb-10 position-relative">
# <dt class="d-inline">Key People:</dt>
# <dd class="d-inline">
# <span class="fact-item"><a href="/biography/Henry-Ford" topicid="213223">Henry Ford</a></span>
# <span class="fact-item"><a href="/biography/Walter-P-Chrysler" topicid="116389">Walter P. Chrysler</a></span>
# <span class="fact-item"><a href="/biography/Robert-S-McNamara" topicid="355213">Robert S. McNamara</a></span>
# <span class="fact-item"><a href="/biography/Alfred-P-Sloan-Jr" topicid="548879">Alfred P. Sloan, Jr.</a></span>
# <span class="fact-item"><a href="/biography/Patricia-Russo" topicid="1013745">Patricia Russo</a></span>
# </dd>
# <button aria-label="Toggle more/less fact data" class="js-more-btn d-none btn btn-unstyled font-12 position-absolute bottom-5 right-0 bg-white">
# 					...<em class="js-content link-blue">(Show more)</em>
# </button>
# </dl>
# <dl class="js-fact py-5 mb-0 position-relative line-clamp clamp-3">
# <dt class="d-inline">Related Topics:</dt>
# <dd class="d-inline">
# <span class="fact-item"><a href="/technology/Model-T" topicid="387041">Model T</a></span>
# <span class="fact-item"><a href="/technology/DeLorean-DMC-12" topicid="2089518">DeLorean DMC-12</a></span>
# <span class="fact-item"><a href="/technology/Edsel" topicid="179398">Edsel</a></span>
# <span class="fact-item"><a href="/technology/electric-automobile" topicid="182400">electric automobile</a></span>
# <span class="fact-item"><a href="/topic/Ford-999" topicid="2173961">Ford 999</a></span>
# </dd>
# <button aria-label="Toggle more/less fact data" class="js-more-btn d-none btn btn-unstyled font-12 position-absolute bottom-5 right-0 bg-white">
# 					...<em class="js-content link-blue">(Show more)</em>
# </button>
# </dl>
# </div>
# <div class="text-center mt-20">
# <a class="btn btn-sm btn-outline-blue border" href="/facts/automobile">
# 				See all facts and data →
# 			</a>
# </div>
# </div><!--[BEFORE-ARTICLE]--><span class="marker before-article"></span><section data-level="1" id="ref1"><p class="topic-paragraph"><strong><span id="ref527638"></span>automobile</strong>, byname <strong>auto</strong>, also called <strong>motorcar</strong> or <strong>car</strong>,  a usually four-wheeled vehicle designed primarily for passenger <a class="md-crosslink autoxref" href="https://www.britannica.com/technology/transportation-technology">transportation</a> and commonly propelled by an <a class="md-crosslink autoxref" href="https://www.britannica.com/technology/internal-combustion-engine">internal-combustion engine</a> using a volatile fuel.</p><!--[P1]--><span class="marker p1"></span><!--[AM1]--><span class="marker AM1 am-inline"></span><!--[MOD1]--><span class="marker MOD1 mod-inline"></span></section> <!--[H2]--><span class="marker h2"></span><section data-level="1" id="ref259040"> <h2 class="h1">Automotive design</h2> <p class="topic-paragraph">The modern automobile is a complex technical system employing subsystems with specific <span id="ref527639"></span><a class="md-crosslink" href="https://www.britannica.com/topic/industrial-design">design</a> functions. Some of these consist of thousands of component parts that have evolved from breakthroughs in existing <a class="md-crosslink autoxref" href="https://www.britannica.com/technology/technology">technology</a> or from new technologies such as electronic computers, high-strength plastics, and new alloys of steel and nonferrous metals. Some subsystems have come about as a result of factors such as <a class="md-crosslink autoxref" href="https://www.britannica.com/science/air-pollution">air pollution</a>, safety legislation, and competition between manufacturers throughout the world.</p><!--[P2]--><span class="marker p2"></span><div class="assemblies"><div class="w-100"><figure class="md-assembly card print-false" data-assembly-id="120667"><div class="md-assembly-wrapper" data-type="image"><a class="position-relative d-flex align-items-center justify-content-center media-overlay-link card-media" data-href="/media/1/44957/120667" href="https://cdn.britannica.com/84/91384-050-DA3570A0/components-automobile.jpg" style="--aspect-ratio: 16/9"><img alt="automobile" data-height="853" data-width="1600" loading="lazy" src="https://cdn.britannica.com/s:690x388,c:crop/84/91384-050-DA3570A0/components-automobile.jpg"/><button aria-label="Zoom in" class="btn btn-circle position-absolute shadow btn-white"><em class="material-icons link-blue" data-icon="zoom_in"></em></button></a></div><figcaption class="card-body"><a class="md-assembly-title font-weight-bold mb-5 d-inline-block font-16 font-sans-serif media-overlay-link" data-href="/media/1/44957/120667" href="https://cdn.britannica.com/84/91384-050-DA3570A0/components-automobile.jpg">automobile</a><div class="md-assembly-caption text-muted font-14 font-serif">The major functional components of an automobile.</div><cite class="credit d-block mt-5">Encyclopædia Britannica, Inc.</cite></figcaption></figure></div></div><!--[AM2]--><span class="marker AM2 am-inline"></span><a class="info-module quiz-module p-5 d-block border m-sm-50 mb-30" href="/quiz/transportation-and-technology-firsts-quiz">
# <div class="wrapper p-30">
# <div class="grid">
# <div class="col-md-auto col-100 mb-15 mb-sm-0">
# <img alt="Hindenburg zeppelin crashing, 1937" loading="lazy" src="https://cdn.britannica.com/78/194978-131-7B55B72C/Hindenburg-zeppelin-crashing-1937.jpg">
# </img></div>
# <div class="col-md col-100">
# <div class="label text-black font-13 font-weight-bold text-uppercase">Britannica Quiz</div>
# <div class="title font-18 font-weight-bold lh-base mb-5" href="/quiz/transportation-and-technology-firsts-quiz">Transportation and Technology Firsts Quiz</div>
# <div class="font-14 text-muted lh-base">Where was the first practical subway line in the United States? Who was the first woman to break the sound barrier? Test your knowledge. Take the quiz.</div>
# </div>
# </div>
# </div>
# </a><span class="marker MOD2 mod-inline"></span> <p class="topic-paragraph">Passenger cars have emerged as the primary means of family transportation, with an estimated 1.4 billion in operation worldwide. About one-quarter of these are in the <span id="ref527640"></span><a class="md-crosslink" href="https://www.britannica.com/place/United-States">United States</a>, where more than three trillion miles (almost five trillion kilometres) are traveled each year. In recent years, Americans have been offered hundreds of different models, about half of them from foreign manufacturers. To capitalize on their <a class="md-dictionary-link md-dictionary-tt-off" data-term="proprietary" href="https://www.merriam-webster.com/dictionary/proprietary">proprietary</a> technological advances, manufacturers introduce new designs ever more frequently. With some 70 million new units built each year worldwide, manufacturers have been able to split the market into many very small segments that nonetheless remain profitable.</p><!--[P3]--><span class="marker p3"></span><!--[AM3]--><span class="marker AM3 am-inline"></span><!--[MOD3]--><span class="marker MOD3 mod-inline"></span> <p class="topic-paragraph">New technical developments are recognized to be the key to successful competition. Research and development engineers and scientists have been employed by all automobile manufacturers and suppliers to improve the body, chassis, engine, drivetrain, control systems, safety systems, and emission-control systems.</p><!--[P4]--><span class="marker p4"></span><!--[AM4]--><span class="marker AM4 am-inline"></span><div class="marketing-INLINE_SUBSCRIPTION marketing-content" data-marketing-id="INLINE_SUBSCRIPTION"><div class="bc-article-inline-dialogue" style="margin:0 auto 20px auto;height:154px;max-width:800px;"></div></div><span class="marker MOD4 mod-inline"></span> <p class="topic-paragraph">These outstanding technical advancements are not made without economic consequences. According to a study by Ward’s Communications Incorporated, the average cost for a new American car increased $4,700 (in terms of the value of the dollar in 2000) between 1980 and 2001 because of <a class="md-dictionary-link md-dictionary-tt-off" data-term="mandated" href="https://www.merriam-webster.com/dictionary/mandated">mandated</a> safety and emission-control performance requirements (such as the addition of air bags and <a class="md-crosslink" href="https://www.britannica.com/technology/catalytic-converter">catalytic converters</a>). New requirements continued to be <a class="md-dictionary-link md-dictionary-tt-off" data-term="implemented" href="https://www.merriam-webster.com/dictionary/implemented">implemented</a> in subsequent years. The addition of computer technology was another factor driving up car prices, which increased by 29 percent between 2009 and 2019. This is in addition to the consumer costs associated with engineering improvements in fuel economy, which may be offset by reduced fuel purchases.</p><!--[P5]--><span class="marker p5"></span><!--[AM5]--><span class="marker AM5 am-inline"></span><!--[MOD5]--><span class="marker MOD5 mod-inline"></span> <p class="topic-paragraph">Vehicle design depends to a large extent on its intended use. Automobiles for off-road use must be durable, simple systems with high resistance to severe overloads and extremes in operating conditions. Conversely, products that are intended for high-speed, limited-access road systems require more passenger comfort options, increased engine performance, and optimized high-speed handling and vehicle stability. Stability depends principally on the distribution of weight between the front and rear wheels, the height of the <a class="md-crosslink autoxref" href="https://www.britannica.com/science/centre-of-gravity">centre of gravity</a> and its position relative to the aerodynamic centre of pressure of the vehicle, suspension characteristics, and the selection of which wheels are used for propuls ...
# </div>
# </div>
# <div class="infinite-pagination-button d-flex justify-content-center border border-top-0">
# <button class="js-load-next btn btn-sm btn-blue mt-30 pr-10 mb-100">
#                                             Load Next Page
#                                             <em class="material-icons" data-icon="keyboard_arrow_down"></em>
# </button>
# </div>
# </div>
# <aside class="col-md-da-300"></aside>
# </div>
# </div>
# </div>
# </div>
# </article></div>
# </div></div>
# </div>
# </main>
# <div id="chatbot-container"></div>
# <div id="md-footer"></div> <iframe name="__uspapiLocator" style="display:none;height:0;opacity:0;visibility:hidden;border:0;width:0;"></iframe>
# <script type="text/javascript">
# 			__ADCMD.push( () => {
# 				__$.setDebug( false );
# 				__AD.initAdsManager();
# 			});
# 		</script>
# <script>
#     window.assertive = {
#         debug: false,
#         entityId: "RZi5r6K8WFMwq9izm",
#         analytics: {
#             sampleRate: 1,
#             custom: {
#                 layout: null,
#                 userState: null,
#                 custom_1: null,
#                 custom_2: null,
#                 custom_3: null,
#                 custom_4: null,
#                 custom_5: null,
#             },
#         },
#         floor: {
#             enabled: false,
#             limit: {
#                 percentage: 0.95,
#             },
#         }
#     };
# </script>
# <script async="" src="https://RZi5r6K8WFMwq9izm.ay.delivery/client-v2-eb.js"></script>
# <noscript><iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-5W6NC8" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <script id="_informizely_script_tag" type="text/javascript">
# var IzWidget = IzWidget || {};
# (function (d)
# { var scriptElement = d.createElement('script'); scriptElement.type = 'text/javascript'; scriptElement.async = true; scriptElement.src = "https://insitez.blob.core.windows.net/site/f780f33e-a610-4ac2-af81-3eb184037547.js"; var node = d.getElementById('_informizely_script_tag'); node.parentNode.insertBefore(scriptElement, node); }
# )(document);
# </script>
# <script src="https://cdn.britannica.com/mendel-resources/3-53/js/libs/jquery-3.5.0.min.js?v=3.53.17"></script>
# <script async="async" src="https://cdn.britannica.com/mendel-resources/3-53/js/libs/prebid4.12.0.js?v=3.53.17" type="text/javascript"></script>
# <script type="text/javascript">
# 	window.pbjs = window.pbjs || {};
#     pbjs.que = pbjs.que || [];
# 	</script>
# <script src="//content.jwplatform.com/libraries/DkXxjTZZ.js"></script><script data-type="Init Mendel Code Splitting" type="text/javascript">
#               (function() {
#                 $.ajax({
#                   dataType: 'script',
#                   cache: true,
#                   url: 'https://cdn.britannica.com/mendel-resources/3-53/dist/topic-page.js?v=3.53.17'
#                 });
#               })();
#             </script>
# <script async="async" src="https://www.googletagmanager.com/gtag/js?id=UA-6636134-11" type="text/javascript"></script>
# <script type="text/javascript">
#         function gaPageLoad(pathname, documentLocation) {
#             pathname = pathname || location.pathname;
#             documentLocation = documentLocation || document.querySelector('html').getAttribute('data-ytrk-page');
#
#             if (documentLocation) {
#                 documentLocation = documentLocation.replace(/ /g, '/');
#                 window.dataLayer = window.dataLayer || [];
#
#                 function gtag() {
#                     dataLayer.push(arguments);
#                 }
#
#                 gtag('js', new Date());
#
#                 gtag('set', {
#                     'dimension1': 'ANONYMOUS',
#                     'dimension2': 'B',
#                 });
#
#                 gtag('config', 'UA-6636134-11', {
#                     'page_path': documentLocation + pathname + decodeURI(location.search),
#                     'link_attribution': true,
#                 });
#             }
#         }
#
#         gaPageLoad();
#     </script>
# <script type="text/javascript">
#     EBStat={accountId:-1,hostnameOverride:'webstats.eb.com',domain:'www.britannica.com', json:''};
#     </script>
# <script type="text/javascript">
#             ( function() {
#                 $.ajax( { dataType: 'script', cache: true, url: '//www.britannica.com/webstats/mendelstats.js?v=1' } )
#                  .done( function() {
#                      try {writeStat(null,EBStat);}
#                      catch(err){}
#                  } );
#             })();
#             </script>
# <script data-cf-beacon='{"rayId":"6a94f41fae822b18","token":"5cc7d7124de641b181da990fc8c9a0b6","version":"2021.10.0","si":100}' defer="" src="https://static.cloudflareinsights.com/beacon.min.js"></script>
# </body>
# </html>

# %%
# getting all the paragraphs
for para in soup.find_all("p"):
    print(para.get_text())
# Out:
# Our editors will review what you’ve submitted and determine whether to revise the article.
# automobile, byname auto, also called motorcar or car,  a usually four-wheeled vehicle designed primarily for passenger transportation and commonly propelled by an internal-combustion engine using a volatile fuel.
# The modern automobile is a complex technical system employing subsystems with specific design functions. Some of these consist of thousands of component parts that have evolved from breakthroughs in existing technology or from new technologies such as electronic computers, high-strength plastics, and new alloys of steel and nonferrous metals. Some subsystems have come about as a result of factors such as air pollution, safety legislation, and competition between manufacturers throughout the world.
# Passenger cars have emerged as the primary means of family transportation, with an estimated 1.4 billion in operation worldwide. About one-quarter of these are in the United States, where more than three trillion miles (almost five trillion kilometres) are traveled each year. In recent years, Americans have been offered hundreds of different models, about half of them from foreign manufacturers. To capitalize on their proprietary technological advances, manufacturers introduce new designs ever more frequently. With some 70 million new units built each year worldwide, manufacturers have been able to split the market into many very small segments that nonetheless remain profitable.
# New technical developments are recognized to be the key to successful competition. Research and development engineers and scientists have been employed by all automobile manufacturers and suppliers to improve the body, chassis, engine, drivetrain, control systems, safety systems, and emission-control systems.
# These outstanding technical advancements are not made without economic consequences. According to a study by Ward’s Communications Incorporated, the average cost for a new American car increased $4,700 (in terms of the value of the dollar in 2000) between 1980 and 2001 because of mandated safety and emission-control performance requirements (such as the addition of air bags and catalytic converters). New requirements continued to be implemented in subsequent years. The addition of computer technology was another factor driving up car prices, which increased by 29 percent between 2009 and 2019. This is in addition to the consumer costs associated with engineering improvements in fuel economy, which may be offset by reduced fuel purchases.
# Vehicle design depends to a large extent on its intended use. Automobiles for off-road use must be durable, simple systems with high resistance to severe overloads and extremes in operating conditions. Conversely, products that are intended for high-speed, limited-access road systems require more passenger comfort options, increased engine performance, and optimized high-speed handling and vehicle stability. Stability depends principally on the distribution of weight between the front and rear wheels, the height of the centre of gravity and its position relative to the aerodynamic centre of pressure of the vehicle, suspension characteristics, and the selection of which wheels are used for propulsion. Weight distribution depends principally on the location and size of the engine. The common practice of front-mounted engines exploits the stability that is more readily achieved with this layout. The development of aluminum engines and new manufacturing processes has, however, made it possible to locate the engine at the rear without necessarily compromising stability.
# Automotive body designs are frequently categorized according to the number of doors, the arrangement of seats, and the roof structure. Automobile roofs are conventionally supported by pillars on each side of the body. Convertible models with retractable fabric tops rely on the pillar at the side of the windshield for upper body strength, as convertible mechanisms and glass areas are essentially nonstructural. Glass areas have been increased for improved visibility and for aesthetic reasons.
# The high cost of new factory tools makes it impractical for manufacturers to produce totally new designs every year. Completely new designs usually have been programmed on three- to six-year cycles with generally minor refinements appearing during the cycle. In the past, as many as four years of planning and new tool purchasing were needed for a completely new design. Computer-aided design (CAD), testing by use of computer simulations, and computer-aided manufacturing (CAM) techniques may now be used to reduce this time requirement by 50 percent or more. See machine tool: Computer-aided design and computer-aided manufacturing (CAD/CAM).
# Automotive bodies are generally formed out of sheet steel. The steel is alloyed with various elements to improve its ability to be formed into deeper depressions without wrinkling or tearing in manufacturing presses. Steel is used because of its general availability, low cost, and good workability. For certain applications, however, other materials, such as aluminum, fibreglass, and carbon-fibre reinforced plastic, are used because of their special properties. Polyamide, polyester, polystyrene, polypropylene, and ethylene plastics have been formulated for greater toughness, dent resistance, and resistance to brittle deformation. These materials are used for body panels. Tooling for plastic components generally costs less and requires less time to develop than that for steel components and therefore may be changed by designers at a lower cost.
# To protect bodies from corrosive elements and to maintain their strength and appearance, special priming and painting processes are used. Bodies are first dipped in cleaning baths to remove oil and other foreign matter. They then go through a succession of dip and spray cycles. Enamel and acrylic lacquer are both in common use. Electrodeposition of the sprayed paint, a process in which the paint spray is given an electrostatic charge and then attracted to the surface by a high voltage, helps assure that an even coat is applied and that hard-to-reach areas are covered. Ovens with conveyor lines are used to speed the drying process in the factory. Galvanized steel with a protective zinc coating and corrosion-resistant stainless steel are used in body areas that are more likely to corrode.

# %%
from requests_html import HTMLSession
# create an HTML Session object
session = HTMLSession()
burl = "https://www.britannica.com/technology/automobile"
# Use the object above to connect to needed webpage
resp = session.get(burl)

# %%
resp.html.absolute_links
# Out:
# {'http://corporate.britannica.com/publishing-partner-program/',
#  'https://cdn.britannica.com/09/97509-050-27B69959/Fiat-600-icon-styling-Italy-space-people-1956.jpg',
#  'https://cdn.britannica.com/16/126216-050-D9865939/Automobiles-John-F-Fitzgerald-Expressway-Massachusetts-Boston.jpg',
#  'https://cdn.britannica.com/17/142617-050-EFF7BBF8/automobile-assembly-line.jpg',
#  'https://cdn.britannica.com/84/91384-050-DA3570A0/components-automobile.jpg',
#  'https://kids.britannica.com/kids/article/car/352807',
#  'https://kids.britannica.com/students/article/automobile/273028',
#  'https://premium.britannica.com/premium-membership/?utm_source=premium&utm_medium=global-nav&utm_campaign=evergreen',
#  'https://twitter.com/britannica',
#  'https://www.britannica.com/',
#  'https://www.britannica.com/art/lacquer',
#  'https://www.britannica.com/biographies',
#  'https://www.britannica.com/biography/Alfred-P-Sloan-Jr',
#  'https://www.britannica.com/biography/Henry-Ford',
#  'https://www.britannica.com/biography/Patricia-Russo',
#  'https://www.britannica.com/biography/Robert-S-McNamara',
#  'https://www.britannica.com/biography/Walter-P-Chrysler',
#  'https://www.britannica.com/browse/Cars-Vehicles',
#  'https://www.britannica.com/browse/Entertainment-Pop-Culture',
#  'https://www.britannica.com/browse/Geography-Travel',
#  'https://www.britannica.com/browse/Health-Medicine',
#  'https://www.britannica.com/browse/Lifestyles-Social-Issues',
#  'https://www.britannica.com/browse/Literature',
#  'https://www.britannica.com/browse/Philosophy-Religion',
#  'https://www.britannica.com/browse/Politics-Law-Government',
#  'https://www.britannica.com/browse/Science',
#  'https://www.britannica.com/browse/Sports-Recreation',
#  'https://www.britannica.com/browse/Technology',
#  'https://www.britannica.com/browse/Visual-Arts',
#  'https://www.britannica.com/browse/World-History',
#  'https://www.britannica.com/contributor/Ken-W-Purdy/5989',
#  'https://www.britannica.com/facts/automobile',
#  'https://www.britannica.com/gallery/browse',
#  'https://www.britannica.com/games',
#  'https://www.britannica.com/list/browse',
#  'https://www.britannica.com/on-this-day',
#  'https://www.britannica.com/place/United-States',
#  'https://www.britannica.com/podcasts',
#  'https://www.britannica.com/quiz/browse',
#  'https://www.britannica.com/quiz/transportation-and-technology-firsts-quiz',
#  'https://www.britannica.com/science/air-pollution',
#  'https://www.britannica.com/science/centre-of-gravity',
#  'https://www.britannica.com/science/plastic',
#  'https://www.britannica.com/science/polypropylene',
#  'https://www.britannica.com/science/polystyrene',
#  'https://www.britannica.com/stories/companion',
#  'https://www.britannica.com/stories/demystified',
#  'https://www.britannica.com/stories/spotlight',
#  'https://www.britannica.com/stories/the-forum',
#  'https://www.britannica.com/stories/wtfact',
#  'https://www.britannica.com/study/infographics',
#  'https://www.britannica.com/summary',
#  'https://www.britannica.com/summary/automobile',
#  'https://www.britannica.com/technology/DeLorean-DMC-12',
#  'https://www.britannica.com/technology/Edsel',
#  'https://www.britannica.com/technology/Model-T',
#  'https://www.britannica.com/technology/automobile',
#  'https://www.britannica.com/technology/automobile#ref259040',
#  'https://www.britannica.com/technology/automobile#ref259041',
#  'https://www.britannica.com/technology/automobile/Alternative-fuel-vehicles',
#  'https://www.britannica.com/technology/automobile/Alternative-fuel-vehicles#ref259076',
#  'https://www.britannica.com/technology/automobile/Alternative-fuel-vehicles#ref259077',
#  'https://www.britannica.com/technology/automobile/Alternative-fuel-vehicles#ref259078',
#  'https://www.britannica.com/technology/automobile/Alternative-fuel-vehicles#ref259079',
#  'https://www.britannica.com/technology/automobile/Brakes',
#  'https://www.britannica.com/technology/automobile/Brakes#ref259052',
#  'https://www.britannica.com/technology/automobile/Brakes#ref259053',
#  'https://www.britannica.com/technology/automobile/Chassis',
#  'https://www.britannica.com/technology/automobile/Chassis#ref259043',
#  'https://www.britannica.com/technology/automobile/Chassis#ref259044',
#  'https://www.britannica.com/technology/automobile/Chassis#ref259045',
#  'https://www.britannica.com/technology/automobile/Cooling-system',
#  'https://www.britannica.com/technology/automobile/Cooling-system#ref259047',
#  'https://www.britannica.com/technology/automobile/Early-electric-automobiles',
#  'https://www.britannica.com/technology/automobile/Early-electric-automobiles#ref259062',
#  'https://www.britannica.com/technology/automobile/Early-electric-automobiles#ref259063',
#  'https://www.britannica.com/technology/automobile/Early-electric-automobiles#ref259064',
#  'https://www.britannica.com/technology/automobile/Early-electric-automobiles#ref259065',
#  'https://www.britannica.com/technology/automobile/Emission-controls',
#  'https://www.britannica.com/technology/automobile/Emission-controls#ref259058',
#  'https://www.britannica.com/technology/automobile/Emission-controls#ref259059',
#  'https://www.britannica.com/technology/automobile/Ford-and-the-automotive-revolution',
#  'https://www.britannica.com/technology/automobile/Ford-and-the-automotive-revolution#ref259069',
#  'https://www.britannica.com/technology/automobile/Ford-and-the-automotive-revolution#ref259070',
#  'https://www.britannica.com/technology/automobile/History-of-the-automobile',
#  'https://www.britannica.com/technology/automobile/History-of-the-automobile#ref259060',
#  'https://www.britannica.com/technology/automobile/Other-European-developments',
#  'https://www.britannica.com/technology/automobile/Other-European-developments#ref259067',
#  'https://www.britannica.com/technology/automobile/Tires',
#  'https://www.britannica.com/technology/automobile/Tires#ref259055',
#  'https://www.britannica.com/technology/automobile/Tires#ref259056',
#  'https://www.britannica.com/technology/automobile/Transmission',
#  'https://www.britannica.com/technology/automobile/Transmission#ref259049',
#  'https://www.britannica.com/technology/automobile/Transmission#ref259050',
#  'https://www.britannica.com/technology/automobile/V-8s-and-chrome-in-America',
#  'https://www.britannica.com/technology/automobile/V-8s-and-chrome-in-America#ref259072',
#  'https://www.britannica.com/technology/automobile/V-8s-and-chrome-in-America#ref259073',
#  'https://www.britannica.com/technology/automobile/V-8s-and-chrome-in-America#ref259074',
#  'https://www.britannica.com/technology/automobile/additional-info',
#  'https://www.britannica.com/technology/automobile/additional-info#Additional-Reading',
#  'https://www.britannica.com/technology/automobile/additional-info#More-Articles',
#  'https://www.britannica.com/technology/automobile/additional-info#contributors',
#  'https://www.britannica.com/technology/automobile/additional-info#history',
#  'https://www.britannica.com/technology/automobile/images-videos',
#  'https://www.britannica.com/technology/automobile/images-videos#Images',
#  'https://www.britannica.com/technology/automobile/images-videos#Videos',
#  'https://www.britannica.com/technology/body-vehicle',
#  'https://www.britannica.com/technology/catalytic-converter',
#  'https://www.britannica.com/technology/electric-automobile',
#  'https://www.britannica.com/technology/electroplating',
#  'https://www.britannica.com/technology/fiberglass',
#  'https://www.britannica.com/technology/internal-combustion-engine',
#  'https://www.britannica.com/technology/machine-tool/Adaptive-control#ref39172',
#  'https://www.britannica.com/technology/paint',
#  'https://www.britannica.com/technology/stainless-steel',
#  'https://www.britannica.com/technology/steel',
#  'https://www.britannica.com/technology/technology',
#  'https://www.britannica.com/technology/transportation-technology',
#  'https://www.britannica.com/topic/Ford-999',
#  'https://www.britannica.com/topic/industrial-design',
#  'https://www.britannica.com/videos/Entertainment-Pop-Culture',
#  'https://www.britannica.com/videos/Geography-Travel',
#  'https://www.britannica.com/videos/Health-Medicine',
#  'https://www.britannica.com/videos/Lifestyles-Social-Issues',
#  'https://www.britannica.com/videos/Literature',
#  'https://www.britannica.com/videos/Philosophy-Religion',
#  'https://www.britannica.com/videos/Politics-Law-Government',
#  'https://www.britannica.com/videos/Science',
#  'https://www.britannica.com/videos/Sports-Recreation',
#  'https://www.britannica.com/videos/Technology',
#  'https://www.britannica.com/videos/Visual-Arts',
#  'https://www.britannica.com/videos/World-History',
#  'https://www.britannica.com/videos/britannica-classics',
#  'https://www.britannica.com/videos/demystified',
#  'https://www.britannica.com/videos/explains',
#  'https://www.britannica.com/videos/this-week-in-history',
#  'https://www.britannica.com/videos/wtfact',
#  'https://www.britannica.com/week-in-review',
#  'https://www.facebook.com/BRITANNICA/',
#  'https://www.livescience.com/37538-who-invented-the-car.html',
#  'https://www.merriam-webster.com/dictionary/Galvanized',
#  'https://www.merriam-webster.com/dictionary/aesthetic',
#  'https://www.merriam-webster.com/dictionary/implemented',
#  'https://www.merriam-webster.com/dictionary/mandated',
#  'https://www.merriam-webster.com/dictionary/proprietary'}

# %%
for u in resp.html.absolute_links:
    if burl in u and u != burl:
        print(u)
# Out:
# https://www.britannica.com/technology/automobile/Early-electric-automobiles#ref259063
# https://www.britannica.com/technology/automobile/additional-info#More-Articles
# https://www.britannica.com/technology/automobile/Tires#ref259056
# https://www.britannica.com/technology/automobile/images-videos
# https://www.britannica.com/technology/automobile/Chassis#ref259043
# https://www.britannica.com/technology/automobile/Emission-controls
# https://www.britannica.com/technology/automobile/Chassis#ref259044
# https://www.britannica.com/technology/automobile/Alternative-fuel-vehicles#ref259079
# https://www.britannica.com/technology/automobile/additional-info#history
# https://www.britannica.com/technology/automobile/Emission-controls#ref259059
# https://www.britannica.com/technology/automobile/Tires
# https://www.britannica.com/technology/automobile/Transmission
# https://www.britannica.com/technology/automobile/Alternative-fuel-vehicles#ref259077
# https://www.britannica.com/technology/automobile/Transmission#ref259049
# https://www.britannica.com/technology/automobile/Emission-controls#ref259058
# https://www.britannica.com/technology/automobile/V-8s-and-chrome-in-America#ref259073
# https://www.britannica.com/technology/automobile/Chassis
# https://www.britannica.com/technology/automobile/History-of-the-automobile
# https://www.britannica.com/technology/automobile/Alternative-fuel-vehicles#ref259078
# https://www.britannica.com/technology/automobile/Early-electric-automobiles
# https://www.britannica.com/technology/automobile/images-videos#Images
# https://www.britannica.com/technology/automobile/Early-electric-automobiles#ref259064
# https://www.britannica.com/technology/automobile/Brakes
# https://www.britannica.com/technology/automobile/Ford-and-the-automotive-revolution#ref259069
# https://www.britannica.com/technology/automobile/Cooling-system
# https://www.britannica.com/technology/automobile/Brakes#ref259053
# https://www.britannica.com/technology/automobile/V-8s-and-chrome-in-America#ref259074
# https://www.britannica.com/technology/automobile/Alternative-fuel-vehicles
# https://www.britannica.com/technology/automobile/Chassis#ref259045
# https://www.britannica.com/technology/automobile/additional-info#Additional-Reading
# https://www.britannica.com/technology/automobile/V-8s-and-chrome-in-America#ref259072
# https://www.britannica.com/technology/automobile/Ford-and-the-automotive-revolution
# https://www.britannica.com/technology/automobile/Ford-and-the-automotive-revolution#ref259070
# https://www.britannica.com/technology/automobile/Brakes#ref259052
# https://www.britannica.com/technology/automobile/Other-European-developments#ref259067
# https://www.britannica.com/technology/automobile/Early-electric-automobiles#ref259065
# https://www.britannica.com/technology/automobile/Alternative-fuel-vehicles#ref259076
# https://www.britannica.com/technology/automobile/images-videos#Videos
# https://www.britannica.com/technology/automobile/V-8s-and-chrome-in-America
# https://www.britannica.com/technology/automobile/Cooling-system#ref259047
# https://www.britannica.com/technology/automobile/Tires#ref259055
# https://www.britannica.com/technology/automobile/additional-info
# https://www.britannica.com/technology/automobile/History-of-the-automobile#ref259060
# https://www.britannica.com/technology/automobile/additional-info#contributors
# https://www.britannica.com/technology/automobile#ref259041
# https://www.britannica.com/technology/automobile#ref259040
# https://www.britannica.com/technology/automobile/Other-European-developments
# https://www.britannica.com/technology/automobile/Transmission#ref259050
# https://www.britannica.com/technology/automobile/Early-electric-automobiles#ref259062

# %%
r.html.links
# Out:
# {'/',
#  '/biographies',
#  '/biography/Alfred-P-Sloan-Jr',
#  '/biography/Henry-Ford',
#  '/biography/Patricia-Russo',
#  '/biography/Robert-S-McNamara',
#  '/biography/Walter-P-Chrysler',
#  '/browse/Cars-Vehicles',
#  '/browse/Entertainment-Pop-Culture',
#  '/browse/Geography-Travel',
#  '/browse/Health-Medicine',
#  '/browse/Lifestyles-Social-Issues',
#  '/browse/Literature',
#  '/browse/Philosophy-Religion',
#  '/browse/Politics-Law-Government',
#  '/browse/Science',
#  '/browse/Sports-Recreation',
#  '/browse/Technology',
#  '/browse/Visual-Arts',
#  '/browse/World-History',
#  '/contributor/Orville-C-Cromer/649',
#  '/facts/automobile',
#  '/gallery/browse',
#  '/games',
#  '/list/browse',
#  '/on-this-day',
#  '/podcasts',
#  '/quiz/browse',
#  '/quiz/transportation-and-technology-firsts-quiz',
#  '/stories/companion',
#  '/stories/demystified',
#  '/stories/spotlight',
#  '/stories/the-forum',
#  '/stories/wtfact',
#  '/summary',
#  '/summary/automobile',
#  '/technology/DeLorean-DMC-12',
#  '/technology/Edsel',
#  '/technology/Model-T',
#  '/technology/automobile',
#  '/technology/automobile#ref259040',
#  '/technology/automobile#ref259041',
#  '/technology/automobile/Alternative-fuel-vehicles',
#  '/technology/automobile/Alternative-fuel-vehicles#ref259076',
#  '/technology/automobile/Alternative-fuel-vehicles#ref259077',
#  '/technology/automobile/Alternative-fuel-vehicles#ref259078',
#  '/technology/automobile/Alternative-fuel-vehicles#ref259079',
#  '/technology/automobile/Brakes',
#  '/technology/automobile/Brakes#ref259052',
#  '/technology/automobile/Brakes#ref259053',
#  '/technology/automobile/Chassis',
#  '/technology/automobile/Chassis#ref259043',
#  '/technology/automobile/Chassis#ref259044',
#  '/technology/automobile/Chassis#ref259045',
#  '/technology/automobile/Cooling-system',
#  '/technology/automobile/Cooling-system#ref259047',
#  '/technology/automobile/Early-electric-automobiles',
#  '/technology/automobile/Early-electric-automobiles#ref259062',
#  '/technology/automobile/Early-electric-automobiles#ref259063',
#  '/technology/automobile/Early-electric-automobiles#ref259064',
#  '/technology/automobile/Early-electric-automobiles#ref259065',
#  '/technology/automobile/Emission-controls',
#  '/technology/automobile/Emission-controls#ref259058',
#  '/technology/automobile/Emission-controls#ref259059',
#  '/technology/automobile/Ford-and-the-automotive-revolution',
#  '/technology/automobile/Ford-and-the-automotive-revolution#ref259069',
#  '/technology/automobile/Ford-and-the-automotive-revolution#ref259070',
#  '/technology/automobile/History-of-the-automobile',
#  '/technology/automobile/History-of-the-automobile#ref259060',
#  '/technology/automobile/Other-European-developments',
#  '/technology/automobile/Other-European-developments#ref259067',
#  '/technology/automobile/Tires',
#  '/technology/automobile/Tires#ref259055',
#  '/technology/automobile/Tires#ref259056',
#  '/technology/automobile/Transmission',
#  '/technology/automobile/Transmission#ref259049',
#  '/technology/automobile/Transmission#ref259050',
#  '/technology/automobile/V-8s-and-chrome-in-America',
#  '/technology/automobile/V-8s-and-chrome-in-America#ref259072',
#  '/technology/automobile/V-8s-and-chrome-in-America#ref259073',
#  '/technology/automobile/V-8s-and-chrome-in-America#ref259074',
#  '/technology/automobile/additional-info',
#  '/technology/automobile/additional-info#Additional-Reading',
#  '/technology/automobile/additional-info#More-Articles',
#  '/technology/automobile/additional-info#contributors',
#  '/technology/automobile/additional-info#history',
#  '/technology/automobile/images-videos',
#  '/technology/automobile/images-videos#Images',
#  '/technology/automobile/images-videos#Videos',
#  '/technology/electric-automobile',
#  '/topic/Ford-999',
#  '/videos/Entertainment-Pop-Culture',
#  '/videos/Geography-Travel',
#  '/videos/Health-Medicine',
#  '/videos/Lifestyles-Social-Issues',
#  '/videos/Literature',
#  '/videos/Philosophy-Religion',
#  '/videos/Politics-Law-Government',
#  '/videos/Science',
#  '/videos/Sports-Recreation',
#  '/videos/Technology',
#  '/videos/Visual-Arts',
#  '/videos/World-History',
#  '/videos/britannica-classics',
#  '/videos/demystified',
#  '/videos/explains',
#  '/videos/this-week-in-history',
#  '/videos/wtfact',
#  '/week-in-review',
#  'http://corporate.britannica.com/publishing-partner-program/',
#  'https://cdn.britannica.com/09/97509-050-27B69959/Fiat-600-icon-styling-Italy-space-people-1956.jpg',
#  'https://cdn.britannica.com/16/126216-050-D9865939/Automobiles-John-F-Fitzgerald-Expressway-Massachusetts-Boston.jpg',
#  'https://cdn.britannica.com/17/142617-050-EFF7BBF8/automobile-assembly-line.jpg',
#  'https://cdn.britannica.com/84/91384-050-DA3570A0/components-automobile.jpg',
#  'https://kids.britannica.com/kids/article/car/352807',
#  'https://kids.britannica.com/students/article/automobile/273028',
#  'https://premium.britannica.com/premium-membership/?utm_source=premium&utm_medium=global-nav&utm_campaign=evergreen',
#  'https://twitter.com/britannica',
#  'https://www.britannica.com/art/lacquer',
#  'https://www.britannica.com/place/United-States',
#  'https://www.britannica.com/science/air-pollution',
#  'https://www.britannica.com/science/centre-of-gravity',
#  'https://www.britannica.com/science/plastic',
#  'https://www.britannica.com/science/polypropylene',
#  'https://www.britannica.com/science/polystyrene',
#  'https://www.britannica.com/study/infographics',
#  'https://www.britannica.com/technology/automobile',
#  'https://www.britannica.com/technology/body-vehicle',
#  'https://www.britannica.com/technology/catalytic-converter',
#  'https://www.britannica.com/technology/electroplating',
#  'https://www.britannica.com/technology/fiberglass',
#  'https://www.britannica.com/technology/internal-combustion-engine',
#  'https://www.britannica.com/technology/machine-tool/Adaptive-control#ref39172',
#  'https://www.britannica.com/technology/paint',
#  'https://www.britannica.com/technology/stainless-steel',
#  'https://www.britannica.com/technology/steel',
#  'https://www.britannica.com/technology/technology',
#  'https://www.britannica.com/technology/transportation-technology',
#  'https://www.britannica.com/topic/industrial-design',
#  'https://www.facebook.com/BRITANNICA/',
#  'https://www.livescience.com/37538-who-invented-the-car.html',
#  'https://www.merriam-webster.com/dictionary/Galvanized',
#  'https://www.merriam-webster.com/dictionary/aesthetic',
#  'https://www.merriam-webster.com/dictionary/implemented',
#  'https://www.merriam-webster.com/dictionary/mandated',
#  'https://www.merriam-webster.com/dictionary/proprietary'}

# %%
r.html.absolute_links
# Out:
# /home/barzamini/.pyenv/versions/3.7.6/lib/python3.7/site-packages/bs4/__init__.py:719: RuntimeWarning: coroutine 'BaseSession.browser' was never awaited
#   sourceline=sourceline, sourcepos=sourcepos
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback
# {'http://corporate.britannica.com/publishing-partner-program/',
#  'https://cdn.britannica.com/09/97509-050-27B69959/Fiat-600-icon-styling-Italy-space-people-1956.jpg',
#  'https://cdn.britannica.com/16/126216-050-D9865939/Automobiles-John-F-Fitzgerald-Expressway-Massachusetts-Boston.jpg',
#  'https://cdn.britannica.com/17/142617-050-EFF7BBF8/automobile-assembly-line.jpg',
#  'https://cdn.britannica.com/84/91384-050-DA3570A0/components-automobile.jpg',
#  'https://kids.britannica.com/kids/article/car/352807',
#  'https://kids.britannica.com/students/article/automobile/273028',
#  'https://premium.britannica.com/premium-membership/?utm_source=premium&utm_medium=global-nav&utm_campaign=evergreen',
#  'https://twitter.com/britannica',
#  'https://www.britannica.com/',
#  'https://www.britannica.com/art/lacquer',
#  'https://www.britannica.com/biographies',
#  'https://www.britannica.com/biography/Alfred-P-Sloan-Jr',
#  'https://www.britannica.com/biography/Henry-Ford',
#  'https://www.britannica.com/biography/Patricia-Russo',
#  'https://www.britannica.com/biography/Robert-S-McNamara',
#  'https://www.britannica.com/biography/Walter-P-Chrysler',
#  'https://www.britannica.com/browse/Cars-Vehicles',
#  'https://www.britannica.com/browse/Entertainment-Pop-Culture',
#  'https://www.britannica.com/browse/Geography-Travel',
#  'https://www.britannica.com/browse/Health-Medicine',
#  'https://www.britannica.com/browse/Lifestyles-Social-Issues',
#  'https://www.britannica.com/browse/Literature',
#  'https://www.britannica.com/browse/Philosophy-Religion',
#  'https://www.britannica.com/browse/Politics-Law-Government',
#  'https://www.britannica.com/browse/Science',
#  'https://www.britannica.com/browse/Sports-Recreation',
#  'https://www.britannica.com/browse/Technology',
#  'https://www.britannica.com/browse/Visual-Arts',
#  'https://www.britannica.com/browse/World-History',
#  'https://www.britannica.com/contributor/George-C-Cromer/648',
#  'https://www.britannica.com/facts/automobile',
#  'https://www.britannica.com/gallery/browse',
#  'https://www.britannica.com/games',
#  'https://www.britannica.com/list/browse',
#  'https://www.britannica.com/on-this-day',
#  'https://www.britannica.com/place/United-States',
#  'https://www.britannica.com/podcasts',
#  'https://www.britannica.com/quiz/browse',
#  'https://www.britannica.com/quiz/transportation-and-technology-firsts-quiz',
#  'https://www.britannica.com/science/air-pollution',
#  'https://www.britannica.com/science/centre-of-gravity',
#  'https://www.britannica.com/science/plastic',
#  'https://www.britannica.com/science/polypropylene',
#  'https://www.britannica.com/science/polystyrene',
#  'https://www.britannica.com/stories/companion',
#  'https://www.britannica.com/stories/demystified',
#  'https://www.britannica.com/stories/spotlight',
#  'https://www.britannica.com/stories/the-forum',
#  'https://www.britannica.com/stories/wtfact',
#  'https://www.britannica.com/study/infographics',
#  'https://www.britannica.com/summary',
#  'https://www.britannica.com/summary/automobile',
#  'https://www.britannica.com/technology/DeLorean-DMC-12',
#  'https://www.britannica.com/technology/Edsel',
#  'https://www.britannica.com/technology/Model-T',
#  'https://www.britannica.com/technology/automobile',
#  'https://www.britannica.com/technology/automobile#ref259040',
#  'https://www.britannica.com/technology/automobile#ref259041',
#  'https://www.britannica.com/technology/automobile/Alternative-fuel-vehicles',
#  'https://www.britannica.com/technology/automobile/Alternative-fuel-vehicles#ref259076',
#  'https://www.britannica.com/technology/automobile/Alternative-fuel-vehicles#ref259077',
#  'https://www.britannica.com/technology/automobile/Alternative-fuel-vehicles#ref259078',
#  'https://www.britannica.com/technology/automobile/Alternative-fuel-vehicles#ref259079',
#  'https://www.britannica.com/technology/automobile/Brakes',
#  'https://www.britannica.com/technology/automobile/Brakes#ref259052',
#  'https://www.britannica.com/technology/automobile/Brakes#ref259053',
#  'https://www.britannica.com/technology/automobile/Chassis',
#  'https://www.britannica.com/technology/automobile/Chassis#ref259043',
#  'https://www.britannica.com/technology/automobile/Chassis#ref259044',
#  'https://www.britannica.com/technology/automobile/Chassis#ref259045',
#  'https://www.britannica.com/technology/automobile/Cooling-system',
#  'https://www.britannica.com/technology/automobile/Cooling-system#ref259047',
#  'https://www.britannica.com/technology/automobile/Early-electric-automobiles',
#  'https://www.britannica.com/technology/automobile/Early-electric-automobiles#ref259062',
#  'https://www.britannica.com/technology/automobile/Early-electric-automobiles#ref259063',
#  'https://www.britannica.com/technology/automobile/Early-electric-automobiles#ref259064',
#  'https://www.britannica.com/technology/automobile/Early-electric-automobiles#ref259065',
#  'https://www.britannica.com/technology/automobile/Emission-controls',
#  'https://www.britannica.com/technology/automobile/Emission-controls#ref259058',
#  'https://www.britannica.com/technology/automobile/Emission-controls#ref259059',
#  'https://www.britannica.com/technology/automobile/Ford-and-the-automotive-revolution',
#  'https://www.britannica.com/technology/automobile/Ford-and-the-automotive-revolution#ref259069',
#  'https://www.britannica.com/technology/automobile/Ford-and-the-automotive-revolution#ref259070',
#  'https://www.britannica.com/technology/automobile/History-of-the-automobile',
#  'https://www.britannica.com/technology/automobile/History-of-the-automobile#ref259060',
#  'https://www.britannica.com/technology/automobile/Other-European-developments',
#  'https://www.britannica.com/technology/automobile/Other-European-developments#ref259067',
#  'https://www.britannica.com/technology/automobile/Tires',
#  'https://www.britannica.com/technology/automobile/Tires#ref259055',
#  'https://www.britannica.com/technology/automobile/Tires#ref259056',
#  'https://www.britannica.com/technology/automobile/Transmission',
#  'https://www.britannica.com/technology/automobile/Transmission#ref259049',
#  'https://www.britannica.com/technology/automobile/Transmission#ref259050',
#  'https://www.britannica.com/technology/automobile/V-8s-and-chrome-in-America',
#  'https://www.britannica.com/technology/automobile/V-8s-and-chrome-in-America#ref259072',
#  'https://www.britannica.com/technology/automobile/V-8s-and-chrome-in-America#ref259073',
#  'https://www.britannica.com/technology/automobile/V-8s-and-chrome-in-America#ref259074',
#  'https://www.britannica.com/technology/automobile/additional-info',
#  'https://www.britannica.com/technology/automobile/additional-info#Additional-Reading',
#  'https://www.britannica.com/technology/automobile/additional-info#More-Articles',
#  'https://www.britannica.com/technology/automobile/additional-info#contributors',
#  'https://www.britannica.com/technology/automobile/additional-info#history',
#  'https://www.britannica.com/technology/automobile/images-videos',
#  'https://www.britannica.com/technology/automobile/images-videos#Images',
#  'https://www.britannica.com/technology/automobile/images-videos#Videos',
#  'https://www.britannica.com/technology/body-vehicle',
#  'https://www.britannica.com/technology/catalytic-converter',
#  'https://www.britannica.com/technology/electric-automobile',
#  'https://www.britannica.com/technology/electroplating',
#  'https://www.britannica.com/technology/fiberglass',
#  'https://www.britannica.com/technology/internal-combustion-engine',
#  'https://www.britannica.com/technology/machine-tool/Adaptive-control#ref39172',
#  'https://www.britannica.com/technology/paint',
#  'https://www.britannica.com/technology/stainless-steel',
#  'https://www.britannica.com/technology/steel',
#  'https://www.britannica.com/technology/technology',
#  'https://www.britannica.com/technology/transportation-technology',
#  'https://www.britannica.com/topic/Ford-999',
#  'https://www.britannica.com/topic/industrial-design',
#  'https://www.britannica.com/videos/Entertainment-Pop-Culture',
#  'https://www.britannica.com/videos/Geography-Travel',
#  'https://www.britannica.com/videos/Health-Medicine',
#  'https://www.britannica.com/videos/Lifestyles-Social-Issues',
#  'https://www.britannica.com/videos/Literature',
#  'https://www.britannica.com/videos/Philosophy-Religion',
#  'https://www.britannica.com/videos/Politics-Law-Government',
#  'https://www.britannica.com/videos/Science',
#  'https://www.britannica.com/videos/Sports-Recreation',
#  'https://www.britannica.com/videos/Technology',
#  'https://www.britannica.com/videos/Visual-Arts',
#  'https://www.britannica.com/videos/World-History',
#  'https://www.britannica.com/videos/britannica-classics',
#  'https://www.britannica.com/videos/demystified',
#  'https://www.britannica.com/videos/explains',
#  'https://www.britannica.com/videos/this-week-in-history',
#  'https://www.britannica.com/videos/wtfact',
#  'https://www.britannica.com/week-in-review',
#  'https://www.facebook.com/BRITANNICA/',
#  'https://www.livescience.com/37538-who-invented-the-car.html',
#  'https://www.merriam-webster.com/dictionary/Galvanized',
#  'https://www.merriam-webster.com/dictionary/aesthetic',
#  'https://www.merriam-webster.com/dictionary/implemented',
#  'https://www.merriam-webster.com/dictionary/mandated',
#  'https://www.merriam-webster.com/dictionary/proprietary'}

# %%
r.html.text
# Out:
# 'window.$UI = {}; window.Constants = {"LICENSE_URL": "/bps/license","DEFAULT_TEST_VERSION": "A","DEFAULT_STATE": "XX","QUIZ_URL": "/quiz","SPOTLIGHT_BROWSE_URL": "/stories/spotlight","CONTENT_TYPE_TEXT": "text/plain;charset=UTF-8","TOPIC_MEDIA_PATH": "/images-videos","DEBUG_URL": "/debug","ERROR_404_URL": "/error404","TOPIC_QUOTES_PATH": "/quotes","INSTANT_ARTICLES_URL": "/instant-articles","TOPIC_PAGE_CONTENT_AJAX_URL": "/topic-content/page","INFINITE_SCROLL_PREFIX_URL": "/scroll","CC_USD": "USD","SURVEY_URL": "/survey","CATEGORY_BROWSE_URL": "/browse","STORY_BROWSE_URL": "/stories","IN_THIS_WEEK_BROWSE_URL": "/week-in-review","COUNTRY_US": "US","OPEN_MEDIA_OVERLAY_PARAMETER": "/media","FACTS_URL": "/facts","GAMES_BROWSE_WORDSEARCH_URL": "/games/Word-Search","NEWSLETTER_SUBSCRIPTION_URL": "/newsletter-subscription","INSIGHTS_LANDING_PAGE_URL_2": "/factsmatter","HOMEPAGE_VIDEO_ADMIN_URL": "/homepage-videos-admin","INSIGHTS_LANDING_PAGE_URL_1": "/insights","MAINTENANCE_ERROR_URL": "https://maintenance.eb.com","IMARS_EDITOR_ID": "12365882","PROFILE_EB_EDITOR_URL": "/editor","WEB_INF_RESOURCES_PATH": "WEB-INF/resources","TOPIC_ADDITIONAL_INFO_PATH": "/additional-info","CC_INR": "INR","ARTICLE_PRINT_URL": "/print/article","FIRST_EDITION_URL": "/subscriber/firstedition","WW1_PORTAL_URL": "/discover/World-War-I","PROFILE_USER_URL": "/user","MENDEL_COOKIE": "__mendel","DEMYSTIFIED_BROWSE_URL": "/stories/demystified","LIST_BROWSE_URL": "/list/browse","PROFILE_EXPERT_URL": "/contributor","USER_PROFILE_PICTURE_URL": "/image/profile","ASSEMBLY_IMAGE_URL": "/image/assembly","DAY_IN_HISTORY_URL": "/on-this-day","DEFAULT_CURRENCY": "USD","GAMES_HOMEPAGE_URL": "/games","CONTENT_TYPE_XML": "text/xml;charset=UTF-8","AJAX_PREFIX_URL": "/ajax","TOPIC_BROWSE_URL": "/topic-browse","MARKETING_CONTENT": "/marketing-content","ENV_RUNTIME": "runtime","USER_PROFILE_PARTNER_LOGO_URL": "/image/profile-partner","GALLERY_URL": "/gallery","CONTENT_TYPE_HTML": "text/html;charset=UTF-8","ENV_LOCAL": "override","MEDIA_OVERLAY_URL": "/media-overlay","ENV_DEV": "development","MEDIA_URL": "/media","PODCASTS_URL": "/podcasts","STAND_ALONE_VIDEO_URL": "/video","MORE_ON_THIS_DAY_URL": "/more-on-this-day","SEARCH_PAGE_URL": "/search","TOPIC_CONTENT_AJAX_URL": "/topic-content/topic","ENV_BRANCH": "branch","ERROR_URL": "/error","MAIN_VERSION": "mainVersion","DEFAULT_S3_REGION": "US_EAST_1","LOGINBOX_URL": "/auth/loginbox","QUIZ_BROWSE_URL": "/quiz/browse","BIO_BROWSE_URL": "/biographies","LIST_URL": "/list","ALPHA_BROWSE_URL": "/sitemap","GAME_URL": "/game","CONTENT_TYPE_JSON": "application/json","COBRAND_IMAGE_URL": "/image/cobrand","SUBMISSION_URL": "/submission","EB_LOG_OUT": "/auth2/logout","ENV_PRODUCTION": "production","CONTENTFUL_ADMIN_PREFIX_URL": "/contentful-admin","TOPIC_AJAX_URL": "/ajax/topic","GAMES_BROWSE_CROSSWORD_URL": "/games/Crossword-Puzzle","WTFACT_BROWSE_URL": "/stories/wtfact","FEATURED_CONTENT_ADMIN_URL": "/fc-admin","VIDEO_CHANNEL_URL": "/videos","GALLERY_BROWSE_URL": "/gallery/browse","CACHE_URL": "/cache","COMPANION_BROWSE_URL": "/stories/companion","MEDIA_FOLDER": "/eb-media","SHOW_ALL_CONTRIBUTORS": "/additional-info#contributors","BRITANNICA_EDITORS_ID": "4419","EXPLORE_BROWSE": "/explore","TOPIC_SUMMARY_URL": "/summary","ENV_CACHE_DISABLED": "mendelCache","STORY_URL": "/story","DEFAULT_COUNTRY": "US","NAVBAR_URL": "/ajax/navbar","EB_LOGIN_URL": "/auth/eb-login","NEW_ARTICLES_URL": "/new-articles",}; window.CDN = "https://cdn.britannica.com"; window.CAM_LOGIN_URL = "https://cam.britannica.com"; window.CAM_SIGN_UP_URL = "https://cam.britannica.com/registration" window.Mendel = { "config" : { "page": "Topic", "videoPlayerId": "DkXxjTZZ", "sharedUrl": "https://www.britannica.com/technology/automobile", "resourcesPrefixUrl": "https://cdn.britannica.com/mendel-resources/3-53/[url]?v=3.53.17", "userInfo": { "type": "ANONYMOUS" ,"currency": "USD" ,"country": "US" ,"state": "IL" ,"bcomId": "4128713418556141116" ,"hasAds": true ,"testVersion": "A"  ...

# %%
! pwd
# Out:
# /home/barzamini/text_processing

# %%
! pip install wordnik-py3
# Out:
# Collecting wordnik-py3
#   Downloading wordnik-py3-2.1.2.tar.gz (12 kB)
# Using legacy 'setup.py install' for wordnik-py3, since package 'wheel' is not installed.
# Installing collected packages: wordnik-py3
#     Running setup.py install for wordnik-py3 ... done
# Successfully installed wordnik-py3-2.1.2
# WARNING: You are using pip version 20.3.3; however, version 21.3.1 is available.
# You should consider upgrading via the '/home/barzamini/.pyenv/versions/3.7.6/bin/python3.7 -m pip install --upgrade pip' command.

# %%
from wordnik import *
apiUrl = 'http://api.wordnik.com/v4'
apiKey = '9dmlxriqc79go7af39ogn53f500z13os36y35a1vfmw2baes8'
client = swagger.ApiClient(apiKey, apiUrl)

# %%
wordApi = WordApi.WordApi(client)
examples = wordApi.getExamples('car')
print(examples)
# Out:
# <wordnik.models.ExampleSearchResults.ExampleSearchResults object at 0x7fb2ad7cb810>

# %%
print(examples.examples)
# Out:
# [<wordnik.models.Example.Example object at 0x7fb2ad7cba10>, <wordnik.models.Example.Example object at 0x7fb2ad7cbd10>, <wordnik.models.Example.Example object at 0x7fb2ad7cbc90>, <wordnik.models.Example.Example object at 0x7fb2ad7d1a50>, <wordnik.models.Example.Example object at 0x7fb2ad7d1f50>, <wordnik.models.Example.Example object at 0x7fb2ad7d1250>, <wordnik.models.Example.Example object at 0x7fb2ad7d1c90>, <wordnik.models.Example.Example object at 0x7fb2ad7d1290>, <wordnik.models.Example.Example object at 0x7fb2ad7dd150>, <wordnik.models.Example.Example object at 0x7fb2ad7d1fd0>]

# %%
for el in examples.examples:
    print(el.text)
# Out:
# The more he thought about it, the more E.erhard sensed the time might be exactly right for starting a car company — an E. V.-car company at that.
# - I got a new car, which has also become my new hobby. * it's a beautiful fast car* I have good mentors, one good one mostly, who has been there when i'm lost for answers on why it does the things i don't want it to do.
# Seriously, the Exige is one super quick car * specially designed to be a track car*, and the Mustang is, well, just a run of the mill muscle car - a very good one, but still designed more for the street, than the track.
# Seriously, the Exige is one super quick car * specially designed to be a track car*, and the Mustang is, well, just a run of the mill muscle car - a very good one, but still designed more for the street, than the track.
# I'll meet you at the car Krystal: ok * By paint* Kristina: Now I'm looking at for a bright pink*Looking around and notices a cute boy* Kristina: Well don't he look good * Boy walks by and bumps Kristina* Boy: I'm so sorry I didn't mean to*smiles at her* Kristina: it's ok*pays for paint and goes meet her mom at the car* Krystal: why are you so smiley?
# Seriously, the Exige is one super quick car * specially designed to be a track car*, and the Mustang is, well, just a run of the mill muscle car - a very good one, but still designed more for the street, than the track.
# Seriously, the Exige is one super quick car * specially designed to be a track car*, and the Mustang is, well, just a run of the mill muscle car - a very good one, but still designed more for the street, than the track.
# Seriously, the Exige is one super quick car * specially designed to be a track car*, and the Mustang is, well, just a run of the mill muscle car - a very good one, but still designed more for the street, than the track.
# Vehicle features: ** bmw full free warranty and full free maintenance good till 50,000 miles**clean car fax and 1 owner california car** popular and hard to find jet black 2006 bmw
# Vehicle features: ** bmw full free warranty and full free maintenance good till 50,000 miles**clean car fax and 1 owner california car**. well equipped with moonroof, power front seats, automatic climate control, hi-fi sound system, steptronic automatic transmission, rain sensor and auto headlight, dynamic cruise control and dark burl walnut wood trim. **test drive it today!
